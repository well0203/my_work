# %% [markdown]
# <details>
# <summary>Table of Contents</summary>
#
# - [1. Pretrain](#1-pretrain)
# - [2. Finetune](#2-finetune)
#
# </details>
#
#
#
# This notebook demonstrates experiments on 5 countries with self-supervised learning.
# All parameters and settings are taken from the paper.

# %%
import pandas as pd
import subprocess
import os
from utils.helper import extract_metrics_from_output

# %% [markdown]
# # 1. Pretrain
#
# Tracking loss - MAE.

# %%
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Execute the command
        print(f"==========Running command for {country}, pred_len {pred_len}:==========")
        # !{command}
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9374965442536594.
#               0       0.981123       0.937497          00:08
# Better model found at epoch 1 with valid_loss value: 0.9312531101717066.
#               1       0.944243       0.931253          00:08
# Better model found at epoch 2 with valid_loss value: 0.927219625874618.
#               2       0.935412       0.927220          00:08
# Better model found at epoch 3 with valid_loss value: 0.9248661840769262.
#               3       0.931152       0.924866          00:08
#               4       0.927994       0.924922          00:08
# Better model found at epoch 5 with valid_loss value: 0.9224562722424401.
#               5       0.925110       0.922456          00:08
# Better model found at epoch 6 with valid_loss value: 0.9222122494269744.
#               6       0.923812       0.922212          00:08
#               7       0.922067       0.922481          00:08
# Better model found at epoch 8 with valid_loss value: 0.9187570528641226.
#               8       0.920782       0.918757          00:08
#               9       0.919674       0.921091          00:08
#              10       0.920443       0.921865          00:08
#              11       0.919106       0.919203          00:08
#              12       0.919393       0.919268          00:09
# Better model found at epoch 13 with valid_loss value: 0.7351999808991475.
#              13       0.908705       0.735200          00:09
# Better model found at epoch 14 with valid_loss value: 0.6758308870838025.
#              14       0.714672       0.675831          00:09
# Better model found at epoch 15 with valid_loss value: 0.671674331093172.
#              15       0.693911       0.671674          00:08
# Better model found at epoch 16 with valid_loss value: 0.6698368950558952.
#              16       0.687387       0.669837          00:08
# Better model found at epoch 17 with valid_loss value: 0.669020789141668.
#              17       0.684520       0.669021          00:08
# Better model found at epoch 18 with valid_loss value: 0.6220301001789448.
#              18       0.664230       0.622030          00:08
# Better model found at epoch 19 with valid_loss value: 0.44891837495727444.
#              19       0.571838       0.448918          00:08
# Better model found at epoch 20 with valid_loss value: 0.39995732153269264.
#              20       0.467948       0.399957          00:08
# Better model found at epoch 21 with valid_loss value: 0.3744632990313857.
#              21       0.429079       0.374463          00:08
# Better model found at epoch 22 with valid_loss value: 0.3664503657436263.
#              22       0.404935       0.366450          00:08
# Better model found at epoch 23 with valid_loss value: 0.3137397489997185.
#              23       0.385198       0.313740          00:08
# Better model found at epoch 24 with valid_loss value: 0.25938828106150474.
#              24       0.325613       0.259388          00:08
# Better model found at epoch 25 with valid_loss value: 0.25334516245777705.
#              25       0.294923       0.253345          00:08
# Better model found at epoch 26 with valid_loss value: 0.24450277150856523.
#              26       0.274202       0.244503          00:08
# Better model found at epoch 27 with valid_loss value: 0.23354300943355918.
#              27       0.256230       0.233543          00:08
# Better model found at epoch 28 with valid_loss value: 0.22448483068727884.
#              28       0.243543       0.224485          00:08
# Better model found at epoch 29 with valid_loss value: 0.22331127101093776.
#              29       0.234776       0.223311          00:08
# Better model found at epoch 30 with valid_loss value: 0.22037693003433126.
#              30       0.228062       0.220377          00:08
# Better model found at epoch 31 with valid_loss value: 0.21659347683895971.
#              31       0.222647       0.216593          00:08
#              32       0.218535       0.219557          00:08
# Better model found at epoch 33 with valid_loss value: 0.21347443014742842.
#              33       0.215160       0.213474          00:08
# Better model found at epoch 34 with valid_loss value: 0.21179972834692173.
#              34       0.211543       0.211800          00:08
#              35       0.209112       0.213278          00:08
# Better model found at epoch 36 with valid_loss value: 0.21169411209938474.
#              36       0.206556       0.211694          00:08
#              37       0.204084       0.214982          00:08
#              38       0.202206       0.214058          00:08
# Better model found at epoch 39 with valid_loss value: 0.21004340417403894.
#              39       0.200623       0.210043          00:08
#              40       0.199424       0.215314          00:08
#              41       0.196915       0.213350          00:08
#              42       0.195734       0.210479          00:08
#              43       0.194781       0.219088          00:08
#              44       0.193200       0.214185          00:08
# Better model found at epoch 45 with valid_loss value: 0.207954425146021.
#              45       0.192373       0.207954          00:08
#              46       0.191483       0.214427          00:08
#              47       0.190464       0.216067          00:08
#              48       0.189298       0.213953          00:08
#              49       0.188957       0.216283          00:08
#              50       0.187945       0.219918          00:08
# No improvement since epoch 45: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.933540591308991.
#               0       0.966707       0.933541          00:08
# Better model found at epoch 1 with valid_loss value: 0.9263597977268104.
#               1       0.936178       0.926360          00:08
# Better model found at epoch 2 with valid_loss value: 0.9245469989574857.
#               2       0.930719       0.924547          00:08
# Better model found at epoch 3 with valid_loss value: 0.9228465565246136.
#               3       0.927739       0.922847          00:08
# Better model found at epoch 4 with valid_loss value: 0.9219682859540277.
#               4       0.924646       0.921968          00:08
# Better model found at epoch 5 with valid_loss value: 0.9207093228742881.
#               5       0.922849       0.920709          00:08
#               6       0.921938       0.921947          00:08
#               7       0.921031       0.921035          00:08
# Better model found at epoch 8 with valid_loss value: 0.9182954892188772.
#               8       0.919906       0.918295          00:08
#               9       0.919170       0.920154          00:08
# Better model found at epoch 10 with valid_loss value: 0.9174730789768104.
#              10       0.918851       0.917473          00:08
# Better model found at epoch 11 with valid_loss value: 0.6755651189991864.
#              11       0.735240       0.675565          00:08
# Better model found at epoch 12 with valid_loss value: 0.6703213200518714.
#              12       0.692743       0.670321          00:08
# Better model found at epoch 13 with valid_loss value: 0.6682068914005289.
#              13       0.686308       0.668207          00:08
# Better model found at epoch 14 with valid_loss value: 0.57451688364524.
#              14       0.657306       0.574517          00:08
# Better model found at epoch 15 with valid_loss value: 0.418001368299939.
#              15       0.508247       0.418001          00:08
# Better model found at epoch 16 with valid_loss value: 0.37768062035954025.
#              16       0.439492       0.377681          00:08
# Better model found at epoch 17 with valid_loss value: 0.3681517462113507.
#              17       0.405854       0.368152          00:08
# Better model found at epoch 18 with valid_loss value: 0.354539982645952.
#              18       0.386420       0.354540          00:08
# Better model found at epoch 19 with valid_loss value: 0.3389932506738202.
#              19       0.369794       0.338993          00:08
# Better model found at epoch 20 with valid_loss value: 0.26496669437169446.
#              20       0.339152       0.264967          00:08
# Better model found at epoch 21 with valid_loss value: 0.23885129551464607.
#              21       0.283418       0.238851          00:08
# Better model found at epoch 22 with valid_loss value: 0.2314452529050549.
#              22       0.256028       0.231445          00:08
# Better model found at epoch 23 with valid_loss value: 0.22623949539768104.
#              23       0.242412       0.226239          00:08
# Better model found at epoch 24 with valid_loss value: 0.22160900789513832.
#              24       0.232185       0.221609          00:08
# Better model found at epoch 25 with valid_loss value: 0.21880556235379373.
#              25       0.223936       0.218806          00:08
# Better model found at epoch 26 with valid_loss value: 0.2186688714147681.
#              26       0.216986       0.218669          00:08
#              27       0.211547       0.221119          00:08
#              28       0.207325       0.220191          00:08
#              29       0.203120       0.221806          00:08
#              30       0.199746       0.222904          00:08
# Better model found at epoch 31 with valid_loss value: 0.21640698500432262.
#              31       0.197584       0.216407          00:08
#              32       0.194689       0.217788          00:08
#              33       0.193003       0.225599          00:08
#              34       0.191323       0.221185          00:08
#              35       0.188823       0.225030          00:08
#              36       0.187134       0.229432          00:08
# No improvement since epoch 31: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9333407249557467.
#               0       0.966395       0.933341          00:08
# Better model found at epoch 1 with valid_loss value: 0.927711380032521.
#               1       0.937060       0.927711          00:08
# Better model found at epoch 2 with valid_loss value: 0.9236066175335501.
#               2       0.929619       0.923607          00:08
# Better model found at epoch 3 with valid_loss value: 0.9233441050551622.
#               3       0.927179       0.923344          00:08
# Better model found at epoch 4 with valid_loss value: 0.9225708791731846.
#               4       0.923747       0.922571          00:08
# Better model found at epoch 5 with valid_loss value: 0.9206768496315659.
#               5       0.922123       0.920677          00:08
#               6       0.921413       0.921527          00:08
#               7       0.920783       0.921147          00:08
# Better model found at epoch 8 with valid_loss value: 0.9196178750977688.
#               8       0.920523       0.919618          00:08
#               9       0.918196       0.921146          00:08
#              10       0.919094       0.920407          00:08
# Better model found at epoch 11 with valid_loss value: 0.6805075198367775.
#              11       0.770441       0.680508          00:08
# Better model found at epoch 12 with valid_loss value: 0.6678811118372303.
#              12       0.693445       0.667881          00:08
# Better model found at epoch 13 with valid_loss value: 0.6642529723005516.
#              13       0.686100       0.664253          00:08
# Better model found at epoch 14 with valid_loss value: 0.5667555564203236.
#              14       0.630532       0.566756          00:08
# Better model found at epoch 15 with valid_loss value: 0.4115449128699778.
#              15       0.514675       0.411545          00:08
# Better model found at epoch 16 with valid_loss value: 0.3749812663376832.
#              16       0.433350       0.374981          00:08
# Better model found at epoch 17 with valid_loss value: 0.3652644453420879.
#              17       0.401685       0.365264          00:08
# Better model found at epoch 18 with valid_loss value: 0.35915361313652644.
#              18       0.382956       0.359154          00:08
# Better model found at epoch 19 with valid_loss value: 0.35348961495811376.
#              19       0.371716       0.353490          00:08
# Better model found at epoch 20 with valid_loss value: 0.34291040228007164.
#              20       0.359702       0.342910          00:08
# Better model found at epoch 21 with valid_loss value: 0.2559818071214289.
#              21       0.335232       0.255982          00:08
# Better model found at epoch 22 with valid_loss value: 0.23971990280364935.
#              22       0.269656       0.239720          00:08
# Better model found at epoch 23 with valid_loss value: 0.23179837771308456.
#              23       0.248150       0.231798          00:08
# Better model found at epoch 24 with valid_loss value: 0.22338845076954347.
#              24       0.235469       0.223388          00:08
#              25       0.225773       0.226531          00:09
#              26       0.218583       0.223976          00:09
#              27       0.213918       0.225730          00:08
#              28       0.209466       0.223746          00:08
#              29       0.206708       0.224007          00:08
# No improvement since epoch 24: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00014174741629268049
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9418090015280682.
#               0       0.986598       0.941809          00:08
# Better model found at epoch 1 with valid_loss value: 0.9325986521332637.
#               1       0.947037       0.932599          00:08
# Better model found at epoch 2 with valid_loss value: 0.9295890897689802.
#               2       0.938017       0.929589          00:08
# Better model found at epoch 3 with valid_loss value: 0.9266489564902686.
#               3       0.931316       0.926649          00:08
# Better model found at epoch 4 with valid_loss value: 0.9258063041609699.
#               4       0.927864       0.925806          00:08
# Better model found at epoch 5 with valid_loss value: 0.9251591371189882.
#               5       0.925029       0.925159          00:08
# Better model found at epoch 6 with valid_loss value: 0.923563603325559.
#               6       0.922852       0.923564          00:08
# Better model found at epoch 7 with valid_loss value: 0.9230553729944105.
#               7       0.921638       0.923055          00:08
# Better model found at epoch 8 with valid_loss value: 0.9215929639747868.
#               8       0.920059       0.921593          00:08
#               9       0.918976       0.923208          00:08
#              10       0.918561       0.921965          00:08
#              11       0.918071       0.922445          00:08
# Better model found at epoch 12 with valid_loss value: 0.9198185167685379.
#              12       0.917054       0.919819          00:08
#              13       0.917218       0.921970          00:08
#              14       0.915976       0.922718          00:08
# Better model found at epoch 15 with valid_loss value: 0.6635426457947965.
#              15       0.772142       0.663543          00:08
# Better model found at epoch 16 with valid_loss value: 0.6505851285411975.
#              16       0.659063       0.650585          00:08
# Better model found at epoch 17 with valid_loss value: 0.6474159342578816.
#              17       0.650682       0.647416          00:08
# Better model found at epoch 18 with valid_loss value: 0.6441856360960874.
#              18       0.646404       0.644186          00:08
# Better model found at epoch 19 with valid_loss value: 0.643249560806056.
#              19       0.644019       0.643250          00:08
#              20       0.641926       0.643656          00:08
# Better model found at epoch 21 with valid_loss value: 0.6191345774439038.
#              21       0.638654       0.619135          00:08
# Better model found at epoch 22 with valid_loss value: 0.53599956991666.
#              22       0.579673       0.536000          00:08
# Better model found at epoch 23 with valid_loss value: 0.46497491128156665.
#              23       0.513674       0.464975          00:08
# Better model found at epoch 24 with valid_loss value: 0.39982113371099404.
#              24       0.441645       0.399821          00:08
# Better model found at epoch 25 with valid_loss value: 0.3862658508801472.
#              25       0.407915       0.386266          00:08
# Better model found at epoch 26 with valid_loss value: 0.3817468342221932.
#              26       0.393652       0.381747          00:08
# Better model found at epoch 27 with valid_loss value: 0.38080003826453673.
#              27       0.383870       0.380800          00:08
# Better model found at epoch 28 with valid_loss value: 0.37325060695472095.
#              28       0.375622       0.373251          00:08
# Better model found at epoch 29 with valid_loss value: 0.3677591118606241.
#              29       0.369082       0.367759          00:08
# Better model found at epoch 30 with valid_loss value: 0.3643979665760214.
#              30       0.364073       0.364398          00:08
# Better model found at epoch 31 with valid_loss value: 0.3584218815973339.
#              31       0.358711       0.358422          00:08
# Better model found at epoch 32 with valid_loss value: 0.30604003199392793.
#              32       0.347062       0.306040          00:08
# Better model found at epoch 33 with valid_loss value: 0.2782895838464593.
#              33       0.297156       0.278290          00:08
# Better model found at epoch 34 with valid_loss value: 0.26884524508153046.
#              34       0.277791       0.268845          00:08
# Better model found at epoch 35 with valid_loss value: 0.2608733095117219.
#              35       0.264711       0.260873          00:08
# Better model found at epoch 36 with valid_loss value: 0.2548718758482286.
#              36       0.255884       0.254872          00:08
# Better model found at epoch 37 with valid_loss value: 0.25259347872391225.
#              37       0.250465       0.252593          00:08
# Better model found at epoch 38 with valid_loss value: 0.25096939575332755.
#              38       0.245513       0.250969          00:08
# Better model found at epoch 39 with valid_loss value: 0.25081510453318523.
#              39       0.241911       0.250815          00:08
# Better model found at epoch 40 with valid_loss value: 0.2476551582983151.
#              40       0.239334       0.247655          00:08
# Better model found at epoch 41 with valid_loss value: 0.2452370194313475.
#              41       0.236686       0.245237          00:08
#              42       0.234261       0.246084          00:08
# Better model found at epoch 43 with valid_loss value: 0.24334961251658757.
#              43       0.232656       0.243350          00:08
# Better model found at epoch 44 with valid_loss value: 0.2431012307483513.
#              44       0.230109       0.243101          00:08
# Better model found at epoch 45 with valid_loss value: 0.24252533847464613.
#              45       0.229181       0.242525          00:08
# Better model found at epoch 46 with valid_loss value: 0.24104885121566874.
#              46       0.227292       0.241049          00:08
#              47       0.226825       0.243284          00:08
# Better model found at epoch 48 with valid_loss value: 0.24020256642572785.
#              48       0.225569       0.240203          00:08
#              49       0.224169       0.242656          00:08
#              50       0.223418       0.241876          00:08
#              51       0.222476       0.242538          00:08
#              52       0.221174       0.242259          00:08
#              53       0.220594       0.240560          00:08
# No improvement since epoch 48: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9386312709774207.
#               0       0.980117       0.938631          00:08
# Better model found at epoch 1 with valid_loss value: 0.9332315716537836.
#               1       0.944281       0.933232          00:08
# Better model found at epoch 2 with valid_loss value: 0.9274921016832791.
#               2       0.934723       0.927492          00:08
# Better model found at epoch 3 with valid_loss value: 0.9268494297955655.
#               3       0.930236       0.926849          00:08
# Better model found at epoch 4 with valid_loss value: 0.9254806530970301.
#               4       0.926633       0.925481          00:08
# Better model found at epoch 5 with valid_loss value: 0.9221956208045159.
#               5       0.923882       0.922196          00:08
#               6       0.921675       0.922240          00:08
#               7       0.919944       0.922240          00:08
# Better model found at epoch 8 with valid_loss value: 0.9220614924481285.
#               8       0.920046       0.922061          00:08
# Better model found at epoch 9 with valid_loss value: 0.9214548159072417.
#               9       0.919155       0.921455          00:08
# Better model found at epoch 10 with valid_loss value: 0.921432249288039.
#              10       0.917934       0.921432          00:08
# Better model found at epoch 11 with valid_loss value: 0.9204958935109845.
#              11       0.918592       0.920496          00:08
#              12       0.917415       0.922445          00:08
# Better model found at epoch 13 with valid_loss value: 0.797397449018511.
#              13       0.912783       0.797397          00:08
# Better model found at epoch 14 with valid_loss value: 0.6602472316161514.
#              14       0.681011       0.660247          00:08
# Better model found at epoch 15 with valid_loss value: 0.6521079923972742.
#              15       0.658299       0.652108          00:08
# Better model found at epoch 16 with valid_loss value: 0.648049973937144.
#              16       0.649769       0.648050          00:08
# Better model found at epoch 17 with valid_loss value: 0.6451719751195077.
#              17       0.646091       0.645172          00:08
#              18       0.643521       0.645607          00:08
# Better model found at epoch 19 with valid_loss value: 0.643551588562856.
#              19       0.641359       0.643552          00:08
#              20       0.639846       0.645097          00:08
# Better model found at epoch 21 with valid_loss value: 0.6406132796608015.
#              21       0.638299       0.640613          00:08
# Better model found at epoch 22 with valid_loss value: 0.5269964306600895.
#              22       0.581725       0.526996          00:08
# Better model found at epoch 23 with valid_loss value: 0.42148242823179416.
#              23       0.485466       0.421482          00:08
# Better model found at epoch 24 with valid_loss value: 0.3884710400350895.
#              24       0.411934       0.388471          00:08
# Better model found at epoch 25 with valid_loss value: 0.381425805087978.
#              25       0.388195       0.381426          00:08
# Better model found at epoch 26 with valid_loss value: 0.37884685370473964.
#              26       0.377500       0.378847          00:08
# Better model found at epoch 27 with valid_loss value: 0.37183705788496746.
#              27       0.370215       0.371837          00:09
# Better model found at epoch 28 with valid_loss value: 0.36252018282139953.
#              28       0.363652       0.362520          00:09
# Better model found at epoch 29 with valid_loss value: 0.2813330356234744.
#              29       0.316015       0.281333          00:08
# Better model found at epoch 30 with valid_loss value: 0.2737271314330757.
#              30       0.280368       0.273727          00:08
# Better model found at epoch 31 with valid_loss value: 0.2668609594309398.
#              31       0.270090       0.266861          00:08
# Better model found at epoch 32 with valid_loss value: 0.2615009106107608.
#              32       0.262950       0.261501          00:08
# Better model found at epoch 33 with valid_loss value: 0.2589020743808482.
#              33       0.256585       0.258902          00:08
# Better model found at epoch 34 with valid_loss value: 0.2551734371821603.
#              34       0.251746       0.255173          00:08
# Better model found at epoch 35 with valid_loss value: 0.2493922706150834.
#              35       0.246299       0.249392          00:08
# Better model found at epoch 36 with valid_loss value: 0.24665493573281122.
#              36       0.240937       0.246655          00:08
# Better model found at epoch 37 with valid_loss value: 0.2396830621630899.
#              37       0.236989       0.239683          00:08
#              38       0.232998       0.239998          00:08
# Better model found at epoch 39 with valid_loss value: 0.23936474569645036.
#              39       0.229594       0.239365          00:08
# Better model found at epoch 40 with valid_loss value: 0.23906818138476404.
#              40       0.227436       0.239068          00:08
#              41       0.225795       0.239499          00:08
# Better model found at epoch 42 with valid_loss value: 0.23868198627568143.
#              42       0.224491       0.238682          00:08
#              43       0.222216       0.239564          00:08
# Better model found at epoch 44 with valid_loss value: 0.23570563593368593.
#              44       0.221845       0.235706          00:08
#              45       0.220369       0.237715          00:08
#              46       0.219178       0.238359          00:08
#              47       0.218521       0.239560          00:08
#              48       0.217718       0.237817          00:08
#              49       0.216099       0.238995          00:08
# No improvement since epoch 44: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00043287612810830566
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9307285448913223.
#               0       0.957239       0.930729          00:08
# Better model found at epoch 1 with valid_loss value: 0.9278633397826445.
#               1       0.931492       0.927863          00:08
# Better model found at epoch 2 with valid_loss value: 0.9254755616561008.
#               2       0.925912       0.925476          00:08
# Better model found at epoch 3 with valid_loss value: 0.9244126474250782.
#               3       0.922448       0.924413          00:08
# Better model found at epoch 4 with valid_loss value: 0.9241134716418986.
#               4       0.920188       0.924113          00:08
# Better model found at epoch 5 with valid_loss value: 0.9213398443932159.
#               5       0.918964       0.921340          00:08
#               6       0.918328       0.923229          00:08
#               7       0.917997       0.922969          00:08
# Better model found at epoch 8 with valid_loss value: 0.9209383972861436.
#               8       0.916911       0.920938          00:08
# Better model found at epoch 9 with valid_loss value: 0.663007746570373.
#               9       0.795836       0.663008          00:08
# Better model found at epoch 10 with valid_loss value: 0.6473627666773012.
#              10       0.657196       0.647363          00:08
# Better model found at epoch 11 with valid_loss value: 0.6460490786575828.
#              11       0.648628       0.646049          00:08
#              12       0.643280       0.646168          00:08
# Better model found at epoch 13 with valid_loss value: 0.6437669889392599.
#              13       0.640847       0.643767          00:08
# Better model found at epoch 14 with valid_loss value: 0.5671317573043595.
#              14       0.612569       0.567132          00:08
# Better model found at epoch 15 with valid_loss value: 0.40965172754919316.
#              15       0.473542       0.409652          00:08
# Better model found at epoch 16 with valid_loss value: 0.38173165612650256.
#              16       0.397894       0.381732          00:08
# Better model found at epoch 17 with valid_loss value: 0.3696496499619216.
#              17       0.379706       0.369650          00:08
# Better model found at epoch 18 with valid_loss value: 0.281163869374434.
#              18       0.325089       0.281164          00:08
# Better model found at epoch 19 with valid_loss value: 0.26945088821679974.
#              19       0.282077       0.269451          00:08
# Better model found at epoch 20 with valid_loss value: 0.2643197742891178.
#              20       0.267880       0.264320          00:08
# Better model found at epoch 21 with valid_loss value: 0.25719151527509054.
#              21       0.258172       0.257192          00:08
# Better model found at epoch 22 with valid_loss value: 0.24871766875411658.
#              22       0.249914       0.248718          00:08
#              23       0.243113       0.250030          00:08
# Better model found at epoch 24 with valid_loss value: 0.2425473189797567.
#              24       0.237525       0.242547          00:08
# Better model found at epoch 25 with valid_loss value: 0.23686547156085336.
#              25       0.229206       0.236865          00:08
# Better model found at epoch 26 with valid_loss value: 0.23360846758320641.
#              26       0.225082       0.233608          00:08
#              27       0.221670       0.235186          00:08
#              28       0.219634       0.238623          00:08
# Better model found at epoch 29 with valid_loss value: 0.22996473006159435.
#              29       0.217902       0.229965          00:08
#              30       0.215873       0.238791          00:08
#              31       0.214399       0.237720          00:08
#              32       0.212660       0.238914          00:08
#              33       0.211395       0.240805          00:08
#              34       0.211054       0.236347          00:08
# No improvement since epoch 29: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(dset_pretrain='ES', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9130761985784944.
#               0       0.958672       0.913076          00:05
# Better model found at epoch 1 with valid_loss value: 0.903384872124819.
#               1       0.912150       0.903385          00:05
# Better model found at epoch 2 with valid_loss value: 0.8972793537377353.
#               2       0.899133       0.897279          00:05
# Better model found at epoch 3 with valid_loss value: 0.8951920044082757.
#               3       0.891961       0.895192          00:05
# Better model found at epoch 4 with valid_loss value: 0.8919612742781888.
#               4       0.886743       0.891961          00:05
# Better model found at epoch 5 with valid_loss value: 0.8891903154907914.
#               5       0.883655       0.889190          00:05
# Better model found at epoch 6 with valid_loss value: 0.8888865239715699.
#               6       0.881110       0.888887          00:05
# Better model found at epoch 7 with valid_loss value: 0.8886845198900193.
#               7       0.879805       0.888685          00:05
# Better model found at epoch 8 with valid_loss value: 0.8870390348540292.
#               8       0.878741       0.887039          00:05
#               9       0.877439       0.887878          00:05
#              10       0.876741       0.888108          00:05
# Better model found at epoch 11 with valid_loss value: 0.8867499302567556.
#              11       0.876480       0.886750          00:05
# Better model found at epoch 12 with valid_loss value: 0.4705571589869511.
#              12       0.755085       0.470557          00:05
# Better model found at epoch 13 with valid_loss value: 0.4542854631831068.
#              13       0.507102       0.454285          00:05
# Better model found at epoch 14 with valid_loss value: 0.445981069107387.
#              14       0.491823       0.445981          00:05
# Better model found at epoch 15 with valid_loss value: 0.44460100895226795.
#              15       0.483675       0.444601          00:05
# Better model found at epoch 16 with valid_loss value: 0.441205934521775.
#              16       0.480161       0.441206          00:05
#              17       0.477206       0.441809          00:05
# Better model found at epoch 18 with valid_loss value: 0.44016057125371966.
#              18       0.474837       0.440161          00:05
#              19       0.473658       0.441174          00:05
#              20       0.472111       0.440460          00:05
# Better model found at epoch 21 with valid_loss value: 0.438378191538825.
#              21       0.470360       0.438378          00:05
# Better model found at epoch 22 with valid_loss value: 0.4369843869380328.
#              22       0.469680       0.436984          00:05
# Better model found at epoch 23 with valid_loss value: 0.4367686384108091.
#              23       0.469179       0.436769          00:05
# Better model found at epoch 24 with valid_loss value: 0.40062761851324996.
#              24       0.459294       0.400628          00:05
# Better model found at epoch 25 with valid_loss value: 0.35491987537950376.
#              25       0.420488       0.354920          00:05
# Better model found at epoch 26 with valid_loss value: 0.2828272340457616.
#              26       0.385081       0.282827          00:05
# Better model found at epoch 27 with valid_loss value: 0.22904101625331752.
#              27       0.324367       0.229041          00:05
# Better model found at epoch 28 with valid_loss value: 0.20725944706801913.
#              28       0.285569       0.207259          00:05
# Better model found at epoch 29 with valid_loss value: 0.19589683529033297.
#              29       0.266219       0.195897          00:05
# Better model found at epoch 30 with valid_loss value: 0.18564055321472375.
#              30       0.251647       0.185641          00:05
# Better model found at epoch 31 with valid_loss value: 0.1806554427690707.
#              31       0.240516       0.180655          00:05
# Better model found at epoch 32 with valid_loss value: 0.17690902103732709.
#              32       0.232127       0.176909          00:05
# Better model found at epoch 33 with valid_loss value: 0.1722213207611187.
#              33       0.223989       0.172221          00:05
# Better model found at epoch 34 with valid_loss value: 0.16680575391190486.
#              34       0.217777       0.166806          00:05
# Better model found at epoch 35 with valid_loss value: 0.15206053587944346.
#              35       0.209670       0.152061          00:05
# Better model found at epoch 36 with valid_loss value: 0.14086233712439178.
#              36       0.197148       0.140862          00:05
# Better model found at epoch 37 with valid_loss value: 0.133576622457199.
#              37       0.186091       0.133577          00:05
# Better model found at epoch 38 with valid_loss value: 0.13053144234369973.
#              38       0.178163       0.130531          00:05
# Better model found at epoch 39 with valid_loss value: 0.12693021104557062.
#              39       0.170964       0.126930          00:05
# Better model found at epoch 40 with valid_loss value: 0.12119367212004384.
#              40       0.165932       0.121194          00:05
# Better model found at epoch 41 with valid_loss value: 0.11852702385784442.
#              41       0.161112       0.118527          00:05
# Better model found at epoch 42 with valid_loss value: 0.1151197463230859.
#              42       0.157264       0.115120          00:05
# Better model found at epoch 43 with valid_loss value: 0.11376115695560057.
#              43       0.154265       0.113761          00:05
# Better model found at epoch 44 with valid_loss value: 0.11264615843528832.
#              44       0.150688       0.112646          00:05
# Better model found at epoch 45 with valid_loss value: 0.11139808422847636.
#              45       0.148596       0.111398          00:05
# Better model found at epoch 46 with valid_loss value: 0.10878239840734076.
#              46       0.147056       0.108782          00:05
#              47       0.144656       0.110444          00:05
# Better model found at epoch 48 with valid_loss value: 0.1078673815715729.
#              48       0.142809       0.107867          00:05
#              49       0.141242       0.108746          00:05
# Better model found at epoch 50 with valid_loss value: 0.1068436363530692.
#              50       0.139966       0.106844          00:05
#              51       0.137911       0.108057          00:05
#              52       0.137051       0.110105          00:05
#              53       0.135439       0.107802          00:05
# Better model found at epoch 54 with valid_loss value: 0.10639493910660788.
#              54       0.134674       0.106395          00:05
# Better model found at epoch 55 with valid_loss value: 0.10567178491497607.
#              55       0.133680       0.105672          00:05
# Better model found at epoch 56 with valid_loss value: 0.10491908998260817.
#              56       0.132703       0.104919          00:05
#              57       0.131464       0.106018          00:05
#              58       0.130879       0.106875          00:05
#              59       0.129625       0.106572          00:05
# Better model found at epoch 60 with valid_loss value: 0.1041057035051321.
#              60       0.128822       0.104106          00:05
#              61       0.128592       0.104647          00:05
#              62       0.127910       0.105501          00:05
#              63       0.127036       0.106395          00:05
#              64       0.126555       0.105279          00:05
#              65       0.126472       0.108407          00:05
# No improvement since epoch 60: early stopping
# pretraining completed
# Model saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(dset_pretrain='ES', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.907619968597437.
#               0       0.939835       0.907620          00:05
# Better model found at epoch 1 with valid_loss value: 0.898755657546786.
#               1       0.900553       0.898756          00:05
# Better model found at epoch 2 with valid_loss value: 0.8926335880288853.
#               2       0.889296       0.892634          00:05
# Better model found at epoch 3 with valid_loss value: 0.8893215393612693.
#               3       0.885763       0.889322          00:05
# Better model found at epoch 4 with valid_loss value: 0.8890647248779495.
#               4       0.882730       0.889065          00:05
#               5       0.880101       0.889851          00:05
#               6       0.878348       0.889647          00:05
# Better model found at epoch 7 with valid_loss value: 0.8861470358268918.
#               7       0.876777       0.886147          00:05
#               8       0.876091       0.886663          00:05
# Better model found at epoch 9 with valid_loss value: 0.5561424112591538.
#               9       0.866305       0.556142          00:05
# Better model found at epoch 10 with valid_loss value: 0.45728162822925145.
#              10       0.517264       0.457282          00:05
# Better model found at epoch 11 with valid_loss value: 0.44359203366558175.
#              11       0.491577       0.443592          00:05
#              12       0.482915       0.444088          00:05
# Better model found at epoch 13 with valid_loss value: 0.4406590485786208.
#              13       0.478205       0.440659          00:05
#              14       0.474855       0.440967          00:05
#              15       0.472594       0.441691          00:05
# Better model found at epoch 16 with valid_loss value: 0.4393163347360659.
#              16       0.472147       0.439316          00:05
#              17       0.469531       0.440451          00:05
# Better model found at epoch 18 with valid_loss value: 0.43035039443907647.
#              18       0.468145       0.430350          00:05
# Better model found at epoch 19 with valid_loss value: 0.3524600793327909.
#              19       0.426579       0.352460          00:05
# Better model found at epoch 20 with valid_loss value: 0.2415254398901546.
#              20       0.365257       0.241525          00:05
# Better model found at epoch 21 with valid_loss value: 0.21056689890154598.
#              21       0.282709       0.210567          00:05
# Better model found at epoch 22 with valid_loss value: 0.1982043645748576.
#              22       0.255747       0.198204          00:05
# Better model found at epoch 23 with valid_loss value: 0.1835481002720708.
#              23       0.236904       0.183548          00:05
# Better model found at epoch 24 with valid_loss value: 0.15847508653186027.
#              24       0.221412       0.158475          00:05
# Better model found at epoch 25 with valid_loss value: 0.13468027510615846.
#              25       0.192572       0.134680          00:05
# Better model found at epoch 26 with valid_loss value: 0.12897402931753457.
# ...
#              27       0.208088       0.165968          00:05
# Better model found at epoch 28 with valid_loss value: 0.15536411157159805.
#              28       0.188424       0.155364          00:05
# Better model found at epoch 29 with valid_loss value: 0.150913826959471.
#              29       0.175979       0.150914          00:05
# Better model found at epoch 30 with valid_loss value: 0.147017639857196.
#              30       0.167391       0.147018          00:05
# Better model found at epoch 31 with valid_loss value: 0.14054397649275677.
#              31       0.160806       0.140544          00:05
# Better model found at epoch 32 with valid_loss value: 0.14002724424021332.
#              32       0.155687       0.140027          00:05
# Better model found at epoch 33 with valid_loss value: 0.13513015715163565.
#              33       0.151411       0.135130          00:05
# Better model found at epoch 34 with valid_loss value: 0.13487767168461978.
#              34       0.147775       0.134878          00:05
# Better model found at epoch 35 with valid_loss value: 0.1310547424777827.
#              35       0.144891       0.131055          00:05
#              36       0.142575       0.132313          00:05
# Better model found at epoch 37 with valid_loss value: 0.1301098707425205.
#              37       0.140260       0.130110          00:05
# Better model found at epoch 38 with valid_loss value: 0.12832910109126186.
#              38       0.138500       0.128329          00:05
# Better model found at epoch 39 with valid_loss value: 0.1275269163370094.
#              39       0.136778       0.127527          00:05
#              40       0.134497       0.128446          00:05
# Better model found at epoch 41 with valid_loss value: 0.12684320870445956.
#              41       0.133052       0.126843          00:05
#              42       0.132410       0.128281          00:05
#              43       0.131035       0.127017          00:05
#              44       0.130178       0.127686          00:05
#              45       0.128823       0.126993          00:05
#              46       0.128468       0.128969          00:05
# No improvement since epoch 41: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(dset_pretrain='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.8967356272884459.
#               0       0.938521       0.896736          00:05
# Better model found at epoch 1 with valid_loss value: 0.8881698471826688.
#               1       0.896467       0.888170          00:05
# Better model found at epoch 2 with valid_loss value: 0.8823258079485354.
#               2       0.885393       0.882326          00:05
# Better model found at epoch 3 with valid_loss value: 0.8821932687906835.
#               3       0.878312       0.882193          00:05
# Better model found at epoch 4 with valid_loss value: 0.8765498658716436.
#               4       0.876024       0.876550          00:05
#               5       0.872625       0.877340          00:05
# Better model found at epoch 6 with valid_loss value: 0.8757813294599268.
#               6       0.871166       0.875781          00:05
#               7       0.869507       0.877671          00:05
# Better model found at epoch 8 with valid_loss value: 0.873351206519528.
#               8       0.867975       0.873351          00:05
#               9       0.867239       0.875410          00:05
#              10       0.867303       0.873736          00:05
# Better model found at epoch 11 with valid_loss value: 0.495188105484642.
#              11       0.608950       0.495188          00:05
# Better model found at epoch 12 with valid_loss value: 0.4847974089707079.
#              12       0.503978       0.484797          00:05
# Better model found at epoch 13 with valid_loss value: 0.4774695747940399.
#              13       0.495159       0.477470          00:05
# Better model found at epoch 14 with valid_loss value: 0.4762754510145443.
#              14       0.490194       0.476275          00:05
#              15       0.486599       0.476790          00:05
# Better model found at epoch 16 with valid_loss value: 0.4751617804109032.
#              16       0.484648       0.475162          00:05
# Better model found at epoch 17 with valid_loss value: 0.47410210282750204.
#              17       0.482739       0.474102          00:05
# Better model found at epoch 18 with valid_loss value: 0.4726005883212978.
#              18       0.481069       0.472601          00:05
# Better model found at epoch 19 with valid_loss value: 0.4454305774511798.
#              19       0.473361       0.445431          00:05
# Better model found at epoch 20 with valid_loss value: 0.318727651895596.
#              20       0.419336       0.318728          00:05
# Better model found at epoch 21 with valid_loss value: 0.2427597703925956.
#              21       0.313724       0.242760          00:05
# Better model found at epoch 22 with valid_loss value: 0.22882416789564686.
#              22       0.260966       0.228824          00:05
# Better model found at epoch 23 with valid_loss value: 0.21324038773265866.
#              23       0.242250       0.213240          00:05
# Better model found at epoch 24 with valid_loss value: 0.180197354620118.
#              24       0.222249       0.180197          00:05
# Better model found at epoch 25 with valid_loss value: 0.1609063417762154.
#              25       0.196233       0.160906          00:05
# Better model found at epoch 26 with valid_loss value: 0.15310471785369204.
#              26       0.180621       0.153105          00:05
# Better model found at epoch 27 with valid_loss value: 0.148449061419345.
#              27       0.170199       0.148449          00:05
# Better model found at epoch 28 with valid_loss value: 0.14366076650223758.
#              28       0.162535       0.143661          00:05
# Better model found at epoch 29 with valid_loss value: 0.1396192061794396.
#              29       0.156692       0.139619          00:05
# Better model found at epoch 30 with valid_loss value: 0.13863732979683685.
#              30       0.151614       0.138637          00:05
# Better model found at epoch 31 with valid_loss value: 0.1341101203341131.
#              31       0.148787       0.134110          00:05
# Better model found at epoch 32 with valid_loss value: 0.13148661179693857.
#              32       0.145196       0.131487          00:05
#              33       0.143299       0.133147          00:05
#              34       0.140370       0.132577          00:05
# Better model found at epoch 35 with valid_loss value: 0.13096277222970912.
#              35       0.138300       0.130963          00:05
# Better model found at epoch 36 with valid_loss value: 0.12906480235137816.
#              36       0.136646       0.129065          00:05
# Better model found at epoch 37 with valid_loss value: 0.12854402199132933.
#              37       0.134263       0.128544          00:05
# Better model found at epoch 38 with valid_loss value: 0.1268503733821959.
#              38       0.132729       0.126850          00:05
#              39       0.131227       0.128180          00:05
#              40       0.129391       0.126982          00:05
# Better model found at epoch 41 with valid_loss value: 0.1263340030480828.
#              41       0.128036       0.126334          00:05
#              42       0.127176       0.129643          00:05
#              43       0.126021       0.128046          00:05
# Better model found at epoch 44 with valid_loss value: 0.12491932830934703.
#              44       0.124882       0.124919          00:05
#              45       0.123773       0.129891          00:05
#              46       0.122938       0.125227          00:05
#              47       0.122092       0.128650          00:05
#              48       0.120755       0.129128          00:05
#              49       0.119283       0.132512          00:05
# No improvement since epoch 44: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(dset_pretrain='IT', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00020565123083486514
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.8988440124320765.
#               0       0.946153       0.898844          00:05
# Better model found at epoch 1 with valid_loss value: 0.8899767188014572.
#               1       0.899741       0.889977          00:05
# Better model found at epoch 2 with valid_loss value: 0.884771896354767.
#               2       0.887960       0.884772          00:05
# Better model found at epoch 3 with valid_loss value: 0.8807809026634283.
#               3       0.881491       0.880781          00:05
# Better model found at epoch 4 with valid_loss value: 0.8785635767433723.
#               4       0.877495       0.878564          00:05
#               5       0.874726       0.879342          00:05
# Better model found at epoch 6 with valid_loss value: 0.8769389742507822.
#               6       0.872342       0.876939          00:05
#               7       0.869537       0.877464          00:05
# Better model found at epoch 8 with valid_loss value: 0.8757279595648774.
#               8       0.869231       0.875728          00:05
#               9       0.868063       0.876539          00:05
#              10       0.867917       0.878409          00:05
#              11       0.867529       0.876601          00:05
# Better model found at epoch 12 with valid_loss value: 0.49274661539807346.
#              12       0.632630       0.492747          00:05
# Better model found at epoch 13 with valid_loss value: 0.4825507593806603.
#              13       0.506108       0.482551          00:05
# Better model found at epoch 14 with valid_loss value: 0.4790158057436605.
#              14       0.496515       0.479016          00:05
# Better model found at epoch 15 with valid_loss value: 0.4761426006375556.
#              15       0.490874       0.476143          00:05
# Better model found at epoch 16 with valid_loss value: 0.4747092342643669.
#              16       0.487785       0.474709          00:05
#              17       0.485000       0.474743          00:05
#              18       0.483858       0.475622          00:05
# Better model found at epoch 19 with valid_loss value: 0.47203844115346616.
#              19       0.482643       0.472038          00:05
# Better model found at epoch 20 with valid_loss value: 0.4707703812597769.
#              20       0.480672       0.470770          00:05
# Better model found at epoch 21 with valid_loss value: 0.43989481330016056.
#              21       0.469181       0.439895          00:05
# Better model found at epoch 22 with valid_loss value: 0.34923305351298783.
#              22       0.427607       0.349233          00:05
# Better model found at epoch 23 with valid_loss value: 0.27176334978465133.
#              23       0.336069       0.271763          00:05
# Better model found at epoch 24 with valid_loss value: 0.22286521475691587.
#              24       0.270485       0.222865          00:05
# Better model found at epoch 25 with valid_loss value: 0.19862946375735838.
#              25       0.239168       0.198629          00:05
# Better model found at epoch 26 with valid_loss value: 0.16507765545241232.
#              26       0.211042       0.165078          00:05
# Better model found at epoch 27 with valid_loss value: 0.15621884423112548.
#              27       0.189828       0.156219          00:05
# Better model found at epoch 28 with valid_loss value: 0.15073511735152004.
#              28       0.177789       0.150735          00:05
# Better model found at epoch 29 with valid_loss value: 0.1459540736630115.
#              29       0.168502       0.145954          00:05
# Better model found at epoch 30 with valid_loss value: 0.1414454218466985.
#              30       0.160971       0.141445          00:05
# Better model found at epoch 31 with valid_loss value: 0.13533021778324655.
#              31       0.156062       0.135330          00:05
# Better model found at epoch 32 with valid_loss value: 0.13469628833888214.
#              32       0.151947       0.134696          00:05
# Better model found at epoch 33 with valid_loss value: 0.1331025401077258.
#              33       0.148849       0.133103          00:05
# Better model found at epoch 34 with valid_loss value: 0.13289125374351637.
#              34       0.146346       0.132891          00:05
# Better model found at epoch 35 with valid_loss value: 0.13064201828598407.
#              35       0.143597       0.130642          00:05
# Better model found at epoch 36 with valid_loss value: 0.12889373744121008.
#              36       0.141405       0.128894          00:05
#              37       0.139610       0.130075          00:05
# Better model found at epoch 38 with valid_loss value: 0.12794094377778692.
#              38       0.137775       0.127941          00:05
#              39       0.135853       0.128368          00:05
# Better model found at epoch 40 with valid_loss value: 0.1265160497636825.
#              40       0.134256       0.126516          00:05
#              41       0.133000       0.127663          00:05
# Better model found at epoch 42 with valid_loss value: 0.12483105533071587.
#              42       0.132160       0.124831          00:05
#              43       0.131138       0.126353          00:05
#              44       0.129818       0.126032          00:05
#              45       0.129057       0.129675          00:05
# Better model found at epoch 46 with valid_loss value: 0.12365966877276985.
#              46       0.127876       0.123660          00:05
#              47       0.126850       0.127556          00:05
#              48       0.126241       0.125912          00:05
#              49       0.125591       0.124891          00:05
#              50       0.125030       0.126107          00:05
#              51       0.123829       0.126865          00:05
# No improvement since epoch 46: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv

# %% [markdown]
# # 2. Finetune
#
# Linear probing + full fine-tuning.

# %%
# In case you just want finetune, please uncomment below
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

# List to store metrics for the DataFrame
data = []

for country in countries:
    for pred_len in pred_lens:
        # Define the parameters for each country and pred_len
        params = {
            "--dset": country,
            "--linear_prob_finetune": 1,
            "--pretrained_model": f"saved_models/{country}/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth",
            "--scaler_type": "minmax",
            "--n_epochs_finetune": 10, # parameters from paper. Though, original code did not have this implementation.
            "--n_epochs_linear_probe": 20,
            "--target_points": pred_len  
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        print(f"==========Running command for {country}, pred_len {pred_len}:==========")

        # Run the command and capture the output
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Capture the output in real-time
        output = []
        for line in process.stdout:
            output.append(line)
            print(line, end='')  # Print in the .ipynb cell

        # Wait for the process to complete
        process.stdout.close()
        process.wait()

        try:
            # Extract metrics from the output using the function
            metrics = extract_metrics_from_output(output, if_supervised=False)
            mse, rmse, mae = metrics[0]

            # Append the results to the data list
            data.append({
                'Country': country,
                'Pred_len': pred_len,
                'MSE': mse,
                'RMSE': rmse,
                'MAE': mae
            })
        except ValueError as e:
            print(f"\nError: {e} for {country}, pred_len {pred_len}")
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.1285201488861187.
#               0       0.144507       0.128520          00:03
# Better model found at epoch 1 with valid_loss value: 0.11345786612690004.
#               1       0.123361       0.113458          00:03
# Better model found at epoch 2 with valid_loss value: 0.10223524152839493.
#               2       0.108955       0.102235          00:03
# Better model found at epoch 3 with valid_loss value: 0.09609801274165092.
#               3       0.097760       0.096098          00:03
# Better model found at epoch 4 with valid_loss value: 0.09536232165207295.
#               4       0.090911       0.095362          00:03
#               5       0.087769       0.095542          00:03
# Better model found at epoch 6 with valid_loss value: 0.09431487708224424.
#               6       0.086571       0.094315          00:03
# Better model found at epoch 7 with valid_loss value: 0.09353292611551492.
#               7       0.086227       0.093533          00:03
#               8       0.086024       0.093710          00:03
#               9       0.086038       0.093822          00:03
#              10       0.085715       0.093549          00:03
#              11       0.085549       0.094076          00:03
# Better model found at epoch 12 with valid_loss value: 0.09350893224035407.
#              12       0.085418       0.093509          00:03
#              13       0.085322       0.093652          00:03
# Better model found at epoch 14 with valid_loss value: 0.09310776132353828.
#              14       0.085062       0.093108          00:03
# Better model found at epoch 15 with valid_loss value: 0.09302877984822362.
#              15       0.084954       0.093029          00:03
# Better model found at epoch 16 with valid_loss value: 0.09297852426436586.
#              16       0.084764       0.092979          00:03
# Better model found at epoch 17 with valid_loss value: 0.0928439072364585.
#              17       0.084681       0.092844          00:03
# Better model found at epoch 18 with valid_loss value: 0.09281386580520147.
#              18       0.084585       0.092814          00:03
#              19       0.084491       0.092845          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.084650       0.093103          00:03
#               1       0.085130       0.094817          00:03
#               2       0.085901       0.093914          00:03
#               3       0.086073       0.094645          00:03
#               4       0.085995       0.093491          00:03
#               5       0.085676       0.093655          00:03
#               6       0.085362       0.093264          00:03
#               7       0.085071       0.092968          00:03
#               8       0.084764       0.092919          00:03
# Better model found at epoch 9 with valid_loss value: 0.0928063554473872.
#               9       0.084720       0.092806          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.09117177761078495.
#               0       0.083689       0.091172          00:07
# Better model found at epoch 1 with valid_loss value: 0.0896803285409462.
#               1       0.080779       0.089680          00:07
# Better model found at epoch 2 with valid_loss value: 0.0882835394319507.
#               2       0.078029       0.088284          00:07
# Better model found at epoch 3 with valid_loss value: 0.08794231393319225.
#               3       0.076234       0.087942          00:07
# Better model found at epoch 4 with valid_loss value: 0.08759846717229472.
#               4       0.075096       0.087598          00:07
# Better model found at epoch 5 with valid_loss value: 0.08682531265079621.
#               5       0.074329       0.086825          00:07
# Better model found at epoch 6 with valid_loss value: 0.08660644217091241.
#               6       0.073651       0.086606          00:07
#               7       0.073219       0.086663          00:07
# Better model found at epoch 8 with valid_loss value: 0.08646060378485905.
#               8       0.072912       0.086461          00:07
# Better model found at epoch 9 with valid_loss value: 0.08645012855376387.
#               9       0.072755       0.086450          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.02096064 rmse: 0.1447779 mae: 0.08866913
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.0002477076355991711
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.13260500033373168.
#               0       0.144699       0.132605          00:03
# Better model found at epoch 1 with valid_loss value: 0.12657372371465622.
#               1       0.130676       0.126574          00:03
# Better model found at epoch 2 with valid_loss value: 0.1245514785108574.
#               2       0.121130       0.124551          00:03
# Better model found at epoch 3 with valid_loss value: 0.12312892730688059.
#               3       0.114386       0.123129          00:03
#               4       0.111932       0.124365          00:03
#               5       0.111776       0.124097          00:03
#               6       0.111823       0.125145          00:03
#               7       0.111693       0.123435          00:03
#               8       0.111445       0.123352          00:03
# Better model found at epoch 9 with valid_loss value: 0.12239991227624085.
#               9       0.111209       0.122400          00:03
#              10       0.110877       0.122950          00:03
#              11       0.110532       0.122437          00:03
#              12       0.110102       0.122550          00:03
# Better model found at epoch 13 with valid_loss value: 0.12176016054083605.
#              13       0.109734       0.121760          00:03
# Better model found at epoch 14 with valid_loss value: 0.12099920261963487.
#              14       0.109345       0.120999          00:03
#              15       0.108956       0.121248          00:03
# Better model found at epoch 16 with valid_loss value: 0.12078500845453621.
#              16       0.108628       0.120785          00:03
# Better model found at epoch 17 with valid_loss value: 0.12047259188745932.
#              17       0.108388       0.120473          00:03
# Better model found at epoch 18 with valid_loss value: 0.12042627668264341.
#              18       0.108257       0.120426          00:03
# Better model found at epoch 19 with valid_loss value: 0.1204050211522325.
#              19       0.108176       0.120405          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.108446       0.120936          00:03
#               1       0.109648       0.123160          00:03
#               2       0.111412       0.123752          00:03
#               3       0.111722       0.123246          00:03
#               4       0.111413       0.122863          00:03
#               5       0.110767       0.122246          00:03
#               6       0.110015       0.121465          00:03
#               7       0.109280       0.121281          00:03
#               8       0.108719       0.120619          00:03
#               9       0.108479       0.120472          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.11955180032356082.
#               0       0.107250       0.119552          00:07
# Better model found at epoch 1 with valid_loss value: 0.1194976384509764.
#               1       0.104641       0.119498          00:07
# Better model found at epoch 2 with valid_loss value: 0.11821999235595504.
#               2       0.102435       0.118220          00:07
#               3       0.100087       0.119047          00:07
#               4       0.097865       0.120022          00:07
#               5       0.096002       0.119591          00:07
#               6       0.094351       0.119586          00:07
#               7       0.093173       0.119733          00:07
#               8       0.092427       0.119389          00:07
#               9       0.092132       0.119391          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.03633046 rmse: 0.1906055 mae: 0.1269483
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00020565123083486514
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.1346323486609532.
#               0       0.147832       0.134632          00:03
# Better model found at epoch 1 with valid_loss value: 0.12972547586718364.
#               1       0.135642       0.129725          00:03
# Better model found at epoch 2 with valid_loss value: 0.12737782838099992.
#               2       0.127563       0.127378          00:03
# Better model found at epoch 3 with valid_loss value: 0.12723896410405175.
#               3       0.120778       0.127239          00:03
# Better model found at epoch 4 with valid_loss value: 0.12694134610931582.
#               4       0.117379       0.126941          00:03
#               5       0.116547       0.127902          00:03
#               6       0.116315       0.127528          00:03
#               7       0.116215       0.127471          00:03
# Better model found at epoch 8 with valid_loss value: 0.1266311050030617.
#               8       0.115982       0.126631          00:03
# Better model found at epoch 9 with valid_loss value: 0.12600667304308003.
#               9       0.115767       0.126007          00:03
#              10       0.115570       0.126525          00:03
# Better model found at epoch 11 with valid_loss value: 0.12584940676199985.
#              11       0.115273       0.125849          00:03
#              12       0.114902       0.125902          00:03
# Better model found at epoch 13 with valid_loss value: 0.12563766813662935.
#              13       0.114611       0.125638          00:03
# Better model found at epoch 14 with valid_loss value: 0.12561521588254362.
#              14       0.114280       0.125615          00:03
# Better model found at epoch 15 with valid_loss value: 0.1249238693712179.
#              15       0.113923       0.124924          00:03
# Better model found at epoch 16 with valid_loss value: 0.12478314579838527.
#              16       0.113717       0.124783          00:03
# Better model found at epoch 17 with valid_loss value: 0.12471192974088692.
#              17       0.113520       0.124712          00:03
# Better model found at epoch 18 with valid_loss value: 0.1246054473630722.
#              18       0.113365       0.124605          00:03
# Better model found at epoch 19 with valid_loss value: 0.1245391458768576.
#              19       0.113269       0.124539          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.113530       0.125207          00:03
#               1       0.114428       0.126315          00:03
#               2       0.115906       0.127305          00:03
#               3       0.116282       0.127274          00:03
#               4       0.115996       0.126712          00:03
#               5       0.115447       0.126104          00:03
#               6       0.114808       0.125686          00:03
#               7       0.114216       0.124941          00:03
#               8       0.113765       0.124707          00:03
# Better model found at epoch 9 with valid_loss value: 0.12450251272280997.
#               9       0.113516       0.124503          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.12398173902094825.
#               0       0.112686       0.123982          00:07
# Better model found at epoch 1 with valid_loss value: 0.1228181213047248.
#               1       0.110406       0.122818          00:07
#               2       0.107998       0.123519          00:07
#               3       0.105634       0.123711          00:07
#               4       0.103384       0.123918          00:07
#               5       0.101492       0.124291          00:07
#               6       0.100055       0.123784          00:07
#               7       0.099002       0.123530          00:07
#               8       0.098292       0.123769          00:07
#               9       0.098086       0.123886          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.0379111 rmse: 0.19470772 mae: 0.13188134
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00020565123083486514
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.11632887466133686.
#               0       0.128083       0.116329          00:03
# Better model found at epoch 1 with valid_loss value: 0.10188605406860725.
#               1       0.108243       0.101886          00:03
# Better model found at epoch 2 with valid_loss value: 0.09645119590814501.
#               2       0.095971       0.096451          00:03
# Better model found at epoch 3 with valid_loss value: 0.09566688875072885.
#               3       0.089141       0.095667          00:03
# Better model found at epoch 4 with valid_loss value: 0.09562057978627152.
#               4       0.086276       0.095621          00:03
#               5       0.085725       0.095957          00:03
# Better model found at epoch 6 with valid_loss value: 0.0953431481503589.
#               6       0.085607       0.095343          00:03
# Better model found at epoch 7 with valid_loss value: 0.09500153977061385.
#               7       0.085590       0.095002          00:03
# Better model found at epoch 8 with valid_loss value: 0.09451722477493667.
#               8       0.085375       0.094517          00:03
#               9       0.085228       0.095007          00:03
#              10       0.084941       0.095079          00:03
# Better model found at epoch 11 with valid_loss value: 0.09436801899969338.
#              11       0.084682       0.094368          00:03
#              12       0.084405       0.094716          00:03
#              13       0.084164       0.094621          00:03
# Better model found at epoch 14 with valid_loss value: 0.09416073312401982.
#              14       0.083934       0.094161          00:03
# Better model found at epoch 15 with valid_loss value: 0.0938951707986921.
#              15       0.083491       0.093895          00:03
# Better model found at epoch 16 with valid_loss value: 0.09368680500228707.
#              16       0.083340       0.093687          00:03
# Better model found at epoch 17 with valid_loss value: 0.09350335592239525.
#              17       0.083167       0.093503          00:03
# Better model found at epoch 18 with valid_loss value: 0.09343736294824172.
#              18       0.082989       0.093437          00:03
# Better model found at epoch 19 with valid_loss value: 0.09342321598665956.
#              19       0.082944       0.093423          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.083182       0.094024          00:03
#               1       0.084094       0.094867          00:03
#               2       0.085224       0.095321          00:03
#               3       0.085577       0.095317          00:03
#               4       0.085413       0.095915          00:03
#               5       0.084882       0.094611          00:03
#               6       0.084324       0.094216          00:03
#               7       0.083828       0.093855          00:03
#               8       0.083390       0.093465          00:03
#               9       0.083098       0.093429          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.09182746620908397.
#               0       0.082012       0.091827          00:07
# Better model found at epoch 1 with valid_loss value: 0.09152460734867601.
#               1       0.079802       0.091525          00:07
# Better model found at epoch 2 with valid_loss value: 0.08987538185997064.
#               2       0.078039       0.089875          00:07
# Better model found at epoch 3 with valid_loss value: 0.08930654834086477.
#               3       0.076816       0.089307          00:07
# Better model found at epoch 4 with valid_loss value: 0.0885244501122175.
#               4       0.075815       0.088524          00:07
# Better model found at epoch 5 with valid_loss value: 0.08826408122386199.
#               5       0.074932       0.088264          00:07
# Better model found at epoch 6 with valid_loss value: 0.08820196614688053.
#               6       0.074207       0.088202          00:07
# Better model found at epoch 7 with valid_loss value: 0.08780958185783437.
#               7       0.073494       0.087810          00:07
# Better model found at epoch 8 with valid_loss value: 0.08768611746584466.
#               8       0.073110       0.087686          00:07
# Better model found at epoch 9 with valid_loss value: 0.08757665277351918.
#               9       0.072919       0.087577          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.024247227 rmse: 0.15571521 mae: 0.09905462
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.12951601554554007.
#               0       0.137853       0.129516          00:03
# Better model found at epoch 1 with valid_loss value: 0.12379182174595708.
#               1       0.126392       0.123792          00:03
# Better model found at epoch 2 with valid_loss value: 0.12079792069263628.
#               2       0.120340       0.120798          00:03
# Better model found at epoch 3 with valid_loss value: 0.11914773666344589.
#               3       0.115017       0.119148          00:03
# Better model found at epoch 4 with valid_loss value: 0.11864081212812755.
#               4       0.110754       0.118641          00:03
# Better model found at epoch 5 with valid_loss value: 0.11847289343788141.
#               5       0.107772       0.118473          00:03
# Better model found at epoch 6 with valid_loss value: 0.11802646770430736.
#               6       0.106250       0.118026          00:03
#               7       0.105488       0.118223          00:03
#               8       0.105162       0.118200          00:03
# Better model found at epoch 9 with valid_loss value: 0.11767414238901037.
#               9       0.104958       0.117674          00:03
# Better model found at epoch 10 with valid_loss value: 0.11750918358103642.
#              10       0.104727       0.117509          00:03
#              11       0.104559       0.117832          00:03
# Better model found at epoch 12 with valid_loss value: 0.11745350203735253.
#              12       0.104428       0.117454          00:03
# Better model found at epoch 13 with valid_loss value: 0.11739794961604963.
#              13       0.104302       0.117398          00:03
# Better model found at epoch 14 with valid_loss value: 0.11720950046722436.
#              14       0.104159       0.117210          00:03
# Better model found at epoch 15 with valid_loss value: 0.11712742829536209.
#              15       0.104042       0.117127          00:03
# Better model found at epoch 16 with valid_loss value: 0.11705165332269629.
#              16       0.103898       0.117052          00:03
# Better model found at epoch 17 with valid_loss value: 0.11694393545946909.
#              17       0.103799       0.116944          00:03
# Better model found at epoch 18 with valid_loss value: 0.11693570142455757.
#              18       0.103778       0.116936          00:03
# Better model found at epoch 19 with valid_loss value: 0.11692112052799532.
#              19       0.103724       0.116921          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.103805       0.117158          00:03
#               1       0.104196       0.117789          00:03
#               2       0.104704       0.117656          00:03
#               3       0.104909       0.117593          00:03
#               4       0.104860       0.117814          00:03
#               5       0.104666       0.117416          00:03
#               6       0.104397       0.117219          00:03
#               7       0.104130       0.117060          00:03
#               8       0.103919       0.116975          00:03
#               9       0.103828       0.116950          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.11671119733396054.
#               0       0.103485       0.116711          00:07
# Better model found at epoch 1 with valid_loss value: 0.11628860957841741.
#               1       0.102613       0.116289          00:07
#               2       0.101657       0.116324          00:07
#               3       0.100582       0.116336          00:07
#               4       0.099671       0.116617          00:07
#               5       0.098775       0.116630          00:07
#               6       0.098029       0.116732          00:07
#               7       0.097474       0.116490          00:07
#               8       0.097121       0.116638          00:07
#               9       0.096944       0.116608          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.04026833 rmse: 0.2006697 mae: 0.13854164
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.13233848005194612.
#               0       0.141179       0.132338          00:03
# Better model found at epoch 1 with valid_loss value: 0.12784059205126688.
#               1       0.130184       0.127841          00:03
# Better model found at epoch 2 with valid_loss value: 0.1252440501727678.
#               2       0.125622       0.125244          00:03
# Better model found at epoch 3 with valid_loss value: 0.12377678431299399.
#               3       0.121352       0.123777          00:03
# Better model found at epoch 4 with valid_loss value: 0.12330571913785918.
#               4       0.117419       0.123306          00:03
# Better model found at epoch 5 with valid_loss value: 0.12305594032371768.
#               5       0.114205       0.123056          00:03
# Better model found at epoch 6 with valid_loss value: 0.12222878481084308.
#               6       0.111900       0.122229          00:03
#               7       0.110500       0.122479          00:03
# Better model found at epoch 8 with valid_loss value: 0.12221799084446526.
#               8       0.109708       0.122218          00:03
# Better model found at epoch 9 with valid_loss value: 0.12189745828423453.
#               9       0.109189       0.121897          00:03
#              10       0.108917       0.121936          00:03
# Better model found at epoch 11 with valid_loss value: 0.12179093570542772.
#              11       0.108683       0.121791          00:03
#              12       0.108512       0.121889          00:03
# Better model found at epoch 13 with valid_loss value: 0.12176720706984295.
#              13       0.108371       0.121767          00:03
# Better model found at epoch 14 with valid_loss value: 0.12160710661881999.
#              14       0.108267       0.121607          00:03
# Better model found at epoch 15 with valid_loss value: 0.12153827247010332.
#              15       0.108157       0.121538          00:03
# Better model found at epoch 16 with valid_loss value: 0.12149775992031842.
#              16       0.108078       0.121498          00:03
# Better model found at epoch 17 with valid_loss value: 0.12146110666577474.
#              17       0.108000       0.121461          00:03
# Better model found at epoch 18 with valid_loss value: 0.12144916697112218.
#              18       0.107963       0.121449          00:03
#              19       0.107897       0.121461          00:03
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.107996       0.121613          00:03
#               1       0.108218       0.121825          00:03
#               2       0.108579       0.122002          00:03
#               3       0.108721       0.122289          00:03
#               4       0.108658       0.122053          00:03
#               5       0.108519       0.121852          00:03
#               6       0.108336       0.121739          00:03
#               7       0.108174       0.121585          00:03
#               8       0.108042       0.121505          00:03
#               9       0.107917       0.121491          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.12138069463133438.
#               0       0.107787       0.121381          00:07
# Better model found at epoch 1 with valid_loss value: 0.12122225247123539.
#               1       0.107137       0.121222          00:07
# Better model found at epoch 2 with valid_loss value: 0.12109827261161082.
#               2       0.106272       0.121098          00:07
#               3       0.105258       0.121133          00:07
# Better model found at epoch 4 with valid_loss value: 0.12102731786056109.
#               4       0.104531       0.121027          00:07
#               5       0.103803       0.121297          00:07
#               6       0.103290       0.121516          00:07
#               7       0.102822       0.121544          00:07
#               8       0.102587       0.121528          00:07
#               9       0.102506       0.121557          00:07
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.04309121 rmse: 0.20758423 mae: 0.14409915
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='ES', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.09781804176049541.
#               0       0.145141       0.097818          00:02
# Better model found at epoch 1 with valid_loss value: 0.0832868934693934.
#               1       0.116842       0.083287          00:02
# Better model found at epoch 2 with valid_loss value: 0.07419355348584275.
#               2       0.105285       0.074194          00:02
# Better model found at epoch 3 with valid_loss value: 0.06979016197711416.
#               3       0.094330       0.069790          00:02
# Better model found at epoch 4 with valid_loss value: 0.06634638803036282.
#               4       0.084843       0.066346          00:02
# Better model found at epoch 5 with valid_loss value: 0.06476602221447995.
#               5       0.078073       0.064766          00:02
# Better model found at epoch 6 with valid_loss value: 0.06448952814611147.
#               6       0.074584       0.064490          00:02
#               7       0.072721       0.064641          00:02
#               8       0.071977       0.064683          00:02
# Better model found at epoch 9 with valid_loss value: 0.06397719411618345.
#               9       0.071691       0.063977          00:02
# Better model found at epoch 10 with valid_loss value: 0.06336097171188877.
#              10       0.071346       0.063361          00:02
#              11       0.071195       0.063892          00:02
#              12       0.071002       0.063589          00:02
#              13       0.070732       0.063588          00:02
# Better model found at epoch 14 with valid_loss value: 0.06296930409750985.
#              14       0.070709       0.062969          00:02
#              15       0.070545       0.063194          00:02
# Better model found at epoch 16 with valid_loss value: 0.06283133931533497.
#              16       0.070443       0.062831          00:02
#              17       0.070261       0.062849          00:02
# Better model found at epoch 18 with valid_loss value: 0.06271597923756182.
#              18       0.070294       0.062716          00:02
# Better model found at epoch 19 with valid_loss value: 0.06268657103255187.
#              19       0.070165       0.062687          00:02
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.070230       0.063010          00:02
#               1       0.070650       0.064400          00:02
#               2       0.071323       0.065415          00:02
#               3       0.071664       0.064474          00:02
#               4       0.071403       0.064086          00:02
#               5       0.071307       0.063451          00:02
#               6       0.070983       0.063157          00:02
#               7       0.070723       0.063051          00:02
#               8       0.070368       0.062972          00:02
#               9       0.070316       0.062723          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.0606693380109478.
#               0       0.069255       0.060669          00:04
# Better model found at epoch 1 with valid_loss value: 0.058572411748092426.
#               1       0.066121       0.058572          00:04
# Better model found at epoch 2 with valid_loss value: 0.05666702415315365.
#               2       0.062974       0.056667          00:04
# Better model found at epoch 3 with valid_loss value: 0.05606376570636712.
#               3       0.060612       0.056064          00:04
# Better model found at epoch 4 with valid_loss value: 0.05482439467890462.
#               4       0.059186       0.054824          00:04
# Better model found at epoch 5 with valid_loss value: 0.05448804354962954.
#               5       0.058240       0.054488          00:04
# Better model found at epoch 6 with valid_loss value: 0.054150337610709545.
#               6       0.057645       0.054150          00:04
# Better model found at epoch 7 with valid_loss value: 0.053783002573902707.
#               7       0.057209       0.053783          00:04
# Better model found at epoch 8 with valid_loss value: 0.05368917218853044.
#               8       0.057050       0.053689          00:04
# Better model found at epoch 9 with valid_loss value: 0.05365770231666951.
#               9       0.056749       0.053658          00:04
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.009809221 rmse: 0.099041514 mae: 0.06074584
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='ES', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.10309352393650834.
#               0       0.147459       0.103094          00:02
# Better model found at epoch 1 with valid_loss value: 0.09326389396549532.
#               1       0.123195       0.093264          00:02
# Better model found at epoch 2 with valid_loss value: 0.08861719663789158.
#               2       0.115739       0.088617          00:02
# Better model found at epoch 3 with valid_loss value: 0.08565693693106692.
#               3       0.107632       0.085657          00:02
# Better model found at epoch 4 with valid_loss value: 0.08420223425422091.
#               4       0.099895       0.084202          00:02
# Better model found at epoch 5 with valid_loss value: 0.08342952619634866.
#               5       0.093876       0.083430          00:02
# Better model found at epoch 6 with valid_loss value: 0.08301011683787632.
#               6       0.090285       0.083010          00:02
# Better model found at epoch 7 with valid_loss value: 0.08293182397878102.
#               7       0.088507       0.082932          00:02
#               8       0.087627       0.083534          00:02
# Better model found at epoch 9 with valid_loss value: 0.08202487334087673.
#               9       0.087195       0.082025          00:02
#              10       0.086929       0.082106          00:02
# Better model found at epoch 11 with valid_loss value: 0.08196426528173312.
#              11       0.086744       0.081964          00:02
#              12       0.086480       0.082080          00:02
# Better model found at epoch 13 with valid_loss value: 0.08187981924455859.
#              13       0.086287       0.081880          00:02
# Better model found at epoch 14 with valid_loss value: 0.08164170267525682.
#              14       0.086194       0.081642          00:02
# Better model found at epoch 15 with valid_loss value: 0.08136173555577451.
#              15       0.086004       0.081362          00:02
#              16       0.085901       0.081408          00:02
# Better model found at epoch 17 with valid_loss value: 0.08125544300498373.
#              17       0.085767       0.081255          00:02
# Better model found at epoch 18 with valid_loss value: 0.0812313269172091.
#              18       0.085637       0.081231          00:02
#              19       0.085675       0.081244          00:02
# Starting full fine-tuning for 10 epochs
# Finetune the head
# ...
#              16       0.073441       0.065490          00:02
# Better model found at epoch 17 with valid_loss value: 0.06532151380382167.
#              17       0.073257       0.065322          00:02
# Better model found at epoch 18 with valid_loss value: 0.06531463176352391.
#              18       0.073249       0.065315          00:02
# Better model found at epoch 19 with valid_loss value: 0.06525904529823719.
#              19       0.073106       0.065259          00:02
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.073171       0.065833          00:02
#               1       0.073632       0.066450          00:02
#               2       0.074539       0.067201          00:02
#               3       0.074925       0.066723          00:02
#               4       0.074725       0.067200          00:02
#               5       0.074533       0.066474          00:02
#               6       0.074030       0.065647          00:02
#               7       0.073664       0.065577          00:02
#               8       0.073512       0.065299          00:02
#               9       0.073279       0.065314          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.06310246814116033.
#               0       0.071936       0.063102          00:04
# Better model found at epoch 1 with valid_loss value: 0.06064890296547018.
#               1       0.068274       0.060649          00:04
# Better model found at epoch 2 with valid_loss value: 0.059410847477807824.
#               2       0.064562       0.059411          00:04
# Better model found at epoch 3 with valid_loss value: 0.05794145824327449.
#               3       0.062330       0.057941          00:04
# Better model found at epoch 4 with valid_loss value: 0.05715574718890743.
#               4       0.060713       0.057156          00:04
# Better model found at epoch 5 with valid_loss value: 0.05691384985379051.
#               5       0.059747       0.056914          00:04
# Better model found at epoch 6 with valid_loss value: 0.05612060389795621.
#               6       0.059098       0.056121          00:04
# Better model found at epoch 7 with valid_loss value: 0.05594438537823458.
#               7       0.058658       0.055944          00:04
# Better model found at epoch 8 with valid_loss value: 0.05577804322447523.
#               8       0.058347       0.055778          00:04
# Better model found at epoch 9 with valid_loss value: 0.055762148754800345.
#               9       0.058196       0.055762          00:04
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.010154399 rmse: 0.100769036 mae: 0.058958236
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.10291845385285293.
#               0       0.151381       0.102918          00:02
# Better model found at epoch 1 with valid_loss value: 0.09404593856476302.
#               1       0.128921       0.094046          00:02
# Better model found at epoch 2 with valid_loss value: 0.08946273965113914.
#               2       0.119448       0.089463          00:02
# Better model found at epoch 3 with valid_loss value: 0.08677594128229252.
#               3       0.109721       0.086776          00:02
# Better model found at epoch 4 with valid_loss value: 0.08595025331824654.
#               4       0.100891       0.085950          00:02
# Better model found at epoch 5 with valid_loss value: 0.08509834357836656.
#               5       0.094887       0.085098          00:02
#               6       0.092107       0.085217          00:02
# Better model found at epoch 7 with valid_loss value: 0.0847708693551668.
#               7       0.091038       0.084771          00:02
# Better model found at epoch 8 with valid_loss value: 0.08428027383479963.
#               8       0.090611       0.084280          00:02
#               9       0.090334       0.084310          00:02
#              10       0.090160       0.084385          00:02
# Better model found at epoch 11 with valid_loss value: 0.08387734247864118.
#              11       0.089967       0.083877          00:02
#              12       0.089711       0.083997          00:02
# Better model found at epoch 13 with valid_loss value: 0.08384440633899512.
#              13       0.089563       0.083844          00:02
# Better model found at epoch 14 with valid_loss value: 0.0834966301045057.
#              14       0.089346       0.083497          00:02
# Better model found at epoch 15 with valid_loss value: 0.0833373824787683.
#              15       0.089149       0.083337          00:02
# Better model found at epoch 16 with valid_loss value: 0.08326844602605014.
#              16       0.089039       0.083268          00:02
# Better model found at epoch 17 with valid_loss value: 0.08309011808539717.
#              17       0.088822       0.083090          00:02
# Better model found at epoch 18 with valid_loss value: 0.08306927475335639.
#              18       0.088756       0.083069          00:02
# Better model found at epoch 19 with valid_loss value: 0.08305379496637257.
#              19       0.088697       0.083054          00:02
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.088833       0.083643          00:02
#               1       0.089408       0.084479          00:02
#               2       0.090252       0.084883          00:02
#               3       0.090565       0.084986          00:02
#               4       0.090408       0.084416          00:02
#               5       0.090129       0.084248          00:02
#               6       0.089712       0.083639          00:02
#               7       0.089304       0.083386          00:02
#               8       0.089045       0.083130          00:02
#               9       0.088940       0.083072          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.0819668626280894.
#               0       0.088007       0.081967          00:05
# Better model found at epoch 1 with valid_loss value: 0.08015081096801262.
#               1       0.085332       0.080151          00:05
# Better model found at epoch 2 with valid_loss value: 0.07917479475500916.
#               2       0.082243       0.079175          00:05
# Better model found at epoch 3 with valid_loss value: 0.0780610198602141.
#               3       0.080400       0.078061          00:05
# Better model found at epoch 4 with valid_loss value: 0.07785175717682058.
#               4       0.079109       0.077852          00:05
# Better model found at epoch 5 with valid_loss value: 0.07745208864390511.
#               5       0.078180       0.077452          00:05
# Better model found at epoch 6 with valid_loss value: 0.07700507689337113.
#               6       0.077465       0.077005          00:05
# Better model found at epoch 7 with valid_loss value: 0.0768277223368211.
#               7       0.076909       0.076828          00:04
# Better model found at epoch 8 with valid_loss value: 0.07670867150153834.
#               8       0.076657       0.076709          00:04
# Better model found at epoch 9 with valid_loss value: 0.07666702456742015.
#               9       0.076438       0.076667          00:04
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018356318 rmse: 0.13548549 mae: 0.08207569
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='IT', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.10369138373744442.
#               0       0.151275       0.103691          00:02
# Better model found at epoch 1 with valid_loss value: 0.09603170780889798.
#               1       0.129522       0.096032          00:02
# Better model found at epoch 2 with valid_loss value: 0.09219756833847048.
#               2       0.120232       0.092198          00:02
# Better model found at epoch 3 with valid_loss value: 0.09028485538577516.
#               3       0.110290       0.090285          00:02
# Better model found at epoch 4 with valid_loss value: 0.08970274502022271.
#               4       0.101760       0.089703          00:02
# Better model found at epoch 5 with valid_loss value: 0.08919072508438992.
#               5       0.096852       0.089191          00:02
#               6       0.095046       0.089328          00:02
# Better model found at epoch 7 with valid_loss value: 0.08896531812170673.
#               7       0.094449       0.088965          00:02
# Better model found at epoch 8 with valid_loss value: 0.0889155090924996.
#               8       0.094180       0.088916          00:02
# Better model found at epoch 9 with valid_loss value: 0.0884036600108832.
#               9       0.093967       0.088404          00:02
#              10       0.093674       0.088864          00:02
#              11       0.093438       0.088523          00:02
# Better model found at epoch 12 with valid_loss value: 0.08803897671108286.
#              12       0.093198       0.088039          00:02
# Better model found at epoch 13 with valid_loss value: 0.08800786114320043.
#              13       0.092945       0.088008          00:02
# Better model found at epoch 14 with valid_loss value: 0.08779044412769636.
#              14       0.092679       0.087790          00:02
# Better model found at epoch 15 with valid_loss value: 0.08747503719395788.
#              15       0.092433       0.087475          00:02
#              16       0.092264       0.087480          00:02
# Better model found at epoch 17 with valid_loss value: 0.0872978714217901.
#              17       0.092113       0.087298          00:02
# Better model found at epoch 18 with valid_loss value: 0.08720830361139985.
#              18       0.091975       0.087208          00:02
#              19       0.091935       0.087212          00:02
# Starting full fine-tuning for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.092099       0.087924          00:02
#               1       0.092727       0.088510          00:02
#               2       0.093773       0.089287          00:02
#               3       0.094280       0.089120          00:02
#               4       0.094026       0.088487          00:02
#               5       0.093622       0.089158          00:02
#               6       0.093185       0.087948          00:02
#               7       0.092709       0.087512          00:02
#               8       0.092333       0.087275          00:02
#               9       0.092134       0.087238          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.08626850491867179.
#               0       0.091223       0.086269          00:05
# Better model found at epoch 1 with valid_loss value: 0.0848120330252758.
#               1       0.088436       0.084812          00:05
# Better model found at epoch 2 with valid_loss value: 0.08399936494492785.
#               2       0.085553       0.083999          00:05
# Better model found at epoch 3 with valid_loss value: 0.08347257616962374.
#               3       0.083532       0.083473          00:05
# Better model found at epoch 4 with valid_loss value: 0.08320697323996841.
#               4       0.082177       0.083207          00:05
# Better model found at epoch 5 with valid_loss value: 0.083113159199788.
#               5       0.081105       0.083113          00:05
# Better model found at epoch 6 with valid_loss value: 0.08296639542789293.
#               6       0.080407       0.082966          00:05
#               7       0.079706       0.082977          00:05
# Better model found at epoch 8 with valid_loss value: 0.08279948593383367.
#               8       0.079450       0.082799          00:05
#               9       0.079183       0.082815          00:05
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.020322172 rmse: 0.14255586 mae: 0.087468274
# ----------- Complete! -----------

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)

# Path if not exists
path = "/results/PatchTST/"
if os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv("finetune_results.csv", index=True)

df_self_sup = df_self_sup.round(4)
df_self_sup
# Out:
#                      MSE    RMSE     MAE
# Country Pred_len
# DE      24        0.0210  0.1448  0.0887
#         96        0.0363  0.1906  0.1269
#         168       0.0379  0.1947  0.1319
# GB      24        0.0242  0.1557  0.0991
#         96        0.0403  0.2007  0.1385
#         168       0.0431  0.2076  0.1441
# ES      24        0.0098  0.0990  0.0607
#         96        0.0185  0.1358  0.0871
#         168       0.0213  0.1458  0.0952
# FR      24        0.0100  0.1001  0.0554
#         96        0.0201  0.1419  0.0813
#         168       0.0212  0.1455  0.0854
# IT      24        0.0102  0.1008  0.0590
#         96        0.0184  0.1355  0.0821
#         168       0.0203  0.1426  0.0875

# %%
import os
# Convert the list of dictionaries into a DataFrame
df_self_sup = pd.DataFrame(data)

# Set MultiIndex
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup = df_self_sup.sort_index().round(4)

path = "/results/PatchTST/"
if os.path.exists(path):
    os.makedirs(path)


# Save the results to a CSV file
df_self_sup.to_csv("finetune_results.csv", index=True)
df_self_sup

# %%
df_self_sup.to_csv("finetune_results.csv", index=False)

# %%
import numpy as np
import pandas as pd
coun = np.repeat(["DE", "GB", "ES", "FR", "IT"], 3)
pred = np.array([24, 96, 168]*5)

df = pd.DataFrame({'Country': coun, 'Pred_len': pred})
df_2 = pd.read_csv("finetune_results.csv")
final = pd.concat([df, df_2], axis=1)
final
# Out:
#    Country  Pred_len     MSE    RMSE     MAE
# 0       DE        24  0.0210  0.1448  0.0887
# 1       DE        96  0.0363  0.1906  0.1269
# 2       DE       168  0.0379  0.1947  0.1319
# 3       GB        24  0.0242  0.1557  0.0991
# 4       GB        96  0.0403  0.2007  0.1385
# 5       GB       168  0.0431  0.2076  0.1441
# 6       ES        24  0.0098  0.0990  0.0607
# 7       ES        96  0.0185  0.1358  0.0871
# 8       ES       168  0.0213  0.1458  0.0952
# 9       FR        24  0.0100  0.1001  0.0554
# 10      FR        96  0.0201  0.1419  0.0813
# 11      FR       168  0.0212  0.1455  0.0854
# 12      IT        24  0.0102  0.1008  0.0590
# 13      IT        96  0.0184  0.1355  0.0821
# 14      IT       168  0.0203  0.1426  0.0875

# %%
final.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
final.to_csv("finetune_results.csv", index=False)

# %% [markdown]
# # Test on bugs for Italy

# %%
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len
            }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Complete command
        # !{command}
# Out:
# args: Namespace(dset_pretrain='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.8967356272884459.
#               0       0.938521       0.896736          00:09
# Better model found at epoch 1 with valid_loss value: 0.8881698471826688.
#               1       0.896467       0.888170          00:09
# Better model found at epoch 2 with valid_loss value: 0.8823258079485354.
#               2       0.885393       0.882326          00:09
# Better model found at epoch 3 with valid_loss value: 0.8821932687906835.
#               3       0.878312       0.882193          00:09
# Better model found at epoch 4 with valid_loss value: 0.8765498658716436.
#               4       0.876024       0.876550          00:09
#               5       0.872625       0.877340          00:09
# Better model found at epoch 6 with valid_loss value: 0.8757813294599268.
#               6       0.871166       0.875781          00:09
#               7       0.869507       0.877671          00:09
# Better model found at epoch 8 with valid_loss value: 0.873351206519528.
#               8       0.867975       0.873351          00:09
#               9       0.867239       0.875410          00:09
#              10       0.867303       0.873736          00:09
# Better model found at epoch 11 with valid_loss value: 0.495188105484642.
#              11       0.608950       0.495188          00:09
# Better model found at epoch 12 with valid_loss value: 0.4847974089707079.
#              12       0.503978       0.484797          00:09
# Better model found at epoch 13 with valid_loss value: 0.4774695747940399.
#              13       0.495159       0.477470          00:09
# Better model found at epoch 14 with valid_loss value: 0.4762754510145443.
#              14       0.490194       0.476275          00:09
#              15       0.486599       0.476790          00:09
# Better model found at epoch 16 with valid_loss value: 0.4751617804109032.
#              16       0.484648       0.475162          00:09
# Better model found at epoch 17 with valid_loss value: 0.47410210282750204.
#              17       0.482739       0.474102          00:09
# Better model found at epoch 18 with valid_loss value: 0.4726005883212978.
#              18       0.481069       0.472601          00:09
# Better model found at epoch 19 with valid_loss value: 0.4454305774511798.
#              19       0.473361       0.445431          00:09
# Better model found at epoch 20 with valid_loss value: 0.318727651895596.
#              20       0.419336       0.318728          00:09
# Better model found at epoch 21 with valid_loss value: 0.2427597703925956.
#              21       0.313724       0.242760          00:09
# Better model found at epoch 22 with valid_loss value: 0.22882416789564686.
#              22       0.260966       0.228824          00:09
# Better model found at epoch 23 with valid_loss value: 0.21324038773265866.
#              23       0.242250       0.213240          00:09
# Better model found at epoch 24 with valid_loss value: 0.180197354620118.
#              24       0.222249       0.180197          00:09
# Better model found at epoch 25 with valid_loss value: 0.1609063417762154.
#              25       0.196233       0.160906          00:09
# Better model found at epoch 26 with valid_loss value: 0.15310471785369204.
#              26       0.180621       0.153105          00:09
# Better model found at epoch 27 with valid_loss value: 0.148449061419345.
#              27       0.170199       0.148449          00:09
# Better model found at epoch 28 with valid_loss value: 0.14366076650223758.
#              28       0.162535       0.143661          00:09
# Better model found at epoch 29 with valid_loss value: 0.1396192061794396.
#              29       0.156692       0.139619          00:09
# Better model found at epoch 30 with valid_loss value: 0.13863732979683685.
#              30       0.151614       0.138637          00:09
# Better model found at epoch 31 with valid_loss value: 0.1341101203341131.
#              31       0.148787       0.134110          00:09
# Better model found at epoch 32 with valid_loss value: 0.13148661179693857.
#              32       0.145196       0.131487          00:09
#              33       0.143299       0.133147          00:09
#              34       0.140370       0.132577          00:09
# Better model found at epoch 35 with valid_loss value: 0.13096277222970912.
#              35       0.138300       0.130963          00:09
# Better model found at epoch 36 with valid_loss value: 0.12906480235137816.
#              36       0.136646       0.129065          00:09
# Better model found at epoch 37 with valid_loss value: 0.12854402199132933.
#              37       0.134263       0.128544          00:09
# Better model found at epoch 38 with valid_loss value: 0.1268503733821959.
#              38       0.132729       0.126850          00:09
#              39       0.131227       0.128180          00:09
#              40       0.129391       0.126982          00:09
# Better model found at epoch 41 with valid_loss value: 0.1263340030480828.
#              41       0.128036       0.126334          00:09
#              42       0.127176       0.129643          00:09
#              43       0.126021       0.128046          00:08
# Better model found at epoch 44 with valid_loss value: 0.12491932830934703.
#              44       0.124882       0.124919          00:09
#              45       0.123773       0.129891          00:09
#              46       0.122938       0.125227          00:09
#              47       0.122092       0.128650          00:09
#              48       0.120755       0.129128          00:09
#              49       0.119283       0.132512          00:09
# No improvement since epoch 44: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv

# %%
# IT IS BETTER!
# Define parameters in a dictionary
params = {
    "--dset": "IT",
    "--linear_prob_finetune": 1,
    "--pretrained_model": "saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain30_mask0.4_model1.pth",    
    "--scaler_type": "minmax",
    "--n_epochs_finetune": 10,
    "--n_epochs_linear_probe": 20
}

# Build the command string
command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

# Add parameters to the command
for key, value in params.items():
    if value is not None:
        command += f"{key} {value} "
    else:
        command += f"{key} "  # Add flags with no value

# Run the command with !
# !{command}
# Out:
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain30_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.10813757056041497.
#               0       0.161137       0.108138          00:04
# Better model found at epoch 1 with valid_loss value: 0.09656939712164361.
#               1       0.132584       0.096569          00:04
# Better model found at epoch 2 with valid_loss value: 0.09087136550294955.
#               2       0.123537       0.090871          00:04
# Better model found at epoch 3 with valid_loss value: 0.08758014526863812.
#               3       0.114970       0.087580          00:04
# Better model found at epoch 4 with valid_loss value: 0.08586278780385476.
#               4       0.106743       0.085863          00:04
# Better model found at epoch 5 with valid_loss value: 0.0844781985798922.
#               5       0.099737       0.084478          00:04
# Better model found at epoch 6 with valid_loss value: 0.0842069819848454.
#               6       0.094818       0.084207          00:04
# Better model found at epoch 7 with valid_loss value: 0.08405468710270037.
#               7       0.092057       0.084055          00:04
# Better model found at epoch 8 with valid_loss value: 0.08382456122228438.
#               8       0.090704       0.083825          00:04
#               9       0.090003       0.083871          00:04
# Better model found at epoch 10 with valid_loss value: 0.08365624523240439.
#              10       0.089537       0.083656          00:04
# Better model found at epoch 11 with valid_loss value: 0.08359747468406734.
#              11       0.089301       0.083597          00:04
# Better model found at epoch 12 with valid_loss value: 0.08344239870448536.
#              12       0.089119       0.083442          00:04
# Better model found at epoch 13 with valid_loss value: 0.08318924434404242.
#              13       0.088892       0.083189          00:04
# Better model found at epoch 14 with valid_loss value: 0.08296695519890408.
#              14       0.088728       0.082967          00:04
#              15       0.088581       0.082979          00:04
# Better model found at epoch 16 with valid_loss value: 0.08290457419014442.
#              16       0.088482       0.082905          00:04
# Better model found at epoch 17 with valid_loss value: 0.08284981140186382.
#              17       0.088394       0.082850          00:04
# Better model found at epoch 18 with valid_loss value: 0.08275175785222996.
#              18       0.088338       0.082752          00:04
#              19       0.088268       0.082760          00:04
# Starting full fine-tuning for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.088347       0.083214          00:04
#               1       0.088748       0.083694          00:04
#               2       0.089289       0.083948          00:04
#               3       0.089499       0.084088          00:04
#               4       0.089419       0.083947          00:04
#               5       0.089231       0.083624          00:04
#               6       0.088961       0.083192          00:04
#               7       0.088721       0.082865          00:04
#               8       0.088478       0.082801          00:04
#               9       0.088414       0.082753          00:04
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.081913217245029.
#               0       0.087893       0.081913          00:08
# Better model found at epoch 1 with valid_loss value: 0.08021011290460994.
#               1       0.085796       0.080210          00:08
# Better model found at epoch 2 with valid_loss value: 0.07895167624688518.
#               2       0.082999       0.078952          00:07
# Better model found at epoch 3 with valid_loss value: 0.0781030342964936.
#               3       0.081195       0.078103          00:08
# Better model found at epoch 4 with valid_loss value: 0.07764475910134001.
#               4       0.080039       0.077645          00:08
# Better model found at epoch 5 with valid_loss value: 0.07738752248715927.
#               5       0.079188       0.077388          00:08
# Better model found at epoch 6 with valid_loss value: 0.07722825003019478.
#               6       0.078624       0.077228          00:08
# Better model found at epoch 7 with valid_loss value: 0.0770519830813924.
#               7       0.078195       0.077052          00:08
#               8       0.077899       0.077059          00:08
# Better model found at epoch 9 with valid_loss value: 0.07698487420698993.
#               9       0.077870       0.076985          00:08
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018168202 rmse: 0.13478947 mae: 0.081972055
# ----------- Complete! -----------
