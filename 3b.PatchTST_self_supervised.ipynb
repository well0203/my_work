# %% [markdown]
# <summary>Table of Contents</summary>
#
# - [1. Pretrain](#1-pretrain)
# - [2. Finetune](#2-finetune)
#
#
# This notebook demonstrates experiments on 5 countries with self-supervised learning.
# All parameters and settings are taken from the paper.

# %%
import pandas as pd
import subprocess
import os
import time
from utils.helper import extract_metrics_from_output, running_time

# %% [markdown]
# # 1. Pretrain
#
# Tracking loss - MAE.

# %%
start = time.time()

countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]
seq_lens = [512, 512, 336, 168, 168]
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len,
            "--batch_size": 128
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Execute the command
        print(f"==========Running command for {country}, pred_len {pred_len}:==========")
        # !{command}
        
end = time.time()
hours, mins, secs = running_time(start, end)
print("Total time: {:0>2}h:{:0>2}m:{:05.2f}s".format(hours, mins, secs))
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=24, batch_size=128, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00043287612810830566
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss      valid_mse           time
# ^C
# Traceback (most recent call last):
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 541, in _check_seekable
#     f.seek(f.tell())
#     ^^^^^^
# AttributeError: 'NoneType' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py", line 177, in <module>
#     pretrain_func(suggested_lr)
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py", line 162, in pretrain_func
#     learn.fit_one_cycle(n_epochs=args.n_epochs_pretrain, lr_max=lr)
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/learner.py", line 110, in fit_one_cycle
#     self.fit(self.n_epochs, cbs=cb)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/learner.py", line 103, in fit
#     self('after_fit')
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/learner.py", line 369, in __call__
#     if attr is not None: attr()
#                          ^^^^^^
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/callback/tracking.py", line 260, in after_fit
#     self.learner.load(self.last_saved_path, with_opt=self.with_opt)
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/learner.py", line 387, in load
#     load_model(fname, self.model, self.opt, with_opt, device=device, strict=strict)
#   File "/vol/fob-vol3/nebenf24/riabchuv/my_work-1/PatchTST-main/PatchTST_self_supervised/src/learner.py", line 429, in load_model
#     state = torch.load(path, map_location=device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 998, in load
#     with _open_file_like(f, 'rb') as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 450, in _open_file_like
#     return _open_buffer_reader(name_or_buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 435, in __init__
#     _check_seekable(buffer)
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 544, in _check_seekable
#     raise_err_msg(["seek", "tell"], e)
#   File "/vol/fob-vol3/nebenf24/riabchuv/.conda/envs/val/lib/python3.11/site-packages/torch/serialization.py", line 537, in raise_err_msg
#     raise type(e)(msg)
# AttributeError: 'NoneType' object has no attribute 'seek'. You can only torch.load from a file that is seekable. Please pre-load the data into a buffer like io.BytesIO and try to load from it instead.
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=96, batch_size=128, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss      valid_mse           time

# %% [markdown]
# # 2. Finetune
#
# Linear probing + full fine-tuning.

# %%
start = time.time()
# In case you just want finetune, please uncomment below
#countries = ['DE', 'GB', 'ES', 'FR', 'IT']
#pred_lens = ["24", "96", "168"]

# List to store metrics for the DataFrame
data = []

for country in countries:
    for pred_len in pred_lens:
        # Define the parameters for each country and pred_len
        params = {
            "--dset": country,
            "--is_finetune": 1,
            "--pretrained_model": f"saved_models/{country}/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth",
            "--scaler_type": "minmax",
            "--n_epochs_finetune": 20,
            "--target_points": pred_len,
            "--batch_size": 128

        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        print(f"==========Running command for {country}, pred_len {pred_len}:==========")

        # Run the command and capture the output
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Capture the output in real-time
        output = []
        for line in process.stdout:
            output.append(line)
            print(line, end='')  # Print in the .ipynb cell

        # Wait for the process to complete
        process.stdout.close()
        process.wait()

        try:
            # Extract metrics from the output using the function
            metrics = extract_metrics_from_output(output, if_supervised=False)
            mse, rmse, mae = metrics[0]

            # Append the results to the data list
            data.append({
                'Country': country,
                'Pred_len': pred_len,
                'MSE': mse,
                'RMSE': rmse,
                'MAE': mae
            })
        except ValueError as e:
            print(f"\nError: {e} for {country}, pred_len {pred_len}")

end = time.time()
hours, mins, secs = running_time(start, end)
print("Total time: {:0>2}h:{:0>2}m:{:05.2f}s".format(hours, mins, secs))
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12127674747667685.
#               0       0.141350       0.121277       0.121277          00:02
# Better model found at epoch 1 with valid_loss value: 0.10207604157765501.
#               1       0.112781       0.102076       0.102076          00:02
# Better model found at epoch 2 with valid_loss value: 0.09573940051911593.
#               2       0.096550       0.095739       0.095739          00:02
# Better model found at epoch 3 with valid_loss value: 0.09461241487868445.
#               3       0.089675       0.094612       0.094612          00:02
# Better model found at epoch 4 with valid_loss value: 0.09393870142163122.
#               4       0.087104       0.093939       0.093939          00:02
# Better model found at epoch 5 with valid_loss value: 0.0930864279803613.
#               5       0.086137       0.093086       0.093086          00:02
#               6       0.085675       0.093104       0.093104          00:02
# Better model found at epoch 7 with valid_loss value: 0.09281753753568843.
#               7       0.085227       0.092818       0.092818          00:02
# Better model found at epoch 8 with valid_loss value: 0.09259128432498592.
#               8       0.084942       0.092591       0.092591          00:02
# Better model found at epoch 9 with valid_loss value: 0.09257437865680794.
#               9       0.084711       0.092574       0.092574          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09122898395716886.
#               0       0.083912       0.091229       0.091229          00:07
# Better model found at epoch 1 with valid_loss value: 0.09044965425257862.
#               1       0.082129       0.090450       0.090450          00:07
# Better model found at epoch 2 with valid_loss value: 0.0893860010543168.
#               2       0.080072       0.089386       0.089386          00:07
# Better model found at epoch 3 with valid_loss value: 0.08883617414008464.
#               3       0.077990       0.088836       0.088836          00:07
# Better model found at epoch 4 with valid_loss value: 0.0884317143737685.
#               4       0.076417       0.088432       0.088432          00:09
# Better model found at epoch 5 with valid_loss value: 0.08755844138300226.
#               5       0.075350       0.087558       0.087558          00:08
# Better model found at epoch 6 with valid_loss value: 0.08693134123170339.
#               6       0.074502       0.086931       0.086931          00:06
#               7       0.073678       0.086990       0.086990          00:06
#               8       0.073059       0.087448       0.087448          00:06
# Better model found at epoch 9 with valid_loss value: 0.08626762195014677.
#               9       0.072479       0.086268       0.086268          00:07
# Better model found at epoch 10 with valid_loss value: 0.08612888158853747.
#              10       0.072087       0.086129       0.086129          00:06
# Better model found at epoch 11 with valid_loss value: 0.08591755091885153.
#              11       0.071621       0.085918       0.085918          00:06
#              12       0.071322       0.086217       0.086217          00:10
# Better model found at epoch 13 with valid_loss value: 0.08585552419902083.
#              13       0.071019       0.085856       0.085856          00:11
#              14       0.070726       0.086313       0.086313          00:11
# Better model found at epoch 15 with valid_loss value: 0.08577983157320652.
#              15       0.070520       0.085780       0.085780          00:11
#              16       0.070379       0.085800       0.085800          00:11
# Better model found at epoch 17 with valid_loss value: 0.08576649946090358.
#              17       0.070204       0.085766       0.085767          00:11
# Better model found at epoch 18 with valid_loss value: 0.08573197144988037.
#              18       0.070191       0.085732       0.085732          00:11
#              19       0.070168       0.085751       0.085751          00:11
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.021040574 rmse: 0.1450537 mae: 0.08833712
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.000298364724028334
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12880223695585843.
#               0       0.141065       0.128802       0.128802          00:02
# Better model found at epoch 1 with valid_loss value: 0.12354897234476708.
#               1       0.122082       0.123549       0.123549          00:02
#               2       0.113893       0.124163       0.124163          00:02
# Better model found at epoch 3 with valid_loss value: 0.1234553586185415.
#               3       0.112430       0.123455       0.123455          00:02
# Better model found at epoch 4 with valid_loss value: 0.12255175026380696.
#               4       0.111698       0.122552       0.122552          00:02
# Better model found at epoch 5 with valid_loss value: 0.12223501306321197.
#               5       0.110954       0.122235       0.122235          00:02
# Better model found at epoch 6 with valid_loss value: 0.12204959332409479.
#               6       0.110028       0.122050       0.122050          00:02
# Better model found at epoch 7 with valid_loss value: 0.12081828229887104.
#               7       0.109054       0.120818       0.120818          00:02
# Better model found at epoch 8 with valid_loss value: 0.12005213961744812.
#               8       0.108407       0.120052       0.120052          00:02
#               9       0.108097       0.120072       0.120072          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11923190459087672.
#               0       0.107245       0.119232       0.119232          00:11
# Better model found at epoch 1 with valid_loss value: 0.11821498638056856.
#               1       0.105508       0.118215       0.118215          00:11
#               2       0.103505       0.118593       0.118593          00:08
#               3       0.101926       0.118471       0.118471          00:11
#               4       0.100034       0.119183       0.119183          00:06
#               5       0.097963       0.121686       0.121686          00:06
#               6       0.095793       0.120598       0.120598          00:06
#               7       0.093618       0.121335       0.121335          00:06
#               8       0.091904       0.121112       0.121112          00:10
#               9       0.090229       0.121404       0.121404          00:10
#              10       0.088756       0.121383       0.121383          00:11
#              11       0.087533       0.121625       0.121625          00:11
#              12       0.086421       0.121750       0.121750          00:11
#              13       0.085618       0.121689       0.121689          00:11
#              14       0.084677       0.121699       0.121699          00:11
#              15       0.084152       0.121373       0.121373          00:11
#              16       0.083692       0.121467       0.121467          00:11
#              17       0.083394       0.121444       0.121444          00:11
#              18       0.083169       0.121396       0.121396          00:11
#              19       0.083054       0.121406       0.121406          00:11
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.035324693 rmse: 0.18794864 mae: 0.12619255
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1344844793617755.
#               0       0.151031       0.134484       0.134484          00:02
# Better model found at epoch 1 with valid_loss value: 0.12936049105994257.
#               1       0.134495       0.129360       0.129360          00:02
# Better model found at epoch 2 with valid_loss value: 0.12632125585648052.
#               2       0.125607       0.126321       0.126321          00:02
# Better model found at epoch 3 with valid_loss value: 0.1258092158201517.
#               3       0.119644       0.125809       0.125809          00:02
# Better model found at epoch 4 with valid_loss value: 0.12508384921926458.
#               4       0.116540       0.125084       0.125084          00:02
# Better model found at epoch 5 with valid_loss value: 0.12489165832630084.
#               5       0.115081       0.124892       0.124892          00:02
# Better model found at epoch 6 with valid_loss value: 0.12477538700691071.
#               6       0.114279       0.124775       0.124775          00:02
# Better model found at epoch 7 with valid_loss value: 0.12446213082624938.
#               7       0.113826       0.124462       0.124462          00:02
# Better model found at epoch 8 with valid_loss value: 0.12422010075333444.
#               8       0.113502       0.124220       0.124220          00:02
#               9       0.113345       0.124224       0.124224          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12396282445416701.
#               0       0.113022       0.123963       0.123963          00:11
# Better model found at epoch 1 with valid_loss value: 0.1232347442863134.
#               1       0.112098       0.123235       0.123235          00:11
# Better model found at epoch 2 with valid_loss value: 0.12239533752109748.
#               2       0.110670       0.122395       0.122395          00:11
# Better model found at epoch 3 with valid_loss value: 0.1221703928698234.
#               3       0.109231       0.122170       0.122170          00:11
# Better model found at epoch 4 with valid_loss value: 0.12197043313513709.
#               4       0.107844       0.121970       0.121970          00:11
#               5       0.106415       0.122343       0.122343          00:11
#               6       0.104791       0.122099       0.122099          00:11
#               7       0.103447       0.122689       0.122689          00:06
#               8       0.102163       0.122388       0.122388          00:06
#               9       0.101074       0.122684       0.122684          00:07
#              10       0.100140       0.122923       0.122923          00:11
#              11       0.099389       0.122959       0.122959          00:11
#              12       0.098706       0.123045       0.123045          00:11
#              13       0.098203       0.123224       0.123224          00:11
#              14       0.097721       0.123299       0.123299          00:11
#              15       0.097347       0.123285       0.123285          00:11
#              16       0.097233       0.123291       0.123291          00:11
#              17       0.097125       0.123145       0.123145          00:11
#              18       0.096900       0.123226       0.123226          00:11
#              19       0.096839       0.123209       0.123209          00:11
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.03793704 rmse: 0.19477433 mae: 0.13143772
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1146023661181036.
#               0       0.129991       0.114602       0.114602          00:02
# Better model found at epoch 1 with valid_loss value: 0.09847534042243043.
#               1       0.105771       0.098475       0.098475          00:02
# Better model found at epoch 2 with valid_loss value: 0.09512102809081953.
#               2       0.093169       0.095121       0.095121          00:02
# Better model found at epoch 3 with valid_loss value: 0.09441418070223279.
#               3       0.087630       0.094414       0.094414          00:02
# Better model found at epoch 4 with valid_loss value: 0.0939405471043359.
#               4       0.085460       0.093941       0.093941          00:02
# Better model found at epoch 5 with valid_loss value: 0.09339971298455847.
#               5       0.084536       0.093400       0.093400          00:02
# Better model found at epoch 6 with valid_loss value: 0.09318149045711356.
#               6       0.083962       0.093181       0.093181          00:02
# Better model found at epoch 7 with valid_loss value: 0.09304558734178965.
#               7       0.083523       0.093046       0.093046          00:02
# Better model found at epoch 8 with valid_loss value: 0.09278892945376588.
#               8       0.083376       0.092789       0.092789          00:02
#               9       0.083158       0.092832       0.092833          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09209413790752674.
#               0       0.082640       0.092094       0.092094          00:10
# Better model found at epoch 1 with valid_loss value: 0.09140926199709466.
#               1       0.081556       0.091409       0.091409          00:10
# Better model found at epoch 2 with valid_loss value: 0.09051318304397217.
#               2       0.080119       0.090513       0.090513          00:10
# Better model found at epoch 3 with valid_loss value: 0.09016541911605779.
#               3       0.078894       0.090165       0.090165          00:10
# Better model found at epoch 4 with valid_loss value: 0.08957596892844218.
#               4       0.077711       0.089576       0.089576          00:10
# Better model found at epoch 5 with valid_loss value: 0.08909715171103426.
#               5       0.076775       0.089097       0.089097          00:10
# Better model found at epoch 6 with valid_loss value: 0.08884801399828594.
#               6       0.076054       0.088848       0.088848          00:10
# Better model found at epoch 7 with valid_loss value: 0.08868835262686987.
#               7       0.075432       0.088688       0.088688          00:10
# Better model found at epoch 8 with valid_loss value: 0.08839614571185861.
#               8       0.074916       0.088396       0.088396          00:11
# Better model found at epoch 9 with valid_loss value: 0.08819824532908759.
#               9       0.074560       0.088198       0.088198          00:11
#              10       0.074054       0.088304       0.088304          00:10
# Better model found at epoch 11 with valid_loss value: 0.08778604940334969.
#              11       0.073732       0.087786       0.087786          00:10
#              12       0.073392       0.088032       0.088032          00:11
#              13       0.073005       0.087983       0.087983          00:10
#              14       0.072781       0.087811       0.087811          00:10
# Better model found at epoch 15 with valid_loss value: 0.08777860776776379.
#              15       0.072474       0.087779       0.087779          00:10
#              16       0.072436       0.087837       0.087837          00:10
#              17       0.072257       0.087780       0.087780          00:10
#              18       0.072222       0.087800       0.087800          00:10
# Better model found at epoch 19 with valid_loss value: 0.08774739805862454.
#              19       0.072218       0.087747       0.087747          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.024682993 rmse: 0.15710822 mae: 0.10014961
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00017073526474706903
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1249971195776546.
#               0       0.133181       0.124997       0.124997          00:02
# Better model found at epoch 1 with valid_loss value: 0.11994824576319671.
#               1       0.119267       0.119948       0.119948          00:02
# Better model found at epoch 2 with valid_loss value: 0.11877014309143613.
#               2       0.111460       0.118770       0.118770          00:02
#               3       0.107650       0.119207       0.119207          00:02
# Better model found at epoch 4 with valid_loss value: 0.11830684205591437.
#               4       0.106344       0.118307       0.118307          00:02
# Better model found at epoch 5 with valid_loss value: 0.11770928354162428.
#               5       0.105623       0.117709       0.117709          00:02
# Better model found at epoch 6 with valid_loss value: 0.117516831598988.
#               6       0.105057       0.117517       0.117517          00:02
# Better model found at epoch 7 with valid_loss value: 0.11717158814966436.
#               7       0.104569       0.117172       0.117172          00:02
# Better model found at epoch 8 with valid_loss value: 0.11683570110671786.
#               8       0.104193       0.116836       0.116836          00:02
#               9       0.103980       0.116849       0.116849          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11675266548324349.
#               0       0.103639       0.116753       0.116753          00:11
# Better model found at epoch 1 with valid_loss value: 0.11645505826001831.
#               1       0.102981       0.116455       0.116455          00:11
#               2       0.102099       0.116518       0.116518          00:11
# Better model found at epoch 3 with valid_loss value: 0.11643157785165785.
#               3       0.101127       0.116432       0.116432          00:11
#               4       0.099934       0.117073       0.117073          00:11
#               5       0.098560       0.117666       0.117666          00:06
#               6       0.097069       0.118268       0.118268          00:09
#               7       0.095469       0.118016       0.118016          00:06
#               8       0.093985       0.118373       0.118373          00:08
#               9       0.092644       0.118544       0.118544          00:06
#              10       0.091628       0.118132       0.118132          00:06
#              11       0.090528       0.118405       0.118405          00:06
#              12       0.089804       0.118664       0.118664          00:06
#              13       0.089067       0.118769       0.118769          00:06
#              14       0.088478       0.118531       0.118531          00:06
#              15       0.087997       0.118477       0.118477          00:06
#              16       0.087723       0.118838       0.118838          00:06
#              17       0.087395       0.118829       0.118829          00:06
#              18       0.087309       0.118607       0.118607          00:06
#              19       0.087190       0.118680       0.118680          00:06
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.041162055 rmse: 0.20288435 mae: 0.13904372
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00020565123083486514
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1268618687479417.
#               0       0.133961       0.126862       0.126862          00:02
# Better model found at epoch 1 with valid_loss value: 0.12434645247149267.
#               1       0.121860       0.124346       0.124346          00:02
# Better model found at epoch 2 with valid_loss value: 0.1238530455950004.
#               2       0.114679       0.123853       0.123853          00:02
# Better model found at epoch 3 with valid_loss value: 0.12375875416803886.
#               3       0.111635       0.123759       0.123759          00:02
# Better model found at epoch 4 with valid_loss value: 0.12316899556374011.
#               4       0.110673       0.123169       0.123169          00:02
#               5       0.110056       0.123187       0.123187          00:02
# Better model found at epoch 6 with valid_loss value: 0.12183816182089269.
#               6       0.109421       0.121838       0.121838          00:02
# Better model found at epoch 7 with valid_loss value: 0.12180398092736291.
#               7       0.108789       0.121804       0.121804          00:02
# Better model found at epoch 8 with valid_loss value: 0.12137432277408715.
#               8       0.108325       0.121374       0.121374          00:02
# Better model found at epoch 9 with valid_loss value: 0.12136462428474395.
#               9       0.108098       0.121365       0.121365          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12126196100117838.
#               0       0.107801       0.121262       0.121262          00:11
#               1       0.107105       0.121324       0.121324          00:11
# Better model found at epoch 2 with valid_loss value: 0.1207106043945795.
#               2       0.106178       0.120711       0.120711          00:11
#               3       0.104948       0.122257       0.122257          00:11
#               4       0.103307       0.123438       0.123438          00:11
#               5       0.101358       0.125350       0.125350          00:10
#               6       0.099244       0.124450       0.124450          00:11
#               7       0.097531       0.124085       0.124085          00:11
#               8       0.095905       0.125311       0.125311          00:06
#               9       0.094575       0.125117       0.125117          00:06
#              10       0.093363       0.125400       0.125400          00:06
#              11       0.092223       0.125649       0.125649          00:06
#              12       0.091403       0.125469       0.125469          00:06
#              13       0.090583       0.125351       0.125351          00:06
#              14       0.089935       0.125548       0.125548          00:06
#              15       0.089501       0.125244       0.125244          00:06
#              16       0.089061       0.125206       0.125206          00:06
#              17       0.088749       0.125496       0.125496          00:06
#              18       0.088558       0.125320       0.125320          00:06
#              19       0.088521       0.125525       0.125525          00:06
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.04315317 rmse: 0.20773341 mae: 0.14484137
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09105826812444708.
#               0       0.138595       0.091058       0.091058          00:02
# Better model found at epoch 1 with valid_loss value: 0.07549094570896835.
#               1       0.108294       0.075491       0.075491          00:02
# Better model found at epoch 2 with valid_loss value: 0.06778168613089613.
#               2       0.093328       0.067782       0.067782          00:02
# Better model found at epoch 3 with valid_loss value: 0.06416387314080847.
#               3       0.082956       0.064164       0.064164          00:02
# Better model found at epoch 4 with valid_loss value: 0.06320629761075981.
#               4       0.076976       0.063206       0.063206          00:02
# Better model found at epoch 5 with valid_loss value: 0.06217982313804387.
#               5       0.073716       0.062180       0.062180          00:02
# Better model found at epoch 6 with valid_loss value: 0.06167659480337432.
#               6       0.072057       0.061677       0.061677          00:02
# Better model found at epoch 7 with valid_loss value: 0.06136617649784613.
#               7       0.071198       0.061366       0.061366          00:02
#               8       0.070717       0.061399       0.061399          00:02
# Better model found at epoch 9 with valid_loss value: 0.06123924654205455.
#               9       0.070532       0.061239       0.061239          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.06025550256919032.
#               0       0.069879       0.060256       0.060256          00:10
# Better model found at epoch 1 with valid_loss value: 0.05889044349477743.
#               1       0.068650       0.058890       0.058890          00:10
# Better model found at epoch 2 with valid_loss value: 0.05769979161849566.
#               2       0.066616       0.057700       0.057700          00:10
# Better model found at epoch 3 with valid_loss value: 0.05670918033152546.
#               3       0.064353       0.056709       0.056709          00:11
# Better model found at epoch 4 with valid_loss value: 0.055825294665207296.
#               4       0.062215       0.055825       0.055825          00:10
# Better model found at epoch 5 with valid_loss value: 0.054887054624982404.
#               5       0.060328       0.054887       0.054887          00:10
# Better model found at epoch 6 with valid_loss value: 0.0541500332694125.
#               6       0.059057       0.054150       0.054150          00:10
# Better model found at epoch 7 with valid_loss value: 0.05366664111508766.
#               7       0.058055       0.053667       0.053667          00:11
# Better model found at epoch 8 with valid_loss value: 0.053211606697424904.
#               8       0.057315       0.053212       0.053212          00:11
# Better model found at epoch 9 with valid_loss value: 0.05293786151819105.
#               9       0.056686       0.052938       0.052938          00:10
# Better model found at epoch 10 with valid_loss value: 0.05284831154589985.
#              10       0.056242       0.052848       0.052848          00:10
# Better model found at epoch 11 with valid_loss value: 0.05259758340443793.
#              11       0.055914       0.052598       0.052598          00:11
# Better model found at epoch 12 with valid_loss value: 0.05244133850951775.
#              12       0.055567       0.052441       0.052441          00:11
# Better model found at epoch 13 with valid_loss value: 0.05225562159608985.
#              13       0.055291       0.052256       0.052256          00:07
#              14       0.055103       0.052264       0.052264          00:10
# Better model found at epoch 15 with valid_loss value: 0.052132687347004686.
#              15       0.054917       0.052133       0.052133          00:04
# Better model found at epoch 16 with valid_loss value: 0.05205820717764798.
#              16       0.054911       0.052058       0.052058          00:10
# Better model found at epoch 17 with valid_loss value: 0.05200821175651188.
#              17       0.054713       0.052008       0.052008          00:10
#              18       0.054637       0.052026       0.052026          00:10
#              19       0.054692       0.052015       0.052015          00:04
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.009623636 rmse: 0.09810013 mae: 0.05954538
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0992972564076485.
#               0       0.145507       0.099297       0.099297          00:02
# Better model found at epoch 1 with valid_loss value: 0.0892580906097437.
#               1       0.117754       0.089258       0.089258          00:02
# Better model found at epoch 2 with valid_loss value: 0.08473231142570178.
#               2       0.107213       0.084732       0.084732          00:02
# Better model found at epoch 3 with valid_loss value: 0.0827901916255594.
#               3       0.098887       0.082790       0.082790          00:02
# Better model found at epoch 4 with valid_loss value: 0.08210990042876576.
#               4       0.093625       0.082110       0.082110          00:02
# Better model found at epoch 5 with valid_loss value: 0.08126308109044447.
#               5       0.090465       0.081263       0.081263          00:02
# Better model found at epoch 6 with valid_loss value: 0.08082971161608778.
#               6       0.088609       0.080830       0.080830          00:02
# Better model found at epoch 7 with valid_loss value: 0.08048762173260782.
#               7       0.087719       0.080488       0.080488          00:02
# Better model found at epoch 8 with valid_loss value: 0.08031306317223098.
#               8       0.087250       0.080313       0.080313          00:02
# Better model found at epoch 9 with valid_loss value: 0.08024425584189382.
#               9       0.087086       0.080244       0.080244          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.07969867405220199.
#               0       0.086752       0.079699       0.079699          00:10
# Better model found at epoch 1 with valid_loss value: 0.07867816028020748.
#               1       0.085715       0.078678       0.078678          00:10
# Better model found at epoch 2 with valid_loss value: 0.0775528388648037.
#               2       0.084067       0.077553       0.077553          00:10
# Better model found at epoch 3 with valid_loss value: 0.0765343463546964.
#               3       0.082148       0.076534       0.076534          00:10
# Better model found at epoch 4 with valid_loss value: 0.07596977364250661.
#               4       0.080471       0.075970       0.075970          00:04
# Better model found at epoch 5 with valid_loss value: 0.07520335781758544.
#               5       0.078933       0.075203       0.075203          00:08
# Better model found at epoch 6 with valid_loss value: 0.07470602310217911.
#               6       0.077739       0.074706       0.074706          00:10
# Better model found at epoch 7 with valid_loss value: 0.07445454733268918.
#               7       0.076789       0.074455       0.074455          00:10
# Better model found at epoch 8 with valid_loss value: 0.07407523047351759.
#               8       0.075940       0.074075       0.074075          00:10
# Better model found at epoch 9 with valid_loss value: 0.07399848708299431.
#               9       0.075421       0.073998       0.073998          00:11
# Better model found at epoch 10 with valid_loss value: 0.0739230100850539.
#              10       0.074895       0.073923       0.073923          00:10
# Better model found at epoch 11 with valid_loss value: 0.07357747859349573.
#              11       0.074489       0.073577       0.073577          00:10
# Better model found at epoch 12 with valid_loss value: 0.07353219636772783.
#              12       0.074125       0.073532       0.073532          00:10
# Better model found at epoch 13 with valid_loss value: 0.07345310394311941.
#              13       0.073773       0.073453       0.073453          00:10
#              14       0.073598       0.073597       0.073597          00:10
#              15       0.073363       0.073475       0.073475          00:10
# Better model found at epoch 16 with valid_loss value: 0.07344043505104506.
#              16       0.073233       0.073440       0.073440          00:10
# Better model found at epoch 17 with valid_loss value: 0.0733886520100183.
#              17       0.073142       0.073389       0.073389          00:04
# Better model found at epoch 18 with valid_loss value: 0.07338567226276445.
#              18       0.073043       0.073386       0.073386          00:10
#              19       0.073089       0.073430       0.073430          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018682173 rmse: 0.13668275 mae: 0.08647464
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.10071355554940926.
#               0       0.144213       0.100714       0.100714          00:02
# Better model found at epoch 1 with valid_loss value: 0.09275536715405278.
#               1       0.119153       0.092755       0.092755          00:02
# Better model found at epoch 2 with valid_loss value: 0.0896098103767444.
#               2       0.108907       0.089610       0.089610          00:02
# Better model found at epoch 3 with valid_loss value: 0.08771811249266734.
#               3       0.100759       0.087718       0.087718          00:02
# Better model found at epoch 4 with valid_loss value: 0.08701802226556068.
#               4       0.095863       0.087018       0.087018          00:02
# ...
#               3       0.080335       0.067449       0.067449          00:02
# Better model found at epoch 4 with valid_loss value: 0.06624441406092921.
#               4       0.076376       0.066244       0.066244          00:02
# Better model found at epoch 5 with valid_loss value: 0.06546701839619441.
#               5       0.074921       0.065467       0.065467          00:02
#               6       0.074158       0.065719       0.065719          00:02
# Better model found at epoch 7 with valid_loss value: 0.06532537697480195.
#               7       0.073712       0.065325       0.065325          00:02
# Better model found at epoch 8 with valid_loss value: 0.0649034519450197.
#               8       0.073287       0.064903       0.064903          00:02
# Better model found at epoch 9 with valid_loss value: 0.06489203914638039.
#               9       0.073106       0.064892       0.064892          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.06318487100170149.
#               0       0.072308       0.063185       0.063185          00:11
# Better model found at epoch 1 with valid_loss value: 0.061304778095531906.
#               1       0.069755       0.061305       0.061305          00:11
# Better model found at epoch 2 with valid_loss value: 0.06001853359959335.
#               2       0.066952       0.060019       0.060019          00:10
# Better model found at epoch 3 with valid_loss value: 0.058516943092340054.
#               3       0.064408       0.058517       0.058517          00:10
# Better model found at epoch 4 with valid_loss value: 0.05766011434907562.
#               4       0.062479       0.057660       0.057660          00:10
# Better model found at epoch 5 with valid_loss value: 0.05725924286482628.
#               5       0.061006       0.057259       0.057259          00:10
# Better model found at epoch 6 with valid_loss value: 0.056558796460938754.
#               6       0.059924       0.056559       0.056559          00:07
# Better model found at epoch 7 with valid_loss value: 0.0565239690173491.
#               7       0.059129       0.056524       0.056524          00:10
# Better model found at epoch 8 with valid_loss value: 0.05605261797918007.
#               8       0.058549       0.056053       0.056053          00:10
# Better model found at epoch 9 with valid_loss value: 0.055562122891680575.
#               9       0.057990       0.055562       0.055562          00:10
#              10       0.057643       0.055579       0.055579          00:10
# Better model found at epoch 11 with valid_loss value: 0.05517908973442275.
#              11       0.057157       0.055179       0.055179          00:10
# Better model found at epoch 12 with valid_loss value: 0.05495174187679699.
#              12       0.056788       0.054952       0.054952          00:10
#              13       0.056508       0.055012       0.055012          00:10
# Better model found at epoch 14 with valid_loss value: 0.05458979171745566.
#              14       0.056184       0.054590       0.054590          00:04
#              15       0.055922       0.054596       0.054596          00:10
# Better model found at epoch 16 with valid_loss value: 0.054549937733734115.
#              16       0.055789       0.054550       0.054550          00:08
# Better model found at epoch 17 with valid_loss value: 0.054463293729956674.
#              17       0.055680       0.054463       0.054463          00:10
# Better model found at epoch 18 with valid_loss value: 0.05440459512947111.
#              18       0.055573       0.054405       0.054405          00:10
#              19       0.055577       0.054421       0.054421          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.010212783 rmse: 0.10105831 mae: 0.0581181
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0991486464796074.
#               0       0.151360       0.099149       0.099149          00:02
# Better model found at epoch 1 with valid_loss value: 0.0897576353043633.
#               1       0.121981       0.089758       0.089758          00:02
# Better model found at epoch 2 with valid_loss value: 0.08680761599560109.
#               2       0.108153       0.086808       0.086808          00:02
# Better model found at epoch 3 with valid_loss value: 0.08498864914946094.
#               3       0.098223       0.084989       0.084989          00:02
# Better model found at epoch 4 with valid_loss value: 0.08463946250127136.
#               4       0.093160       0.084639       0.084639          00:02
# Better model found at epoch 5 with valid_loss value: 0.08377662702146053.
#               5       0.090888       0.083777       0.083777          00:02
# Better model found at epoch 6 with valid_loss value: 0.08353269497876831.
#               6       0.089852       0.083533       0.083533          00:02
# Better model found at epoch 7 with valid_loss value: 0.083136502817649.
#               7       0.089244       0.083137       0.083136          00:02
# Better model found at epoch 8 with valid_loss value: 0.08296476011842707.
#               8       0.088835       0.082965       0.082965          00:02
# Better model found at epoch 9 with valid_loss value: 0.08294092214039615.
#               9       0.088610       0.082941       0.082941          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08226489198217556.
#               0       0.088106       0.082265       0.082265          00:11
# Better model found at epoch 1 with valid_loss value: 0.08117013284110558.
#               1       0.086630       0.081170       0.081170          00:10
# Better model found at epoch 2 with valid_loss value: 0.07976517704466284.
#               2       0.084488       0.079765       0.079765          00:10
# Better model found at epoch 3 with valid_loss value: 0.07897457560453112.
#               3       0.082265       0.078975       0.078975          00:11
# Better model found at epoch 4 with valid_loss value: 0.07812309296175753.
#               4       0.080597       0.078123       0.078123          00:11
# Better model found at epoch 5 with valid_loss value: 0.07781131704034022.
#               5       0.079204       0.077811       0.077811          00:10
# Better model found at epoch 6 with valid_loss value: 0.07764775374733014.
#               6       0.078016       0.077648       0.077648          00:10
#               7       0.077229       0.077770       0.077770          00:11
#               8       0.076442       0.077902       0.077902          00:11
# Better model found at epoch 9 with valid_loss value: 0.07699665414113355.
#               9       0.075888       0.076997       0.076997          00:11
#              10       0.075280       0.077185       0.077185          00:11
#              11       0.074785       0.077073       0.077073          00:10
# Better model found at epoch 12 with valid_loss value: 0.07696525257132324.
#              12       0.074321       0.076965       0.076965          00:11
#              13       0.073872       0.077122       0.077122          00:11
#              14       0.073644       0.077111       0.077111          00:11
# Better model found at epoch 15 with valid_loss value: 0.07685626334926769.
#              15       0.073426       0.076856       0.076856          00:10
#              16       0.073214       0.076981       0.076981          00:10
#              17       0.073092       0.076865       0.076865          00:10
# Better model found at epoch 18 with valid_loss value: 0.07684062464243033.
#              18       0.072937       0.076841       0.076841          00:10
#              19       0.072892       0.076920       0.076920          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.01917157 rmse: 0.13846144 mae: 0.08216856
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 5.590810182512223e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.10482808688945949.
#               0       0.159380       0.104828       0.104828          00:02
# Better model found at epoch 1 with valid_loss value: 0.09512628096441215.
#               1       0.128497       0.095126       0.095126          00:02
# Better model found at epoch 2 with valid_loss value: 0.09167352830600095.
#               2       0.117761       0.091674       0.091674          00:02
# Better model found at epoch 3 with valid_loss value: 0.0898252273928917.
#               3       0.109140       0.089825       0.089825          00:02
# Better model found at epoch 4 with valid_loss value: 0.0887374689487537.
#               4       0.103062       0.088737       0.088737          00:02
# Better model found at epoch 5 with valid_loss value: 0.08836539871665569.
#               5       0.099130       0.088365       0.088365          00:02
# Better model found at epoch 6 with valid_loss value: 0.08794052448143937.
#               6       0.096840       0.087941       0.087941          00:02
# Better model found at epoch 7 with valid_loss value: 0.08758579092718281.
#               7       0.095528       0.087586       0.087586          00:02
# Better model found at epoch 8 with valid_loss value: 0.08740885631071958.
#               8       0.094896       0.087409       0.087409          00:02
# Better model found at epoch 9 with valid_loss value: 0.087356775925459.
#               9       0.094685       0.087357       0.087357          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08715418302579038.
#               0       0.094284       0.087154       0.087154          00:10
# Better model found at epoch 1 with valid_loss value: 0.0866700022769842.
#               1       0.093237       0.086670       0.086670          00:07
# Better model found at epoch 2 with valid_loss value: 0.085715520171893.
#               2       0.091260       0.085716       0.085716          00:09
# Better model found at epoch 3 with valid_loss value: 0.0847902440875597.
#               3       0.088922       0.084790       0.084790          00:10
# Better model found at epoch 4 with valid_loss value: 0.08440115878555697.
#               4       0.086829       0.084401       0.084401          00:10
# Better model found at epoch 5 with valid_loss value: 0.08385516901140293.
#               5       0.085172       0.083855       0.083855          00:11
# Better model found at epoch 6 with valid_loss value: 0.08350425455139553.
#               6       0.083943       0.083504       0.083504          00:10
# Better model found at epoch 7 with valid_loss value: 0.08312103859423885.
#               7       0.083005       0.083121       0.083121          00:10
#               8       0.082224       0.083443       0.083443          00:10
# Better model found at epoch 9 with valid_loss value: 0.08288309394714566.
#               9       0.081555       0.082883       0.082883          00:10
#              10       0.080953       0.082971       0.082971          00:10
#              11       0.080473       0.082941       0.082941          00:10
# Better model found at epoch 12 with valid_loss value: 0.08280747588101278.
#              12       0.080070       0.082807       0.082807          00:07
# Better model found at epoch 13 with valid_loss value: 0.08266884778489317.
#              13       0.079807       0.082669       0.082669          00:10
# Better model found at epoch 14 with valid_loss value: 0.08265173221250824.
#              14       0.079561       0.082652       0.082652          00:10
# Better model found at epoch 15 with valid_loss value: 0.08255950611151562.
#              15       0.079383       0.082560       0.082559          00:10
#              16       0.079223       0.082628       0.082628          00:05
# Better model found at epoch 17 with valid_loss value: 0.08252354632408561.
#              17       0.079145       0.082524       0.082524          00:10
#              18       0.079092       0.082559       0.082559          00:10
#              19       0.079061       0.082585       0.082585          00:04
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.020497167 rmse: 0.14316832 mae: 0.08738728
# ----------- Complete! -----------
# Total time: 01h:03m:23.45s

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup.columns = pd.MultiIndex.from_product([['Self-supervised'], ['MSE','RMSE', 'MAE']], names=['Model', 'Metrics'])

# Path if not exists
path = "results/patchtst/"
if not os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results.csv"), index=True)
df_self_sup.round(4)
# Out:
# Model            Self-supervised
# Metrics                      MSE    RMSE     MAE
# Country Pred_len
# DE      24                0.0210  0.1451  0.0883
#         96                0.0353  0.1879  0.1262
#         168               0.0379  0.1948  0.1314
# GB      24                0.0247  0.1571  0.1001
#         96                0.0412  0.2029  0.1390
#         168               0.0432  0.2077  0.1448
# ES      24                0.0096  0.0981  0.0595
#         96                0.0187  0.1367  0.0865
#         168               0.0214  0.1463  0.0940
# FR      24                0.0100  0.0999  0.0547
#         96                0.0197  0.1404  0.0809
#         168               0.0218  0.1475  0.0872
# IT      24                0.0102  0.1011  0.0581
#         96                0.0192  0.1385  0.0822
#         168               0.0205  0.1432  0.0874
