# %% [markdown]
# <details>
# <summary>Table of Contents</summary>
#
# - [1. Pretrain](#1-pretrain)
# - [2. Finetune](#2-finetune)
#
# </details>
#
#
#
# This notebook demonstrates experiments on 5 countries with self-supervised learning.
# All parameters and settings are taken from the paper.

# %%
import pandas as pd
import subprocess
import os
from utils.helper import extract_metrics_from_output

# %% [markdown]
# # 1. Pretrain
#
# Tracking loss - MAE.

# %%
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Execute the command
        print(f"==========Running command for {country}, pred_len {pred_len}:==========")
        # !{command}
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00035938136638046257
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9651524109799743.
#               0       0.982107       0.965152          00:17
# Better model found at epoch 1 with valid_loss value: 0.9606560137526138.
#               1       0.965265       0.960656          00:10
# Better model found at epoch 2 with valid_loss value: 0.9603071404515844.
#               2       0.961556       0.960307          00:17
# Better model found at epoch 3 with valid_loss value: 0.9592228214975068.
#               3       0.959726       0.959223          00:17
# Better model found at epoch 4 with valid_loss value: 0.9582095809624819.
#               4       0.959612       0.958210          00:17
#               5       0.958652       0.959139          00:17
#               6       0.957142       0.958400          00:17
#               7       0.958461       0.958951          00:16
#               8       0.957441       0.958606          00:07
# Better model found at epoch 9 with valid_loss value: 0.8420295881001689.
#               9       0.947880       0.842030          00:10
# Better model found at epoch 10 with valid_loss value: 0.8205353956389738.
#              10       0.836203       0.820535          00:17
# Better model found at epoch 11 with valid_loss value: 0.8185005108221409.
#              11       0.827645       0.818501          00:17
# Better model found at epoch 12 with valid_loss value: 0.8084630599565706.
#              12       0.821739       0.808463          00:17
# Better model found at epoch 13 with valid_loss value: 0.7518792191521232.
#              13       0.785067       0.751879          00:17
# Better model found at epoch 14 with valid_loss value: 0.6507104778857367.
#              14       0.710951       0.650710          00:17
# Better model found at epoch 15 with valid_loss value: 0.638151942255107.
#              15       0.663763       0.638152          00:17
# Better model found at epoch 16 with valid_loss value: 0.6284738497391226.
#              16       0.645683       0.628474          00:17
# Better model found at epoch 17 with valid_loss value: 0.6267899980647821.
#              17       0.635517       0.626790          00:17
# Better model found at epoch 18 with valid_loss value: 0.618062471411553.
#              18       0.626919       0.618062          00:17
# Better model found at epoch 19 with valid_loss value: 0.569692036452469.
#              19       0.610329       0.569692          00:17
# Better model found at epoch 20 with valid_loss value: 0.5568143547933087.
#              20       0.574726       0.556814          00:17
# Better model found at epoch 21 with valid_loss value: 0.5513286323663945.
#              21       0.560063       0.551329          00:09
# Better model found at epoch 22 with valid_loss value: 0.5480499537558308.
#              22       0.552063       0.548050          00:15
# Better model found at epoch 23 with valid_loss value: 0.5431656097318843.
#              23       0.546112       0.543166          00:18
# Better model found at epoch 24 with valid_loss value: 0.542383354423858.
#              24       0.541150       0.542383          00:17
#              25       0.537708       0.544204          00:17
#              26       0.534254       0.546801          00:17
#              27       0.532823       0.543616          00:17
#              28       0.529857       0.546885          00:13
#              29       0.527991       0.549657          00:17
# No improvement since epoch 24: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00011768119524349978
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.980289329485354.
#               0       0.994485       0.980289          00:07
# Better model found at epoch 1 with valid_loss value: 0.9674958839757933.
#               1       0.976495       0.967496          00:11
# Better model found at epoch 2 with valid_loss value: 0.9656419249644019.
#               2       0.969565       0.965642          00:17
# Better model found at epoch 3 with valid_loss value: 0.962409256763629.
#               3       0.966544       0.962409          00:17
# Better model found at epoch 4 with valid_loss value: 0.9593428187296582.
#               4       0.963832       0.959343          00:17
#               5       0.961110       0.959830          00:17
#               6       0.960801       0.960814          00:16
# Better model found at epoch 7 with valid_loss value: 0.9579801604454842.
#               7       0.959942       0.957980          00:13
# Better model found at epoch 8 with valid_loss value: 0.9569105503712367.
#               8       0.959079       0.956911          00:17
# Better model found at epoch 9 with valid_loss value: 0.9565950150020341.
#               9       0.958292       0.956595          00:17
#              10       0.958542       0.957660          00:17
#              11       0.957764       0.957743          00:17
#              12       0.957501       0.958847          00:17
#              13       0.957444       0.957850          00:17
#              14       0.957051       0.957221          00:17
# Better model found at epoch 15 with valid_loss value: 0.8298721648698129.
#              15       0.898845       0.829872          00:17
# Better model found at epoch 16 with valid_loss value: 0.8209762287683076.
#              16       0.835426       0.820976          00:17
# Better model found at epoch 17 with valid_loss value: 0.8162889671480879.
#              17       0.827512       0.816289          00:17
# Better model found at epoch 18 with valid_loss value: 0.8160159428397071.
#              18       0.825556       0.816016          00:17
# Better model found at epoch 19 with valid_loss value: 0.8148417635018308.
#              19       0.824186       0.814842          00:17
#              20       0.821408       0.815111          00:17
# Better model found at epoch 21 with valid_loss value: 0.7917511855421074.
#              21       0.808475       0.791751          00:17
# Better model found at epoch 22 with valid_loss value: 0.7757236415530919.
#              22       0.787426       0.775724          00:17
# Better model found at epoch 23 with valid_loss value: 0.742420794344996.
#              23       0.764374       0.742421          00:17
# Better model found at epoch 24 with valid_loss value: 0.6913806639035801.
#              24       0.732291       0.691381          00:17
# Better model found at epoch 25 with valid_loss value: 0.6624621373448942.
#              25       0.700672       0.662462          00:17
# Better model found at epoch 26 with valid_loss value: 0.6537527731514443.
#              26       0.679297       0.653753          00:17
# Better model found at epoch 27 with valid_loss value: 0.6446907260730268.
#              27       0.662719       0.644691          00:17
# Better model found at epoch 28 with valid_loss value: 0.6418309633085842.
#              28       0.651417       0.641831          00:17
# Better model found at epoch 29 with valid_loss value: 0.6371973768688974.
#              29       0.643216       0.637197          00:17
# Better model found at epoch 30 with valid_loss value: 0.625625270163751.
#              30       0.634897       0.625625          00:17
# Better model found at epoch 31 with valid_loss value: 0.5997628518485557.
#              31       0.624292       0.599763          00:17
# Better model found at epoch 32 with valid_loss value: 0.5722083343927991.
#              32       0.601013       0.572208          00:17
# Better model found at epoch 33 with valid_loss value: 0.565672278656428.
#              33       0.583481       0.565672          00:17
# Better model found at epoch 34 with valid_loss value: 0.560136226098454.
#              34       0.574563       0.560136          00:17
# Better model found at epoch 35 with valid_loss value: 0.5579758696094386.
#              35       0.567623       0.557976          00:17
# Better model found at epoch 36 with valid_loss value: 0.552640334176668.
#              36       0.562646       0.552640          00:17
# Better model found at epoch 37 with valid_loss value: 0.5508418779241253.
#              37       0.558717       0.550842          00:17
# Better model found at epoch 38 with valid_loss value: 0.5481516826434093.
#              38       0.554999       0.548152          00:17
# Better model found at epoch 39 with valid_loss value: 0.5472681677176566.
#              39       0.551405       0.547268          00:17
#              40       0.549011       0.548034          00:17
# Better model found at epoch 41 with valid_loss value: 0.5456391994889137.
#              41       0.546528       0.545639          00:17
# Better model found at epoch 42 with valid_loss value: 0.5450374494634865.
#              42       0.544716       0.545037          00:17
# Better model found at epoch 43 with valid_loss value: 0.5446564391146257.
#              43       0.542367       0.544656          00:17
# Better model found at epoch 44 with valid_loss value: 0.5425639414030716.
#              44       0.541013       0.542564          00:17
#              45       0.539260       0.543381          00:17
# Better model found at epoch 46 with valid_loss value: 0.5420112976123881.
#              46       0.537927       0.542011          00:17
#              47       0.536472       0.542053          00:17
# Better model found at epoch 48 with valid_loss value: 0.5419029142722742.
#              48       0.535934       0.541903          00:17
#              49       0.534419       0.542274          00:17
# Better model found at epoch 50 with valid_loss value: 0.5415747447747152.
#              50       0.532954       0.541575          00:17
#              51       0.531788       0.545020          00:17
#              52       0.531320       0.542344          00:16
# Better model found at epoch 53 with valid_loss value: 0.5410072022477624.
#              53       0.530507       0.541007          00:17
#              54       0.530016       0.546391          00:17
#              55       0.529546       0.545227          00:17
#              56       0.528750       0.544966          00:17
#              57       0.528137       0.543512          00:08
#              58       0.526992       0.544372          00:07
# No improvement since epoch 53: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9686896985118557.
#               0       0.986142       0.968690          00:17
# Better model found at epoch 1 with valid_loss value: 0.9629116903198583.
#               1       0.968895       0.962912          00:12
# Better model found at epoch 2 with valid_loss value: 0.961381881766631.
#               2       0.963589       0.961382          00:08
#               3       0.961618       0.961574          00:17
# Better model found at epoch 4 with valid_loss value: 0.9594381637987814.
#               4       0.960994       0.959438          00:17
# Better model found at epoch 5 with valid_loss value: 0.957855611543924.
#               5       0.959550       0.957856          00:17
#               6       0.958973       0.958784          00:17
# Better model found at epoch 7 with valid_loss value: 0.9576626467818623.
#               7       0.958728       0.957663          00:17
# Better model found at epoch 8 with valid_loss value: 0.9576348276953318.
#               8       0.957733       0.957635          00:17
# Better model found at epoch 9 with valid_loss value: 0.9570930791258438.
#               9       0.957016       0.957093          00:17
# Better model found at epoch 10 with valid_loss value: 0.9566432300242879.
#              10       0.957122       0.956643          00:17
# Better model found at epoch 11 with valid_loss value: 0.8292983865573028.
#              11       0.923927       0.829298          00:17
# Better model found at epoch 12 with valid_loss value: 0.8196975052229128.
#              12       0.834666       0.819698          00:17
# Better model found at epoch 13 with valid_loss value: 0.817282872833649.
#              13       0.826378       0.817283          00:16
# Better model found at epoch 14 with valid_loss value: 0.8172534457074345.
#              14       0.822624       0.817253          00:09
# Better model found at epoch 15 with valid_loss value: 0.7938985989471843.
#              15       0.814148       0.793899          00:09
# Better model found at epoch 16 with valid_loss value: 0.7512435774895028.
#              16       0.782903       0.751244          00:17
# Better model found at epoch 17 with valid_loss value: 0.6852494680604726.
#              17       0.730408       0.685249          00:17
# Better model found at epoch 18 with valid_loss value: 0.6533522722887164.
#              18       0.686389       0.653352          00:17
# Better model found at epoch 19 with valid_loss value: 0.6418193312741849.
#              19       0.660004       0.641819          00:17
# Better model found at epoch 20 with valid_loss value: 0.6353505896359912.
#              20       0.645788       0.635351          00:17
# Better model found at epoch 21 with valid_loss value: 0.6292851845514984.
#              21       0.635455       0.629285          00:17
# Better model found at epoch 22 with valid_loss value: 0.6052569309726453.
#              22       0.622921       0.605257          00:17
# Better model found at epoch 23 with valid_loss value: 0.5650136474327968.
#              23       0.593717       0.565014          00:17
# Better model found at epoch 24 with valid_loss value: 0.5577912577957764.
#              24       0.571767       0.557791          00:17
# Better model found at epoch 25 with valid_loss value: 0.5543970478321052.
#              25       0.563008       0.554397          00:17
# Better model found at epoch 26 with valid_loss value: 0.5488877028702865.
#              26       0.555848       0.548888          00:17
# Better model found at epoch 27 with valid_loss value: 0.5452430407258563.
#              27       0.550197       0.545243          00:16
# Better model found at epoch 28 with valid_loss value: 0.5451159653898403.
#              28       0.545963       0.545116          00:17
# Better model found at epoch 29 with valid_loss value: 0.5424042878699777.
#              29       0.541428       0.542404          00:17
#              30       0.539174       0.544842          00:17
#              31       0.536389       0.544496          00:17
#              32       0.534499       0.544881          00:17
#              33       0.532726       0.544545          00:17
#              34       0.531127       0.545714          00:17
# No improvement since epoch 29: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9652349561937027.
#               0       0.982681       0.965235          00:12
# Better model found at epoch 1 with valid_loss value: 0.9605622373632781.
#               1       0.965836       0.960562          00:17
# Better model found at epoch 2 with valid_loss value: 0.9598187806618949.
#               2       0.960997       0.959819          00:17
#               3       0.958867       0.960705          00:17
# Better model found at epoch 4 with valid_loss value: 0.9590834135485363.
#               4       0.958300       0.959083          00:17
# ^C
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9661083547345403.
#               0       0.984988       0.966108          00:17
# Better model found at epoch 1 with valid_loss value: 0.9622086999084621.
#               1       0.967587       0.962209          00:17
# Better model found at epoch 2 with valid_loss value: 0.959558234591131.
#               2       0.962852       0.959558          00:17
# Better model found at epoch 3 with valid_loss value: 0.9590570808329943.
#               3       0.960226       0.959057          00:17
#               4       0.959454       0.961031          00:17
# Better model found at epoch 5 with valid_loss value: 0.957900144299227.
#               5       0.957255       0.957900          00:17
#               6       0.956359       0.958810          00:17
#               7       0.956992       0.959380          00:17
# Better model found at epoch 8 with valid_loss value: 0.9566564375254272.
#               8       0.955815       0.956656          00:17
#               9       0.955633       0.957825          00:17
#              10       0.955539       0.958077          00:17
# Better model found at epoch 11 with valid_loss value: 0.8290142360404801.
#              11       0.927312       0.829014          00:17
# Better model found at epoch 12 with valid_loss value: 0.8186403453010578.
#              12       0.824214       0.818640          00:17
# Better model found at epoch 13 with valid_loss value: 0.815769219767087.
#              13       0.815606       0.815769          00:17
# Better model found at epoch 14 with valid_loss value: 0.8146064031987388.
#              14       0.812537       0.814606          00:14
# ^C
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404

# %% [markdown]
# # 2. Finetune
#
# Linear probing + full fine-tuning.

# %%
# 2 hrs
# In case you just want finetune, please uncomment below
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

# List to store metrics for the DataFrame
data = []

for country in countries:
    for pred_len in pred_lens:
        # Define the parameters for each country and pred_len
        params = {
            "--dset": country,
            "--is_finetune": 1,
            "--pretrained_model": f"saved_models/{country}/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth",
            "--scaler_type": "minmax",
            "--n_epochs_finetune": 20,
            "--target_points": pred_len  
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        print(f"==========Running command for {country}, pred_len {pred_len}:==========")

        # Run the command and capture the output
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Capture the output in real-time
        output = []
        for line in process.stdout:
            output.append(line)
            print(line, end='')  # Print in the .ipynb cell

        # Wait for the process to complete
        process.stdout.close()
        process.wait()

        try:
            # Extract metrics from the output using the function
            metrics = extract_metrics_from_output(output, if_supervised=False)
            mse, rmse, mae = metrics[0]

            # Append the results to the data list
            data.append({
                'Country': country,
                'Pred_len': pred_len,
                'MSE': mse,
                'RMSE': rmse,
                'MAE': mae
            })
        except ValueError as e:
            print(f"\nError: {e} for {country}, pred_len {pred_len}")
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00017073526474706903
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11805084753749799.
#               0       0.137983       0.118051       0.118051          00:03
# Better model found at epoch 1 with valid_loss value: 0.09970743180241676.
#               1       0.108147       0.099707       0.099707          00:03
# Better model found at epoch 2 with valid_loss value: 0.09648143368862594.
#               2       0.093195       0.096481       0.096481          00:03
# Better model found at epoch 3 with valid_loss value: 0.09525588073779556.
#               3       0.088129       0.095256       0.095256          00:03
# Better model found at epoch 4 with valid_loss value: 0.09469150434607226.
#               4       0.086795       0.094692       0.094692          00:03
# Better model found at epoch 5 with valid_loss value: 0.0942099578744521.
#               5       0.086168       0.094210       0.094210          00:03
# Better model found at epoch 6 with valid_loss value: 0.09356551026922148.
#               6       0.085704       0.093566       0.093566          00:03
# Better model found at epoch 7 with valid_loss value: 0.09334743500369451.
#               7       0.085165       0.093347       0.093347          00:03
# Better model found at epoch 8 with valid_loss value: 0.09271705582035648.
#               8       0.084776       0.092717       0.092717          00:03
#               9       0.084552       0.092771       0.092771          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09143736938849625.
#               0       0.083692       0.091437       0.091437          00:07
# Better model found at epoch 1 with valid_loss value: 0.09029276140521957.
#               1       0.081621       0.090293       0.090293          00:07
# Better model found at epoch 2 with valid_loss value: 0.0890750035185781.
#               2       0.079305       0.089075       0.089075          00:07
# Better model found at epoch 3 with valid_loss value: 0.08876748136410247.
#               3       0.077420       0.088767       0.088767          00:07
# Better model found at epoch 4 with valid_loss value: 0.08807585104036815.
#               4       0.076038       0.088076       0.088076          00:07
# Better model found at epoch 5 with valid_loss value: 0.08733402403754323.
#               5       0.075128       0.087334       0.087334          00:07
# Better model found at epoch 6 with valid_loss value: 0.08717802457915293.
#               6       0.074239       0.087178       0.087178          00:07
# Better model found at epoch 7 with valid_loss value: 0.08692045366723802.
#               7       0.073632       0.086920       0.086920          00:07
# Better model found at epoch 8 with valid_loss value: 0.08665235843692194.
#               8       0.072898       0.086652       0.086652          00:07
# Better model found at epoch 9 with valid_loss value: 0.08641004385970424.
#               9       0.072332       0.086410       0.086410          00:07
#              10       0.071839       0.086662       0.086662          00:07
# Better model found at epoch 11 with valid_loss value: 0.08609755406986389.
#              11       0.071400       0.086098       0.086098          00:07
# Better model found at epoch 12 with valid_loss value: 0.08608308313206228.
#              12       0.070919       0.086083       0.086083          00:07
# Better model found at epoch 13 with valid_loss value: 0.08597417803502493.
#              13       0.070430       0.085974       0.085974          00:07
# Better model found at epoch 14 with valid_loss value: 0.08596104227194587.
#              14       0.070172       0.085961       0.085961          00:07
# Better model found at epoch 15 with valid_loss value: 0.0857509878722153.
#              15       0.069880       0.085751       0.085751          00:07
#              16       0.069698       0.085773       0.085773          00:07
# Better model found at epoch 17 with valid_loss value: 0.08566941458714512.
#              17       0.069457       0.085669       0.085669          00:07
#              18       0.069453       0.085745       0.085745          00:07
#              19       0.069351       0.085754       0.085754          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.02098319 rmse: 0.14485575 mae: 0.08839449
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00014174741629268049
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.13211976835842149.
#               0       0.147188       0.132120       0.132120          00:03
# Better model found at epoch 1 with valid_loss value: 0.12463227932389137.
#               1       0.128616       0.124632       0.124632          00:03
# Better model found at epoch 2 with valid_loss value: 0.12289981454053092.
#               2       0.118069       0.122900       0.122900          00:03
# Better model found at epoch 3 with valid_loss value: 0.12218827076128967.
#               3       0.112646       0.122188       0.122188          00:03
# Better model found at epoch 4 with valid_loss value: 0.12196183976746847.
#               4       0.110599       0.121962       0.121962          00:03
# Better model found at epoch 5 with valid_loss value: 0.12085217195763832.
#               5       0.109734       0.120852       0.120852          00:03
#               6       0.109204       0.121348       0.121348          00:03
# Better model found at epoch 7 with valid_loss value: 0.12052519435898087.
#               7       0.108714       0.120525       0.120525          00:03
# Better model found at epoch 8 with valid_loss value: 0.12035467335613304.
#               8       0.108405       0.120355       0.120355          00:03
#               9       0.108223       0.120433       0.120433          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11991623334519935.
#               0       0.107742       0.119916       0.119916          00:07
# Better model found at epoch 1 with valid_loss value: 0.11883646233281632.
#               1       0.106474       0.118836       0.118836          00:07
# Better model found at epoch 2 with valid_loss value: 0.11789137589630798.
#               2       0.104900       0.117891       0.117891          00:07
#               3       0.103309       0.118110       0.118110          00:07
#               4       0.101726       0.118438       0.118438          00:07
#               5       0.100306       0.119789       0.119789          00:07
#               6       0.098834       0.118726       0.118726          00:07
#               7       0.097508       0.119030       0.119030          00:07
#               8       0.096339       0.119963       0.119963          00:07
#               9       0.095210       0.119241       0.119241          00:07
#              10       0.094383       0.119297       0.119297          00:07
#              11       0.093561       0.119546       0.119546          00:07
#              12       0.092944       0.119759       0.119759          00:07
#              13       0.092233       0.119773       0.119773          00:07
#              14       0.091814       0.119460       0.119460          00:07
#              15       0.091457       0.119438       0.119438          00:07
#              16       0.091077       0.119343       0.119343          00:07
#              17       0.090977       0.119554       0.119554          00:07
#              18       0.090745       0.119474       0.119474          00:07
#              19       0.090791       0.119504       0.119504          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.0350436 rmse: 0.18719935 mae: 0.12525234
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1356350820068078.
#               0       0.153235       0.135635       0.135635          00:03
# Better model found at epoch 1 with valid_loss value: 0.1304676263822709.
#               1       0.136118       0.130468       0.130468          00:03
# Better model found at epoch 2 with valid_loss value: 0.12747851176570477.
#               2       0.127702       0.127479       0.127478          00:03
# Better model found at epoch 3 with valid_loss value: 0.1261462508876379.
#               3       0.121639       0.126146       0.126146          00:03
#               4       0.118092       0.126491       0.126491          00:03
# Better model found at epoch 5 with valid_loss value: 0.12534716571749444.
#               5       0.116157       0.125347       0.125347          00:03
# Better model found at epoch 6 with valid_loss value: 0.12505520601239606.
#               6       0.115143       0.125055       0.125055          00:03
# Better model found at epoch 7 with valid_loss value: 0.1249099095767125.
#               7       0.114540       0.124910       0.124910          00:03
# Better model found at epoch 8 with valid_loss value: 0.12469188954632698.
#               8       0.114196       0.124692       0.124692          00:03
# Better model found at epoch 9 with valid_loss value: 0.12468793979885354.
#               9       0.114079       0.124688       0.124688          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12439507557143298.
#               0       0.113754       0.124395       0.124395          00:07
# Better model found at epoch 1 with valid_loss value: 0.12386024157258563.
#               1       0.112832       0.123860       0.123860          00:07
# Better model found at epoch 2 with valid_loss value: 0.12291969916150379.
#               2       0.111499       0.122920       0.122920          00:07
# Better model found at epoch 3 with valid_loss value: 0.12242542796368146.
#               3       0.109984       0.122425       0.122425          00:07
# Better model found at epoch 4 with valid_loss value: 0.1221531265437181.
#               4       0.108554       0.122153       0.122153          00:07
#               5       0.107245       0.122531       0.122531          00:07
#               6       0.105999       0.122522       0.122522          00:07
#               7       0.104829       0.122872       0.122872          00:07
#               8       0.103861       0.122637       0.122637          00:07
#               9       0.102965       0.123153       0.123153          00:07
#              10       0.102176       0.123231       0.123231          00:07
#              11       0.101567       0.123226       0.123226          00:07
#              12       0.100962       0.123312       0.123312          00:07
#              13       0.100486       0.122928       0.122928          00:07
#              14       0.100106       0.123074       0.123074          00:07
#              15       0.099839       0.123105       0.123105          00:07
#              16       0.099617       0.123126       0.123126          00:07
#              17       0.099513       0.123170       0.123170          00:07
#              18       0.099404       0.123200       0.123200          00:07
#              19       0.099322       0.123101       0.123101          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.037925854 rmse: 0.19474562 mae: 0.13131142
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11691121700704721.
#               0       0.132001       0.116911       0.116911          00:03
# Better model found at epoch 1 with valid_loss value: 0.10035964501945271.
#               1       0.107917       0.100360       0.100360          00:03
# Better model found at epoch 2 with valid_loss value: 0.09610320617862313.
#               2       0.094830       0.096103       0.096103          00:03
# Better model found at epoch 3 with valid_loss value: 0.09479773909366455.
#               3       0.088886       0.094798       0.094798          00:03
# Better model found at epoch 4 with valid_loss value: 0.09476943535303904.
#               4       0.086182       0.094769       0.094769          00:03
# Better model found at epoch 5 with valid_loss value: 0.09413233120878237.
#               5       0.084940       0.094132       0.094132          00:03
# Better model found at epoch 6 with valid_loss value: 0.0940140308013813.
#               6       0.084283       0.094014       0.094014          00:03
# Better model found at epoch 7 with valid_loss value: 0.09398266401286291.
#               7       0.084000       0.093983       0.093983          00:03
# Better model found at epoch 8 with valid_loss value: 0.09353213090115811.
#               8       0.083655       0.093532       0.093532          00:03
#               9       0.083561       0.093579       0.093579          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09275729759379524.
#               0       0.083021       0.092757       0.092757          00:07
# Better model found at epoch 1 with valid_loss value: 0.09208649992271695.
#               1       0.081948       0.092086       0.092087          00:07
# Better model found at epoch 2 with valid_loss value: 0.09154834596984579.
#               2       0.080552       0.091548       0.091548          00:07
# Better model found at epoch 3 with valid_loss value: 0.09059921345642492.
#               3       0.079240       0.090599       0.090599          00:07
# Better model found at epoch 4 with valid_loss value: 0.09008295244201886.
#               4       0.078006       0.090083       0.090083          00:07
# Better model found at epoch 5 with valid_loss value: 0.08910064672721972.
#               5       0.077111       0.089101       0.089101          00:07
#               6       0.076275       0.089155       0.089155          00:07
# Better model found at epoch 7 with valid_loss value: 0.0886081734212894.
#               7       0.075666       0.088608       0.088608          00:07
# Better model found at epoch 8 with valid_loss value: 0.08815674692061586.
#               8       0.075128       0.088157       0.088157          00:07
# Better model found at epoch 9 with valid_loss value: 0.08796819276090256.
#               9       0.074710       0.087968       0.087968          00:07
# Better model found at epoch 10 with valid_loss value: 0.0877037005388451.
#              10       0.074287       0.087704       0.087704          00:07
# Better model found at epoch 11 with valid_loss value: 0.08727917388184615.
#              11       0.073935       0.087279       0.087279          00:07
#              12       0.073718       0.087853       0.087853          00:07
#              13       0.073489       0.087571       0.087571          00:07
#              14       0.073239       0.087460       0.087460          00:07
#              15       0.073077       0.087376       0.087376          00:07
#              16       0.072918       0.087410       0.087410          00:07
#              17       0.072872       0.087304       0.087304          00:07
#              18       0.072814       0.087314       0.087314          00:07
#              19       0.072732       0.087319       0.087319          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.024261355 rmse: 0.15576057 mae: 0.099373244
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1264205945032801.
#               0       0.136710       0.126421       0.126421          00:03
# Better model found at epoch 1 with valid_loss value: 0.12069450359794548.
#               1       0.122158       0.120695       0.120694          00:03
# Better model found at epoch 2 with valid_loss value: 0.11904840182249288.
#               2       0.114585       0.119048       0.119048          00:03
# Better model found at epoch 3 with valid_loss value: 0.1186024627809703.
#               3       0.109683       0.118602       0.118602          00:03
# Better model found at epoch 4 with valid_loss value: 0.11814557813453519.
#               4       0.107071       0.118146       0.118146          00:03
# Better model found at epoch 5 with valid_loss value: 0.11755247930863506.
#               5       0.105751       0.117552       0.117553          00:03
# Better model found at epoch 6 with valid_loss value: 0.1174375504570535.
#               6       0.105051       0.117438       0.117438          00:03
# Better model found at epoch 7 with valid_loss value: 0.11705735457244203.
#               7       0.104575       0.117057       0.117057          00:03
# Better model found at epoch 8 with valid_loss value: 0.11697485530347335.
#               8       0.104324       0.116975       0.116975          00:03
# Better model found at epoch 9 with valid_loss value: 0.11691963065436839.
#               9       0.104171       0.116920       0.116920          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1167939945776546.
#               0       0.103956       0.116794       0.116794          00:07
# Better model found at epoch 1 with valid_loss value: 0.11671491208553703.
#               1       0.103427       0.116715       0.116715          00:07
# Better model found at epoch 2 with valid_loss value: 0.11639841326472233.
#               2       0.102691       0.116398       0.116398          00:07
# Better model found at epoch 3 with valid_loss value: 0.11596804836884662.
#               3       0.101816       0.115968       0.115968          00:07
#               4       0.100975       0.116153       0.116153          00:07
# Better model found at epoch 5 with valid_loss value: 0.11575420184092758.
#               5       0.100105       0.115754       0.115754          00:07
#               6       0.099169       0.115939       0.115939          00:07
#               7       0.098232       0.116530       0.116530          00:07
#               8       0.097207       0.116981       0.116981          00:07
#               9       0.096348       0.117295       0.117295          00:07
#              10       0.095536       0.117575       0.117575          00:07
#              11       0.094829       0.117742       0.117742          00:07
#              12       0.094294       0.117482       0.117482          00:07
#              13       0.093804       0.117969       0.117969          00:07
#              14       0.093481       0.118131       0.118131          00:07
#              15       0.093154       0.117912       0.117912          00:07
#              16       0.092931       0.117988       0.117988          00:07
#              17       0.092673       0.117917       0.117917          00:07
#              18       0.092622       0.118034       0.118034          00:07
#              19       0.092675       0.118052       0.118052          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.041034114 rmse: 0.20256878 mae: 0.13901229
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12817662209395067.
#               0       0.136474       0.128177       0.128177          00:03
# Better model found at epoch 1 with valid_loss value: 0.12452790969956673.
#               1       0.124285       0.124528       0.124528          00:03
# Better model found at epoch 2 with valid_loss value: 0.12357645271913079.
#               2       0.117437       0.123576       0.123576          00:03
# Better model found at epoch 3 with valid_loss value: 0.12274666404127388.
#               3       0.112869       0.122747       0.122747          00:03
# Better model found at epoch 4 with valid_loss value: 0.12255163897836736.
#               4       0.110678       0.122552       0.122552          00:03
# Better model found at epoch 5 with valid_loss value: 0.12206044315644039.
#               5       0.109630       0.122060       0.122060          00:03
# Better model found at epoch 6 with valid_loss value: 0.12182819197485283.
#               6       0.108995       0.121828       0.121828          00:03
# Better model found at epoch 7 with valid_loss value: 0.1215408553838455.
#               7       0.108524       0.121541       0.121541          00:03
# Better model found at epoch 8 with valid_loss value: 0.1214139308015499.
#               8       0.108260       0.121414       0.121414          00:03
# Better model found at epoch 9 with valid_loss value: 0.12136855393172134.
#               9       0.108075       0.121369       0.121369          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12123745849649575.
#               0       0.107892       0.121237       0.121237          00:07
# Better model found at epoch 1 with valid_loss value: 0.12120100624691256.
#               1       0.107367       0.121201       0.121201          00:07
# Better model found at epoch 2 with valid_loss value: 0.1209626043135343.
#               2       0.106652       0.120963       0.120963          00:07
#               3       0.105791       0.121281       0.121281          00:07
#               4       0.104912       0.121423       0.121423          00:07
#               5       0.103777       0.122001       0.122001          00:07
#               6       0.102405       0.122472       0.122472          00:07
#               7       0.100944       0.123663       0.123663          00:07
#               8       0.099542       0.124142       0.124142          00:07
#               9       0.098308       0.124289       0.124289          00:07
#              10       0.097250       0.125168       0.125168          00:07
#              11       0.096275       0.125088       0.125088          00:07
#              12       0.095557       0.125511       0.125511          00:07
#              13       0.094955       0.125223       0.125223          00:07
#              14       0.094449       0.125725       0.125725          00:07
#              15       0.093997       0.125483       0.125483          00:07
#              16       0.093837       0.125739       0.125739          00:07
#              17       0.093611       0.125669       0.125669          00:07
#              18       0.093488       0.125567       0.125567          00:07
#              19       0.093423       0.125705       0.125705          00:07
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.042886544 rmse: 0.20709066 mae: 0.14428912
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0877131351190536.
#               0       0.135024       0.087713       0.087713          00:02
# Better model found at epoch 1 with valid_loss value: 0.07308119586259199.
#               1       0.106110       0.073081       0.073081          00:02
# Better model found at epoch 2 with valid_loss value: 0.06751569674600641.
#               2       0.090120       0.067516       0.067516          00:02
# Better model found at epoch 3 with valid_loss value: 0.06555298990387999.
#               3       0.079705       0.065553       0.065553          00:02
# Better model found at epoch 4 with valid_loss value: 0.06503949250480034.
#               4       0.074802       0.065039       0.065039          00:02
# Better model found at epoch 5 with valid_loss value: 0.06410291161551743.
#               5       0.072860       0.064103       0.064103          00:02
# Better model found at epoch 6 with valid_loss value: 0.06361980416756725.
#               6       0.071604       0.063620       0.063620          00:02
# Better model found at epoch 7 with valid_loss value: 0.06305168732312862.
#               7       0.071053       0.063052       0.063052          00:02
# Better model found at epoch 8 with valid_loss value: 0.06275792434051794.
#               8       0.070791       0.062758       0.062758          00:02
# Better model found at epoch 9 with valid_loss value: 0.06260264155679487.
#               9       0.070429       0.062603       0.062603          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.06097980049505137.
#               0       0.069766       0.060980       0.060980          00:04
# Better model found at epoch 1 with valid_loss value: 0.059262942516172895.
#               1       0.067782       0.059263       0.059263          00:04
# Better model found at epoch 2 with valid_loss value: 0.05788978894500463.
#               2       0.065171       0.057890       0.057890          00:04
# Better model found at epoch 3 with valid_loss value: 0.05666377457349807.
#               3       0.062714       0.056664       0.056664          00:04
# Better model found at epoch 4 with valid_loss value: 0.05576958548165564.
#               4       0.060549       0.055770       0.055770          00:05
# Better model found at epoch 5 with valid_loss value: 0.05541626487070482.
#               5       0.059230       0.055416       0.055416          00:05
# Better model found at epoch 6 with valid_loss value: 0.054646399198706674.
#               6       0.058262       0.054646       0.054646          00:04
# Better model found at epoch 7 with valid_loss value: 0.054030559675398604.
#               7       0.057435       0.054031       0.054031          00:04
# Better model found at epoch 8 with valid_loss value: 0.05371714213547531.
#               8       0.056959       0.053717       0.053717          00:05
# Better model found at epoch 9 with valid_loss value: 0.05333100666047983.
#               9       0.056348       0.053331       0.053331          00:05
# Better model found at epoch 10 with valid_loss value: 0.0531684491380112.
#              10       0.056000       0.053168       0.053168          00:04
# Better model found at epoch 11 with valid_loss value: 0.05291421616290263.
#              11       0.055636       0.052914       0.052914          00:04
#              12       0.055356       0.052960       0.052960          00:05
# Better model found at epoch 13 with valid_loss value: 0.052881450386163945.
#              13       0.055007       0.052881       0.052881          00:05
# Better model found at epoch 14 with valid_loss value: 0.052476165953107404.
#              14       0.054879       0.052476       0.052476          00:05
# Better model found at epoch 15 with valid_loss value: 0.0524611206938259.
#              15       0.054634       0.052461       0.052461          00:05
# Better model found at epoch 16 with valid_loss value: 0.05230073283028139.
#              16       0.054572       0.052301       0.052301          00:04
# Better model found at epoch 17 with valid_loss value: 0.052197914559184995.
#              17       0.054418       0.052198       0.052198          00:05
#              18       0.054386       0.052207       0.052207          00:04
#              19       0.054279       0.052214       0.052214          00:05
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.009525932 rmse: 0.097600885 mae: 0.059319768
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09638885423553194.
#               0       0.141385       0.096389       0.096389          00:02
# Better model found at epoch 1 with valid_loss value: 0.08820961687601708.
#               1       0.116839       0.088210       0.088210          00:02
# Better model found at epoch 2 with valid_loss value: 0.08501352010653987.
#               2       0.104838       0.085014       0.085014          00:02
# Better model found at epoch 3 with valid_loss value: 0.0835630387383035.
#               3       0.095637       0.083563       0.083563          00:02
# Better model found at epoch 4 with valid_loss value: 0.08257105604626475.
#               4       0.090905       0.082571       0.082571          00:02
# Better model found at epoch 5 with valid_loss value: 0.0821325167104226.
#               5       0.088610       0.082133       0.082133          00:02
# Better model found at epoch 6 with valid_loss value: 0.08189613832701892.
#               6       0.087545       0.081896       0.081896          00:02
# Better model found at epoch 7 with valid_loss value: 0.08156420938167463.
#               7       0.086855       0.081564       0.081564          00:02
# Better model found at epoch 8 with valid_loss value: 0.08110842724172346.
#               8       0.086463       0.081108       0.081108          00:02
#               9       0.086315       0.081148       0.081148          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08039707217980828.
#               0       0.085884       0.080397       0.080397          00:05
# Better model found at epoch 1 with valid_loss value: 0.07896884952355827.
#               1       0.084667       0.078969       0.078969          00:05
# Better model found at epoch 2 with valid_loss value: 0.07757672153904344.
#               2       0.082823       0.077577       0.077577          00:05
# Better model found at epoch 3 with valid_loss value: 0.07690892541573434.
#               3       0.080854       0.076909       0.076909          00:05
# Better model found at epoch 4 with valid_loss value: 0.07582114881572925.
#               4       0.079263       0.075821       0.075821          00:05
# Better model found at epoch 5 with valid_loss value: 0.07533618501767189.
#               5       0.078022       0.075336       0.075336          00:05
# Better model found at epoch 6 with valid_loss value: 0.0750212952603743.
#               6       0.077071       0.075021       0.075021          00:05
#               7       0.076252       0.075330       0.075330          00:05
#               8       0.075558       0.075746       0.075746          00:05
#               9       0.074881       0.075542       0.075542          00:05
#              10       0.074416       0.076714       0.076714          00:05
#              11       0.073923       0.076514       0.076514          00:05
#              12       0.073508       0.076251       0.076251          00:05
#              13       0.073164       0.076613       0.076613          00:05
#              14       0.072836       0.076909       0.076909          00:05
#              15       0.072592       0.076673       0.076673          00:05
#              16       0.072422       0.076804       0.076804          00:05
#              17       0.072335       0.076807       0.076807          00:05
#              18       0.072202       0.076858       0.076858          00:05
#              19       0.072334       0.076766       0.076766          00:05
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.01872848 rmse: 0.13685204 mae: 0.087999925
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 4.641588833612777e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.10507525263911473.
#               0       0.152880       0.105075       0.105075          00:02
# Better model found at epoch 1 with valid_loss value: 0.09514622065649185.
#               1       0.124228       0.095146       0.095146          00:02
# Better model found at epoch 2 with valid_loss value: 0.0914078801502295.
#               2       0.116087       0.091408       0.091408          00:02
# Better model found at epoch 3 with valid_loss value: 0.08932894614546455.
#               3       0.109027       0.089329       0.089329          00:02
# Better model found at epoch 4 with valid_loss value: 0.08817052440746953.
#               4       0.103715       0.088171       0.088171          00:02
# Better model found at epoch 5 with valid_loss value: 0.08764628337003952.
#               5       0.100043       0.087646       0.087646          00:02
# Better model found at epoch 6 with valid_loss value: 0.08726298701089864.
# ...
#               1       0.109182       0.074195       0.074195          00:02
# Better model found at epoch 2 with valid_loss value: 0.06913072310863862.
#               2       0.090847       0.069131       0.069131          00:02
# Better model found at epoch 3 with valid_loss value: 0.06712343026649459.
#               3       0.080655       0.067123       0.067123          00:02
# Better model found at epoch 4 with valid_loss value: 0.06664282627114916.
#               4       0.076699       0.066643       0.066643          00:02
# Better model found at epoch 5 with valid_loss value: 0.06607564699425467.
#               5       0.075077       0.066076       0.066076          00:02
# Better model found at epoch 6 with valid_loss value: 0.06584218285830434.
#               6       0.074388       0.065842       0.065842          00:02
# Better model found at epoch 7 with valid_loss value: 0.06545081467649187.
#               7       0.073847       0.065451       0.065451          00:02
# Better model found at epoch 8 with valid_loss value: 0.06521897533036936.
#               8       0.073520       0.065219       0.065219          00:02
# Better model found at epoch 9 with valid_loss value: 0.06503930106430704.
#               9       0.073439       0.065039       0.065039          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.06340714814061997.
#               0       0.072297       0.063407       0.063407          00:04
# Better model found at epoch 1 with valid_loss value: 0.06190110541471469.
#               1       0.069943       0.061901       0.061901          00:05
# Better model found at epoch 2 with valid_loss value: 0.06026263986347917.
#               2       0.067045       0.060263       0.060263          00:05
# Better model found at epoch 3 with valid_loss value: 0.05858847311460763.
#               3       0.064292       0.058588       0.058588          00:04
# Better model found at epoch 4 with valid_loss value: 0.058415204741975126.
#               4       0.062204       0.058415       0.058415          00:04
# Better model found at epoch 5 with valid_loss value: 0.057367038588748594.
#               5       0.060865       0.057367       0.057367          00:05
# Better model found at epoch 6 with valid_loss value: 0.05717061082515683.
#               6       0.059917       0.057171       0.057171          00:05
# Better model found at epoch 7 with valid_loss value: 0.05649844852697242.
#               7       0.059251       0.056498       0.056498          00:04
# Better model found at epoch 8 with valid_loss value: 0.05623279293576333.
#               8       0.058618       0.056233       0.056233          00:05
# Better model found at epoch 9 with valid_loss value: 0.0559780789050562.
#               9       0.058052       0.055978       0.055978          00:05
# Better model found at epoch 10 with valid_loss value: 0.05547946968587894.
#              10       0.057683       0.055479       0.055479          00:04
# Better model found at epoch 11 with valid_loss value: 0.05510288169189571.
#              11       0.057210       0.055103       0.055103          00:04
#              12       0.056845       0.055116       0.055116          00:04
# Better model found at epoch 13 with valid_loss value: 0.05503015884809293.
#              13       0.056484       0.055030       0.055030          00:04
# Better model found at epoch 14 with valid_loss value: 0.0547527419383721.
#              14       0.056272       0.054753       0.054753          00:05
# Better model found at epoch 15 with valid_loss value: 0.05439810087889054.
#              15       0.056004       0.054398       0.054398          00:04
#              16       0.055886       0.054538       0.054538          00:04
# Better model found at epoch 17 with valid_loss value: 0.054240682797357546.
#              17       0.055740       0.054241       0.054241          00:05
#              18       0.055647       0.054278       0.054278          00:05
#              19       0.055562       0.054303       0.054303          00:04
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.010141188 rmse: 0.10070347 mae: 0.057919707
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09717921232963792.
#               0       0.147544       0.097179       0.097179          00:02
# Better model found at epoch 1 with valid_loss value: 0.0894129580070179.
#               1       0.120720       0.089413       0.089413          00:02
# Better model found at epoch 2 with valid_loss value: 0.08597522360023394.
#               2       0.106264       0.085975       0.085975          00:02
# Better model found at epoch 3 with valid_loss value: 0.08508860973733727.
#               3       0.096658       0.085089       0.085089          00:02
# Better model found at epoch 4 with valid_loss value: 0.08472408732328113.
#               4       0.092482       0.084724       0.084724          00:02
# Better model found at epoch 5 with valid_loss value: 0.08394390009980167.
#               5       0.090836       0.083944       0.083944          00:02
# Better model found at epoch 6 with valid_loss value: 0.083752183161488.
#               6       0.090030       0.083752       0.083752          00:02
# Better model found at epoch 7 with valid_loss value: 0.08344117700811127.
#               7       0.089406       0.083441       0.083441          00:02
# Better model found at epoch 8 with valid_loss value: 0.08310889049309653.
#               8       0.089016       0.083109       0.083109          00:02
# Better model found at epoch 9 with valid_loss value: 0.08298261377072315.
#               9       0.088788       0.082983       0.082983          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0822118822785293.
#               0       0.088232       0.082212       0.082212          00:05
# Better model found at epoch 1 with valid_loss value: 0.08083291981063111.
#               1       0.086628       0.080833       0.080833          00:05
# Better model found at epoch 2 with valid_loss value: 0.07958734076230675.
#               2       0.084326       0.079587       0.079587          00:05
# Better model found at epoch 3 with valid_loss value: 0.07886854129850233.
#               3       0.082103       0.078869       0.078869          00:05
# Better model found at epoch 4 with valid_loss value: 0.07812724970917667.
#               4       0.080492       0.078127       0.078127          00:05
# Better model found at epoch 5 with valid_loss value: 0.07786569246147783.
#               5       0.079280       0.077866       0.077866          00:05
# Better model found at epoch 6 with valid_loss value: 0.07739512084265664.
#               6       0.078218       0.077395       0.077395          00:05
# Better model found at epoch 7 with valid_loss value: 0.0771230351546608.
#               7       0.077319       0.077123       0.077123          00:05
# Better model found at epoch 8 with valid_loss value: 0.07698818669268714.
#               8       0.076427       0.076988       0.076988          00:05
# Better model found at epoch 9 with valid_loss value: 0.07697009962685618.
#               9       0.075692       0.076970       0.076970          00:05
# Better model found at epoch 10 with valid_loss value: 0.07687040224998729.
#              10       0.075021       0.076870       0.076870          00:05
#              11       0.074420       0.076941       0.076941          00:05
#              12       0.073807       0.076957       0.076957          00:05
#              13       0.073441       0.077342       0.077342          00:05
# Better model found at epoch 14 with valid_loss value: 0.07675071573529038.
#              14       0.073007       0.076751       0.076751          00:05
#              15       0.072774       0.076781       0.076781          00:05
# Better model found at epoch 16 with valid_loss value: 0.07659466140536005.
#              16       0.072505       0.076595       0.076595          00:05
#              17       0.072302       0.076725       0.076725          00:05
# Better model found at epoch 18 with valid_loss value: 0.07653548362489829.
#              18       0.072284       0.076535       0.076535          00:05
#              19       0.072234       0.076648       0.076648          00:05
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018840233 rmse: 0.13725972 mae: 0.082005136
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.10049139481683785.
#               0       0.150734       0.100491       0.100491          00:02
# Better model found at epoch 1 with valid_loss value: 0.09331675390817964.
#               1       0.124647       0.093317       0.093317          00:02
# Better model found at epoch 2 with valid_loss value: 0.09097286521475692.
#               2       0.112079       0.090973       0.090973          00:02
# Better model found at epoch 3 with valid_loss value: 0.089566584259993.
#               3       0.102464       0.089567       0.089567          00:02
# Better model found at epoch 4 with valid_loss value: 0.08891555934373971.
#               4       0.097218       0.088916       0.088916          00:02
# Better model found at epoch 5 with valid_loss value: 0.08831025300574778.
#               5       0.094862       0.088310       0.088310          00:02
# Better model found at epoch 6 with valid_loss value: 0.0880257807354273.
#               6       0.093669       0.088026       0.088026          00:02
# Better model found at epoch 7 with valid_loss value: 0.0876037205696577.
#               7       0.092986       0.087604       0.087604          00:02
# Better model found at epoch 8 with valid_loss value: 0.08740245430272826.
#               8       0.092603       0.087402       0.087402          00:02
# Better model found at epoch 9 with valid_loss value: 0.08736550959099189.
#               9       0.092406       0.087366       0.087366          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08673891682768504.
#               0       0.091925       0.086739       0.086739          00:05
# Better model found at epoch 1 with valid_loss value: 0.08580960054364606.
#               1       0.090539       0.085810       0.085810          00:05
# Better model found at epoch 2 with valid_loss value: 0.08489818375133788.
#               2       0.088366       0.084898       0.084898          00:05
# Better model found at epoch 3 with valid_loss value: 0.084116475460028.
#               3       0.086229       0.084116       0.084116          00:05
# Better model found at epoch 4 with valid_loss value: 0.08342482241613751.
#               4       0.084512       0.083425       0.083425          00:05
#               5       0.083084       0.083608       0.083608          00:05
# Better model found at epoch 6 with valid_loss value: 0.08315784762762689.
#               6       0.081890       0.083158       0.083158          00:05
#               7       0.081010       0.083629       0.083629          00:05
#               8       0.080248       0.083549       0.083549          00:05
#               9       0.079622       0.083937       0.083937          00:05
#              10       0.078932       0.083926       0.083926          00:05
#              11       0.078516       0.083860       0.083860          00:05
#              12       0.078034       0.083749       0.083749          00:05
#              13       0.077575       0.083773       0.083773          00:05
#              14       0.077251       0.083871       0.083871          00:05
#              15       0.077042       0.083837       0.083837          00:05
#              16       0.076827       0.083785       0.083785          00:05
#              17       0.076690       0.083814       0.083814          00:05
#              18       0.076627       0.083754       0.083754          00:05
#              19       0.076572       0.083839       0.083839          00:05
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.020110812 rmse: 0.1418126 mae: 0.08796212
# ----------- Complete! -----------

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup.columns = pd.MultiIndex.from_product([['Self-supervised'], ['MSE','RMSE', 'MAE']], names=['Model', 'Metrics'])

# Path if not exists
path = "results/patchtst/"
if not os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results.csv"), index=True)
df_self_sup.round(4)
# Out:
# Model            Self-supervised
# Metrics                      MSE    RMSE     MAE
# Country Pred_len
# DE      24                0.0210  0.1449  0.0884
#         96                0.0350  0.1872  0.1253
#         168               0.0379  0.1947  0.1313
# GB      24                0.0243  0.1558  0.0994
#         96                0.0410  0.2026  0.1390
#         168               0.0429  0.2071  0.1443
# ES      24                0.0095  0.0976  0.0593
#         96                0.0187  0.1369  0.0880
#         168               0.0212  0.1456  0.0947
# FR      24                0.0100  0.1001  0.0551
#         96                0.0203  0.1425  0.0818
#         168               0.0223  0.1494  0.0874
# IT      24                0.0101  0.1007  0.0579
#         96                0.0188  0.1373  0.0820
#         168               0.0201  0.1418  0.0880
