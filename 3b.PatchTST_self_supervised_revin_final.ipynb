# %% [markdown]
# <details>
# <summary>Table of Contents</summary>
#
# - [1. Pretrain](#1-pretrain)
# - [2. Finetune](#2-finetune)
#
# </details>
#
#
#
# This notebook demonstrates experiments on 5 countries with self-supervised learning.
# All parameters and settings are taken from the paper.

# %%
import pandas as pd
import subprocess
import os
from utils.helper import extract_metrics_from_output

# %% [markdown]
# # 1. Pretrain
#
# Tracking loss - MAE.

# %%
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Execute the command
        print(f"==========Running command for {country}, pred_len {pred_len}:==========")
        # !{command}
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00035938136638046257
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9651524109799743.
#               0       0.982107       0.965152          00:17
# Better model found at epoch 1 with valid_loss value: 0.9606560137526138.
#               1       0.965265       0.960656          00:10
# Better model found at epoch 2 with valid_loss value: 0.9603071404515844.
#               2       0.961556       0.960307          00:17
# Better model found at epoch 3 with valid_loss value: 0.9592228214975068.
#               3       0.959726       0.959223          00:17
# Better model found at epoch 4 with valid_loss value: 0.9582095809624819.
#               4       0.959612       0.958210          00:17
#               5       0.958652       0.959139          00:17
#               6       0.957142       0.958400          00:17
#               7       0.958461       0.958951          00:16
#               8       0.957441       0.958606          00:07
# Better model found at epoch 9 with valid_loss value: 0.8420295881001689.
#               9       0.947880       0.842030          00:10
# Better model found at epoch 10 with valid_loss value: 0.8205353956389738.
#              10       0.836203       0.820535          00:17
# Better model found at epoch 11 with valid_loss value: 0.8185005108221409.
#              11       0.827645       0.818501          00:17
# Better model found at epoch 12 with valid_loss value: 0.8084630599565706.
#              12       0.821739       0.808463          00:17
# Better model found at epoch 13 with valid_loss value: 0.7518792191521232.
#              13       0.785067       0.751879          00:17
# Better model found at epoch 14 with valid_loss value: 0.6507104778857367.
#              14       0.710951       0.650710          00:17
# Better model found at epoch 15 with valid_loss value: 0.638151942255107.
#              15       0.663763       0.638152          00:17
# Better model found at epoch 16 with valid_loss value: 0.6284738497391226.
#              16       0.645683       0.628474          00:17
# Better model found at epoch 17 with valid_loss value: 0.6267899980647821.
#              17       0.635517       0.626790          00:17
# Better model found at epoch 18 with valid_loss value: 0.618062471411553.
#              18       0.626919       0.618062          00:17
# Better model found at epoch 19 with valid_loss value: 0.569692036452469.
#              19       0.610329       0.569692          00:17
# Better model found at epoch 20 with valid_loss value: 0.5568143547933087.
#              20       0.574726       0.556814          00:17
# Better model found at epoch 21 with valid_loss value: 0.5513286323663945.
#              21       0.560063       0.551329          00:09
# Better model found at epoch 22 with valid_loss value: 0.5480499537558308.
#              22       0.552063       0.548050          00:15
# Better model found at epoch 23 with valid_loss value: 0.5431656097318843.
#              23       0.546112       0.543166          00:18
# Better model found at epoch 24 with valid_loss value: 0.542383354423858.
#              24       0.541150       0.542383          00:17
#              25       0.537708       0.544204          00:17
#              26       0.534254       0.546801          00:17
#              27       0.532823       0.543616          00:17
#              28       0.529857       0.546885          00:13
#              29       0.527991       0.549657          00:17
# No improvement since epoch 24: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.00011768119524349978
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.980289329485354.
#               0       0.994485       0.980289          00:07
# Better model found at epoch 1 with valid_loss value: 0.9674958839757933.
#               1       0.976495       0.967496          00:11
# Better model found at epoch 2 with valid_loss value: 0.9656419249644019.
#               2       0.969565       0.965642          00:17
# Better model found at epoch 3 with valid_loss value: 0.962409256763629.
#               3       0.966544       0.962409          00:17
# Better model found at epoch 4 with valid_loss value: 0.9593428187296582.
#               4       0.963832       0.959343          00:17
#               5       0.961110       0.959830          00:17
#               6       0.960801       0.960814          00:16
# Better model found at epoch 7 with valid_loss value: 0.9579801604454842.
#               7       0.959942       0.957980          00:13
# Better model found at epoch 8 with valid_loss value: 0.9569105503712367.
#               8       0.959079       0.956911          00:17
# Better model found at epoch 9 with valid_loss value: 0.9565950150020341.
#               9       0.958292       0.956595          00:17
#              10       0.958542       0.957660          00:17
#              11       0.957764       0.957743          00:17
#              12       0.957501       0.958847          00:17
#              13       0.957444       0.957850          00:17
#              14       0.957051       0.957221          00:17
# Better model found at epoch 15 with valid_loss value: 0.8298721648698129.
#              15       0.898845       0.829872          00:17
# Better model found at epoch 16 with valid_loss value: 0.8209762287683076.
#              16       0.835426       0.820976          00:17
# Better model found at epoch 17 with valid_loss value: 0.8162889671480879.
#              17       0.827512       0.816289          00:17
# Better model found at epoch 18 with valid_loss value: 0.8160159428397071.
#              18       0.825556       0.816016          00:17
# Better model found at epoch 19 with valid_loss value: 0.8148417635018308.
#              19       0.824186       0.814842          00:17
#              20       0.821408       0.815111          00:17
# Better model found at epoch 21 with valid_loss value: 0.7917511855421074.
#              21       0.808475       0.791751          00:17
# Better model found at epoch 22 with valid_loss value: 0.7757236415530919.
#              22       0.787426       0.775724          00:17
# Better model found at epoch 23 with valid_loss value: 0.742420794344996.
#              23       0.764374       0.742421          00:17
# Better model found at epoch 24 with valid_loss value: 0.6913806639035801.
#              24       0.732291       0.691381          00:17
# Better model found at epoch 25 with valid_loss value: 0.6624621373448942.
#              25       0.700672       0.662462          00:17
# Better model found at epoch 26 with valid_loss value: 0.6537527731514443.
#              26       0.679297       0.653753          00:17
# Better model found at epoch 27 with valid_loss value: 0.6446907260730268.
#              27       0.662719       0.644691          00:17
# Better model found at epoch 28 with valid_loss value: 0.6418309633085842.
#              28       0.651417       0.641831          00:17
# Better model found at epoch 29 with valid_loss value: 0.6371973768688974.
#              29       0.643216       0.637197          00:17
# Better model found at epoch 30 with valid_loss value: 0.625625270163751.
#              30       0.634897       0.625625          00:17
# Better model found at epoch 31 with valid_loss value: 0.5997628518485557.
#              31       0.624292       0.599763          00:17
# Better model found at epoch 32 with valid_loss value: 0.5722083343927991.
#              32       0.601013       0.572208          00:17
# Better model found at epoch 33 with valid_loss value: 0.565672278656428.
#              33       0.583481       0.565672          00:17
# Better model found at epoch 34 with valid_loss value: 0.560136226098454.
#              34       0.574563       0.560136          00:17
# Better model found at epoch 35 with valid_loss value: 0.5579758696094386.
#              35       0.567623       0.557976          00:17
# Better model found at epoch 36 with valid_loss value: 0.552640334176668.
#              36       0.562646       0.552640          00:17
# Better model found at epoch 37 with valid_loss value: 0.5508418779241253.
#              37       0.558717       0.550842          00:17
# Better model found at epoch 38 with valid_loss value: 0.5481516826434093.
#              38       0.554999       0.548152          00:17
# Better model found at epoch 39 with valid_loss value: 0.5472681677176566.
#              39       0.551405       0.547268          00:17
#              40       0.549011       0.548034          00:17
# Better model found at epoch 41 with valid_loss value: 0.5456391994889137.
#              41       0.546528       0.545639          00:17
# Better model found at epoch 42 with valid_loss value: 0.5450374494634865.
#              42       0.544716       0.545037          00:17
# Better model found at epoch 43 with valid_loss value: 0.5446564391146257.
#              43       0.542367       0.544656          00:17
# Better model found at epoch 44 with valid_loss value: 0.5425639414030716.
#              44       0.541013       0.542564          00:17
#              45       0.539260       0.543381          00:17
# Better model found at epoch 46 with valid_loss value: 0.5420112976123881.
#              46       0.537927       0.542011          00:17
#              47       0.536472       0.542053          00:17
# Better model found at epoch 48 with valid_loss value: 0.5419029142722742.
#              48       0.535934       0.541903          00:17
#              49       0.534419       0.542274          00:17
# Better model found at epoch 50 with valid_loss value: 0.5415747447747152.
#              50       0.532954       0.541575          00:17
#              51       0.531788       0.545020          00:17
#              52       0.531320       0.542344          00:16
# Better model found at epoch 53 with valid_loss value: 0.5410072022477624.
#              53       0.530507       0.541007          00:17
#              54       0.530016       0.546391          00:17
#              55       0.529546       0.545227          00:17
#              56       0.528750       0.544966          00:17
#              57       0.528137       0.543512          00:08
#              58       0.526992       0.544372          00:07
# No improvement since epoch 53: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9686896985118557.
#               0       0.986142       0.968690          00:17
# Better model found at epoch 1 with valid_loss value: 0.9629116903198583.
#               1       0.968895       0.962912          00:12
# Better model found at epoch 2 with valid_loss value: 0.961381881766631.
#               2       0.963589       0.961382          00:08
#               3       0.961618       0.961574          00:17
# Better model found at epoch 4 with valid_loss value: 0.9594381637987814.
#               4       0.960994       0.959438          00:17
# Better model found at epoch 5 with valid_loss value: 0.957855611543924.
#               5       0.959550       0.957856          00:17
#               6       0.958973       0.958784          00:17
# Better model found at epoch 7 with valid_loss value: 0.9576626467818623.
#               7       0.958728       0.957663          00:17
# Better model found at epoch 8 with valid_loss value: 0.9576348276953318.
#               8       0.957733       0.957635          00:17
# Better model found at epoch 9 with valid_loss value: 0.9570930791258438.
#               9       0.957016       0.957093          00:17
# Better model found at epoch 10 with valid_loss value: 0.9566432300242879.
#              10       0.957122       0.956643          00:17
# Better model found at epoch 11 with valid_loss value: 0.8292983865573028.
#              11       0.923927       0.829298          00:17
# Better model found at epoch 12 with valid_loss value: 0.8196975052229128.
#              12       0.834666       0.819698          00:17
# Better model found at epoch 13 with valid_loss value: 0.817282872833649.
#              13       0.826378       0.817283          00:16
# Better model found at epoch 14 with valid_loss value: 0.8172534457074345.
#              14       0.822624       0.817253          00:09
# Better model found at epoch 15 with valid_loss value: 0.7938985989471843.
#              15       0.814148       0.793899          00:09
# Better model found at epoch 16 with valid_loss value: 0.7512435774895028.
#              16       0.782903       0.751244          00:17
# Better model found at epoch 17 with valid_loss value: 0.6852494680604726.
#              17       0.730408       0.685249          00:17
# Better model found at epoch 18 with valid_loss value: 0.6533522722887164.
#              18       0.686389       0.653352          00:17
# Better model found at epoch 19 with valid_loss value: 0.6418193312741849.
#              19       0.660004       0.641819          00:17
# Better model found at epoch 20 with valid_loss value: 0.6353505896359912.
#              20       0.645788       0.635351          00:17
# Better model found at epoch 21 with valid_loss value: 0.6292851845514984.
#              21       0.635455       0.629285          00:17
# Better model found at epoch 22 with valid_loss value: 0.6052569309726453.
#              22       0.622921       0.605257          00:17
# Better model found at epoch 23 with valid_loss value: 0.5650136474327968.
#              23       0.593717       0.565014          00:17
# Better model found at epoch 24 with valid_loss value: 0.5577912577957764.
#              24       0.571767       0.557791          00:17
# Better model found at epoch 25 with valid_loss value: 0.5543970478321052.
#              25       0.563008       0.554397          00:17
# Better model found at epoch 26 with valid_loss value: 0.5488877028702865.
#              26       0.555848       0.548888          00:17
# Better model found at epoch 27 with valid_loss value: 0.5452430407258563.
#              27       0.550197       0.545243          00:16
# Better model found at epoch 28 with valid_loss value: 0.5451159653898403.
#              28       0.545963       0.545116          00:17
# Better model found at epoch 29 with valid_loss value: 0.5424042878699777.
#              29       0.541428       0.542404          00:17
#              30       0.539174       0.544842          00:17
#              31       0.536389       0.544496          00:17
#              32       0.534499       0.544881          00:17
#              33       0.532726       0.544545          00:17
#              34       0.531127       0.545714          00:17
# No improvement since epoch 29: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9652349561937027.
#               0       0.982681       0.965235          00:12
# Better model found at epoch 1 with valid_loss value: 0.9605622373632781.
#               1       0.965836       0.960562          00:17
# Better model found at epoch 2 with valid_loss value: 0.9598187806618949.
#               2       0.960997       0.959819          00:17
#               3       0.958867       0.960705          00:17
# Better model found at epoch 4 with valid_loss value: 0.9590834135485363.
#               4       0.958300       0.959083          00:17
# ^C
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9661083547345403.
#               0       0.984988       0.966108          00:17
# Better model found at epoch 1 with valid_loss value: 0.9622086999084621.
#               1       0.967587       0.962209          00:17
# Better model found at epoch 2 with valid_loss value: 0.959558234591131.
#               2       0.962852       0.959558          00:17
# Better model found at epoch 3 with valid_loss value: 0.9590570808329943.
#               3       0.960226       0.959057          00:17
#               4       0.959454       0.961031          00:17
# Better model found at epoch 5 with valid_loss value: 0.957900144299227.
#               5       0.957255       0.957900          00:17
#               6       0.956359       0.958810          00:17
#               7       0.956992       0.959380          00:17
# Better model found at epoch 8 with valid_loss value: 0.9566564375254272.
#               8       0.955815       0.956656          00:17
#               9       0.955633       0.957825          00:17
#              10       0.955539       0.958077          00:17
# Better model found at epoch 11 with valid_loss value: 0.8290142360404801.
#              11       0.927312       0.829014          00:17
# Better model found at epoch 12 with valid_loss value: 0.8186403453010578.
#              12       0.824214       0.818640          00:17
# Better model found at epoch 13 with valid_loss value: 0.815769219767087.
#              13       0.815606       0.815769          00:17
# Better model found at epoch 14 with valid_loss value: 0.8146064031987388.
#              14       0.812537       0.814606          00:14
# ^C
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404

# %% [markdown]
# # 2. Finetune
#
# Linear probing + full fine-tuning.

# %%
# In case you just want finetune, please uncomment below
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

# List to store metrics for the DataFrame
data = []

for country in countries:
    for pred_len in pred_lens:
        # Define the parameters for each country and pred_len
        params = {
            "--dset": country,
            "--is_finetune": 1,
            "--pretrained_model": f"saved_models/{country}/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth",
            "--scaler_type": "minmax",
            "--n_epochs_finetune": 20,
            "--target_points": pred_len  
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        print(f"==========Running command for {country}, pred_len {pred_len}:==========")

        # Run the command and capture the output
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Capture the output in real-time
        output = []
        for line in process.stdout:
            output.append(line)
            print(line, end='')  # Print in the .ipynb cell

        # Wait for the process to complete
        process.stdout.close()
        process.wait()

        try:
            # Extract metrics from the output using the function
            metrics = extract_metrics_from_output(output, if_supervised=False)
            mse, rmse, mae = metrics[0]

            # Append the results to the data list
            data.append({
                'Country': country,
                'Pred_len': pred_len,
                'MSE': mse,
                'RMSE': rmse,
                'MAE': mae
            })
        except ValueError as e:
            print(f"\nError: {e} for {country}, pred_len {pred_len}")
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12105851513177075.
#               0       0.141290       0.121059       0.121059          00:03
# Better model found at epoch 1 with valid_loss value: 0.10276727920294153.
#               1       0.112838       0.102767       0.102767          00:03
# Better model found at epoch 2 with valid_loss value: 0.09617722001857307.
#               2       0.096988       0.096177       0.096177          00:03
# Better model found at epoch 3 with valid_loss value: 0.09453688914971047.
#               3       0.089975       0.094537       0.094537          00:03
# Better model found at epoch 4 with valid_loss value: 0.09316548799536553.
#               4       0.087372       0.093165       0.093165          00:03
#               5       0.086354       0.094124       0.094124          00:03
#               6       0.085825       0.093475       0.093475          00:03
# Better model found at epoch 7 with valid_loss value: 0.09308720355979572.
#               7       0.085387       0.093087       0.093087          00:03
# Better model found at epoch 8 with valid_loss value: 0.0928081520427859.
#               8       0.084991       0.092808       0.092808          00:03
# Better model found at epoch 9 with valid_loss value: 0.09272930801192798.
#               9       0.084878       0.092729       0.092729          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09133738836368525.
#               0       0.084123       0.091337       0.091337          00:17
# Better model found at epoch 1 with valid_loss value: 0.09054609117389818.
#               1       0.082400       0.090546       0.090546          00:17
# Better model found at epoch 2 with valid_loss value: 0.08940157154777224.
#               2       0.080169       0.089402       0.089402          00:17
# Better model found at epoch 3 with valid_loss value: 0.08849612673666962.
#               3       0.078198       0.088496       0.088496          00:18
# Better model found at epoch 4 with valid_loss value: 0.08827420302635415.
#               4       0.076686       0.088274       0.088274          00:17
# Better model found at epoch 5 with valid_loss value: 0.08762789010349646.
#               5       0.075589       0.087628       0.087628          00:17
#               6       0.074675       0.087686       0.087686          00:17
# Better model found at epoch 7 with valid_loss value: 0.08682289755534221.
#               7       0.074067       0.086823       0.086823          00:17
#               8       0.073396       0.087167       0.087167          00:17
# Better model found at epoch 9 with valid_loss value: 0.0865115073211557.
#               9       0.072982       0.086512       0.086511          00:17
#              10       0.072566       0.086657       0.086657          00:17
#              11       0.072108       0.086613       0.086613          00:07
# Better model found at epoch 12 with valid_loss value: 0.08643262402045299.
#              12       0.071796       0.086433       0.086433          00:17
#              13       0.071413       0.086437       0.086437          00:17
# Better model found at epoch 14 with valid_loss value: 0.08604156508866817.
#              14       0.071179       0.086042       0.086042          00:17
# Better model found at epoch 15 with valid_loss value: 0.08598864897282653.
#              15       0.070974       0.085989       0.085989          00:17
# Better model found at epoch 16 with valid_loss value: 0.08578363093068904.
#              16       0.070836       0.085784       0.085784          00:17
#              17       0.070599       0.085914       0.085914          00:17
#              18       0.070603       0.085807       0.085807          00:17
#              19       0.070590       0.085789       0.085789          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.02097016 rmse: 0.14481078 mae: 0.0884165
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.13281640346890256.
#               0       0.147893       0.132816       0.132816          00:03
# Better model found at epoch 1 with valid_loss value: 0.12570335940678398.
#               1       0.129733       0.125703       0.125703          00:03
# Better model found at epoch 2 with valid_loss value: 0.12325945016909072.
#               2       0.119517       0.123259       0.123259          00:03
# Better model found at epoch 3 with valid_loss value: 0.1225973205318094.
#               3       0.113572       0.122597       0.122597          00:03
# Better model found at epoch 4 with valid_loss value: 0.12132489892697315.
#               4       0.110922       0.121325       0.121325          00:03
# Better model found at epoch 5 with valid_loss value: 0.12108673766146257.
#               5       0.109811       0.121087       0.121087          00:03
# Better model found at epoch 6 with valid_loss value: 0.1209274503057618.
#               6       0.109210       0.120927       0.120927          00:03
# Better model found at epoch 7 with valid_loss value: 0.12070915402194365.
#               7       0.108768       0.120709       0.120709          00:03
# Better model found at epoch 8 with valid_loss value: 0.12046256007170464.
#               8       0.108457       0.120463       0.120463          00:03
# Better model found at epoch 9 with valid_loss value: 0.12041615547447111.
#               9       0.108289       0.120416       0.120416          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12010185173413344.
#               0       0.107864       0.120102       0.120102          00:17
# Better model found at epoch 1 with valid_loss value: 0.11914195595377339.
#               1       0.106774       0.119142       0.119142          00:16
# Better model found at epoch 2 with valid_loss value: 0.11877272553905614.
#               2       0.105173       0.118773       0.118773          00:07
# Better model found at epoch 3 with valid_loss value: 0.11757986318589808.
#               3       0.103648       0.117580       0.117580          00:07
#               4       0.102320       0.118417       0.118417          00:17
#               5       0.100983       0.118217       0.118217          00:17
#               6       0.099588       0.118882       0.118882          00:17
#               7       0.098344       0.119754       0.119754          00:17
#               8       0.097122       0.119697       0.119697          00:17
#               9       0.096114       0.119002       0.119002          00:17
#              10       0.095283       0.119473       0.119473          00:17
#              11       0.094453       0.119553       0.119553          00:17
#              12       0.093818       0.119693       0.119693          00:17
#              13       0.093240       0.120014       0.120014          00:17
#              14       0.092778       0.119839       0.119839          00:17
#              15       0.092397       0.119705       0.119705          00:07
#              16       0.092171       0.119852       0.119852          00:08
#              17       0.091988       0.119805       0.119805          00:17
#              18       0.091961       0.119726       0.119726          00:16
#              19       0.091877       0.119695       0.119695          00:12
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.034867324 rmse: 0.18672794 mae: 0.12519094
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.13411247948141364.
#               0       0.150086       0.134112       0.134113          00:03
# Better model found at epoch 1 with valid_loss value: 0.12885426006697165.
#               1       0.133679       0.128854       0.128854          00:03
# Better model found at epoch 2 with valid_loss value: 0.12781848150561398.
#               2       0.124616       0.127818       0.127818          00:03
# Better model found at epoch 3 with valid_loss value: 0.12598740671761793.
#               3       0.118892       0.125987       0.125987          00:03
# Better model found at epoch 4 with valid_loss value: 0.12569853243866294.
#               4       0.116210       0.125699       0.125699          00:03
#               5       0.114977       0.125895       0.125895          00:03
# Better model found at epoch 6 with valid_loss value: 0.12484629150672032.
#               6       0.114356       0.124846       0.124846          00:03
# Better model found at epoch 7 with valid_loss value: 0.12477280409316853.
#               7       0.113869       0.124773       0.124773          00:03
# Better model found at epoch 8 with valid_loss value: 0.12454538708088053.
#               8       0.113591       0.124545       0.124545          00:03
# Better model found at epoch 9 with valid_loss value: 0.12449531674522477.
#               9       0.113413       0.124495       0.124495          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12428872384684259.
#               0       0.113029       0.124289       0.124289          00:17
# Better model found at epoch 1 with valid_loss value: 0.12352271404294624.
#               1       0.111963       0.123523       0.123523          00:12
# Better model found at epoch 2 with valid_loss value: 0.12226948831534044.
#               2       0.110507       0.122269       0.122270          00:14
# Better model found at epoch 3 with valid_loss value: 0.12178096585938786.
#               3       0.109015       0.121781       0.121781          00:16
# Better model found at epoch 4 with valid_loss value: 0.12173393069863535.
#               4       0.107522       0.121734       0.121734          00:16
#               5       0.106042       0.122126       0.122126          00:17
#               6       0.104626       0.122948       0.122948          00:17
#               7       0.103430       0.122902       0.122902          00:17
#               8       0.102287       0.122662       0.122662          00:13
#               9       0.101200       0.122578       0.122578          00:07
#              10       0.100386       0.122854       0.122854          00:07
#              11       0.099524       0.123558       0.123558          00:16
#              12       0.098912       0.123348       0.123348          00:17
#              13       0.098294       0.123533       0.123533          00:14
#              14       0.097834       0.123463       0.123463          00:17
#              15       0.097419       0.123586       0.123586          00:17
#              16       0.097222       0.123438       0.123438          00:17
#              17       0.096985       0.123785       0.123785          00:17
#              18       0.096945       0.123754       0.123754          00:17
#              19       0.096955       0.123739       0.123739          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.037424114 rmse: 0.19345313 mae: 0.13087086
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.117558541128408.
#               0       0.132387       0.117559       0.117559          00:03
# Better model found at epoch 1 with valid_loss value: 0.10118864126022901.
#               1       0.108754       0.101189       0.101189          00:03
# Better model found at epoch 2 with valid_loss value: 0.09606566420701303.
#               2       0.096067       0.096066       0.096066          00:03
# Better model found at epoch 3 with valid_loss value: 0.09474922120043831.
#               3       0.089883       0.094749       0.094749          00:03
# Better model found at epoch 4 with valid_loss value: 0.09436073444348661.
#               4       0.086668       0.094361       0.094361          00:03
# Better model found at epoch 5 with valid_loss value: 0.0939931392439581.
#               5       0.085094       0.093993       0.093993          00:03
# Better model found at epoch 6 with valid_loss value: 0.09399224585498935.
#               6       0.084280       0.093992       0.093992          00:03
# Better model found at epoch 7 with valid_loss value: 0.09359610147830545.
#               7       0.083887       0.093596       0.093596          00:03
# Better model found at epoch 8 with valid_loss value: 0.09349875153309474.
#               8       0.083552       0.093499       0.093499          00:03
# Better model found at epoch 9 with valid_loss value: 0.09348216984113619.
#               9       0.083443       0.093482       0.093482          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09269099046088347.
#               0       0.083106       0.092691       0.092691          00:17
# Better model found at epoch 1 with valid_loss value: 0.09199184977933489.
#               1       0.082098       0.091992       0.091992          00:17
# Better model found at epoch 2 with valid_loss value: 0.09107913022948669.
#               2       0.080816       0.091079       0.091079          00:17
# Better model found at epoch 3 with valid_loss value: 0.09054311648315606.
#               3       0.079506       0.090543       0.090543          00:17
# Better model found at epoch 4 with valid_loss value: 0.08996728311421807.
#               4       0.078304       0.089967       0.089967          00:17
# Better model found at epoch 5 with valid_loss value: 0.08931987063570652.
#               5       0.077364       0.089320       0.089320          00:17
# Better model found at epoch 6 with valid_loss value: 0.08861876646191894.
#               6       0.076561       0.088619       0.088619          00:16
# Better model found at epoch 7 with valid_loss value: 0.08841052829250945.
#               7       0.075983       0.088411       0.088411          00:17
# Better model found at epoch 8 with valid_loss value: 0.08836863718558992.
#               8       0.075510       0.088369       0.088369          00:17
# Better model found at epoch 9 with valid_loss value: 0.08793116129727462.
#               9       0.075041       0.087931       0.087931          00:15
#              10       0.074685       0.088021       0.088021          00:07
# Better model found at epoch 11 with valid_loss value: 0.08779395245961175.
#              11       0.074366       0.087794       0.087794          00:07
#              12       0.074076       0.087799       0.087799          00:17
# Better model found at epoch 13 with valid_loss value: 0.08762118477750021.
#              13       0.073893       0.087621       0.087621          00:17
# Better model found at epoch 14 with valid_loss value: 0.08759738725156326.
#              14       0.073676       0.087597       0.087597          00:15
# Better model found at epoch 15 with valid_loss value: 0.08752954859470505.
#              15       0.073553       0.087530       0.087530          00:17
# Better model found at epoch 16 with valid_loss value: 0.08752516018955082.
#              16       0.073463       0.087525       0.087525          00:14
# Better model found at epoch 17 with valid_loss value: 0.08751076779143879.
#              17       0.073340       0.087511       0.087511          00:14
# Better model found at epoch 18 with valid_loss value: 0.08746743351772358.
#              18       0.073250       0.087467       0.087467          00:17
# Better model found at epoch 19 with valid_loss value: 0.08743770624522479.
#              19       0.073244       0.087438       0.087438          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.024337353 rmse: 0.15600434 mae: 0.09926091
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00020565123083486514
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12389763257094183.
#               0       0.131793       0.123898       0.123898          00:03
# Better model found at epoch 1 with valid_loss value: 0.12002278910699755.
#               1       0.117964       0.120023       0.120023          00:03
# Better model found at epoch 2 with valid_loss value: 0.11906591280385476.
#               2       0.110314       0.119066       0.119066          00:03
#               3       0.107283       0.119321       0.119321          00:03
# Better model found at epoch 4 with valid_loss value: 0.11876813672828519.
#               4       0.106376       0.118768       0.118768          00:03
# Better model found at epoch 5 with valid_loss value: 0.11811450930316823.
#               5       0.105870       0.118115       0.118115          00:03
# Better model found at epoch 6 with valid_loss value: 0.11752028810580248.
#               6       0.105197       0.117520       0.117520          00:03
# Better model found at epoch 7 with valid_loss value: 0.11737377393332994.
#               7       0.104643       0.117374       0.117374          00:03
# Better model found at epoch 8 with valid_loss value: 0.1170776168537683.
#               8       0.104209       0.117078       0.117078          00:03
# Better model found at epoch 9 with valid_loss value: 0.1170175252841487.
#               9       0.103926       0.117018       0.117018          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11667511259471623.
#               0       0.103632       0.116675       0.116675          00:07
# Better model found at epoch 1 with valid_loss value: 0.1166473612152919.
#               1       0.102894       0.116647       0.116647          00:07
# Better model found at epoch 2 with valid_loss value: 0.11655240660280207.
#               2       0.101910       0.116552       0.116552          00:16
#               3       0.100954       0.116561       0.116561          00:16
#               4       0.099826       0.116582       0.116582          00:17
#               5       0.098613       0.117950       0.117950          00:17
#               6       0.096914       0.117847       0.117847          00:17
#               7       0.095285       0.118558       0.118558          00:13
#               8       0.093725       0.119052       0.119052          00:12
#               9       0.092226       0.119223       0.119223          00:12
#              10       0.090942       0.120817       0.120817          00:17
#              11       0.089830       0.120795       0.120795          00:17
#              12       0.088806       0.120202       0.120202          00:17
#              13       0.087866       0.120590       0.120590          00:17
#              14       0.087229       0.120848       0.120848          00:15
#              15       0.086725       0.121255       0.121255          00:16
#              16       0.086326       0.121027       0.121027          00:17
#              17       0.086046       0.120999       0.120999          00:17
#              18       0.085925       0.121146       0.121146          00:15
#              19       0.085704       0.121315       0.121315          00:16
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.04080385 rmse: 0.20199963 mae: 0.13886747
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00017073526474706903
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12744049167742982.
#               0       0.134580       0.127440       0.127440          00:03
# Better model found at epoch 1 with valid_loss value: 0.1243999298412286.
#               1       0.122675       0.124400       0.124400          00:03
# Better model found at epoch 2 with valid_loss value: 0.12371422151904433.
#               2       0.115457       0.123714       0.123714          00:03
# Better model found at epoch 3 with valid_loss value: 0.1234013371975599.
#               3       0.111713       0.123401       0.123401          00:03
# Better model found at epoch 4 with valid_loss value: 0.12270715651629137.
#               4       0.110411       0.122707       0.122707          00:03
# Better model found at epoch 5 with valid_loss value: 0.12240318676480426.
#               5       0.109749       0.122403       0.122403          00:03
# Better model found at epoch 6 with valid_loss value: 0.12223006119234213.
#               6       0.109190       0.122230       0.122230          00:03
# Better model found at epoch 7 with valid_loss value: 0.12170411161274802.
#               7       0.108683       0.121704       0.121704          00:03
# Better model found at epoch 8 with valid_loss value: 0.12148994082735572.
#               8       0.108305       0.121490       0.121490          00:03
# Better model found at epoch 9 with valid_loss value: 0.12138661422742054.
#               9       0.108110       0.121387       0.121387          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12136206147149782.
#               0       0.107854       0.121362       0.121362          00:17
# Better model found at epoch 1 with valid_loss value: 0.12116679520263873.
#               1       0.107215       0.121167       0.121167          00:17
#               2       0.106340       0.121199       0.121199          00:17
#               3       0.105329       0.121311       0.121311          00:17
#               4       0.103999       0.122317       0.122317          00:17
#               5       0.102116       0.124171       0.124171          00:17
#               6       0.099954       0.124292       0.124292          00:17
#               7       0.098097       0.125447       0.125447          00:17
#               8       0.096493       0.125509       0.125509          00:17
#               9       0.095109       0.125937       0.125937          00:15
#              10       0.093965       0.126652       0.126652          00:16
#              11       0.092883       0.126812       0.126812          00:17
#              12       0.091889       0.127792       0.127792          00:17
#              13       0.091320       0.127264       0.127264          00:12
#              14       0.090658       0.127415       0.127415          00:13
#              15       0.090216       0.127217       0.127217          00:07
#              16       0.089876       0.127377       0.127377          00:09
#              17       0.089614       0.127376       0.127376          00:15
#              18       0.089439       0.127345       0.127345          00:17
#              19       0.089401       0.127318       0.127318          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.04290265 rmse: 0.20712954 mae: 0.14442436
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 8.111308307896872e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08944408115474707.
#               0       0.139264       0.089444       0.089444          00:03
# Better model found at epoch 1 with valid_loss value: 0.07376325416166107.
#               1       0.106349       0.073763       0.073763          00:03
# Better model found at epoch 2 with valid_loss value: 0.0663974290111162.
#               2       0.090506       0.066397       0.066397          00:03
# Better model found at epoch 3 with valid_loss value: 0.06395896799947473.
#               3       0.080376       0.063959       0.063959          00:03
# Better model found at epoch 4 with valid_loss value: 0.062427812207832355.
#               4       0.075012       0.062428       0.062428          00:03
# Better model found at epoch 5 with valid_loss value: 0.06196237619003338.
#               5       0.072124       0.061962       0.061962          00:03
#               6       0.070846       0.061970       0.061970          00:03
# Better model found at epoch 7 with valid_loss value: 0.06153886073153752.
#               7       0.070131       0.061539       0.061539          00:03
# Better model found at epoch 8 with valid_loss value: 0.06107815182130399.
#               8       0.069650       0.061078       0.061078          00:03
# Better model found at epoch 9 with valid_loss value: 0.061036349071535205.
#               9       0.069598       0.061036       0.061036          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.059905308819630146.
#               0       0.069090       0.059905       0.059905          00:17
# Better model found at epoch 1 with valid_loss value: 0.05870482966469207.
#               1       0.067591       0.058705       0.058705          00:17
# Better model found at epoch 2 with valid_loss value: 0.05732943280364072.
#               2       0.065431       0.057329       0.057329          00:17
# Better model found at epoch 3 with valid_loss value: 0.05630328721587482.
#               3       0.063051       0.056303       0.056303          00:16
# Better model found at epoch 4 with valid_loss value: 0.05525932784477039.
#               4       0.061019       0.055259       0.055259          00:17
# Better model found at epoch 5 with valid_loss value: 0.05437688043651731.
#               5       0.059438       0.054377       0.054377          00:16
# Better model found at epoch 6 with valid_loss value: 0.05395578007347545.
#               6       0.058124       0.053956       0.053956          00:16
# Better model found at epoch 7 with valid_loss value: 0.05358722276274982.
#               7       0.057421       0.053587       0.053587          00:17
# Better model found at epoch 8 with valid_loss value: 0.05314015521484689.
#               8       0.056872       0.053140       0.053140          00:15
#               9       0.056264       0.053214       0.053213          00:16
# Better model found at epoch 10 with valid_loss value: 0.05283310920723922.
#              10       0.055852       0.052833       0.052833          00:17
# Better model found at epoch 11 with valid_loss value: 0.05254610554666137.
#              11       0.055529       0.052546       0.052546          00:17
# Better model found at epoch 12 with valid_loss value: 0.052324005122044395.
#              12       0.055150       0.052324       0.052324          00:17
#              13       0.054977       0.052347       0.052347          00:17
# Better model found at epoch 14 with valid_loss value: 0.052129236509394605.
#              14       0.054678       0.052129       0.052129          00:14
# Better model found at epoch 15 with valid_loss value: 0.05200875171687761.
#              15       0.054611       0.052009       0.052009          00:07
# Better model found at epoch 16 with valid_loss value: 0.05197342849149761.
#              16       0.054348       0.051973       0.051973          00:16
# Better model found at epoch 17 with valid_loss value: 0.05197004146738529.
#              17       0.054324       0.051970       0.051970          00:18
# Better model found at epoch 18 with valid_loss value: 0.05190825036662327.
#              18       0.054247       0.051908       0.051908          00:17
#              19       0.054293       0.051925       0.051925          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.009585491 rmse: 0.097905524 mae: 0.059343576
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0991600589115897.
#               0       0.146529       0.099160       0.099160          00:03
# Better model found at epoch 1 with valid_loss value: 0.08923572264035802.
#               1       0.117713       0.089236       0.089236          00:03
# Better model found at epoch 2 with valid_loss value: 0.08462834804401444.
#               2       0.107181       0.084628       0.084628          00:03
# Better model found at epoch 3 with valid_loss value: 0.08296838051134052.
#               3       0.098794       0.082968       0.082968          00:03
# Better model found at epoch 4 with valid_loss value: 0.08171383242378204.
#               4       0.093425       0.081714       0.081714          00:03
# Better model found at epoch 5 with valid_loss value: 0.08108293550396664.
#               5       0.090331       0.081083       0.081083          00:03
# Better model found at epoch 6 with valid_loss value: 0.08076643668315195.
#               6       0.088533       0.080766       0.080766          00:03
# Better model found at epoch 7 with valid_loss value: 0.08052321481355523.
#               7       0.087574       0.080523       0.080523          00:03
# Better model found at epoch 8 with valid_loss value: 0.08034011927729608.
#               8       0.087146       0.080340       0.080340          00:03
# Better model found at epoch 9 with valid_loss value: 0.08023693559614016.
#               9       0.086988       0.080237       0.080237          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.07973675025586097.
#               0       0.086646       0.079737       0.079737          00:17
# Better model found at epoch 1 with valid_loss value: 0.07877329367753255.
#               1       0.085635       0.078773       0.078773          00:17
# Better model found at epoch 2 with valid_loss value: 0.07748521846712265.
#               2       0.083985       0.077485       0.077485          00:14
# Better model found at epoch 3 with valid_loss value: 0.07669298313224675.
#               3       0.082105       0.076693       0.076693          00:17
# Better model found at epoch 4 with valid_loss value: 0.07583922594906936.
#               4       0.080391       0.075839       0.075839          00:17
# Better model found at epoch 5 with valid_loss value: 0.07554153429967199.
#               5       0.078911       0.075542       0.075542          00:17
# Better model found at epoch 6 with valid_loss value: 0.07464817627549074.
#               6       0.077762       0.074648       0.074648          00:17
# Better model found at epoch 7 with valid_loss value: 0.0743874334920413.
#               7       0.076832       0.074387       0.074387          00:17
# Better model found at epoch 8 with valid_loss value: 0.07410815171442738.
#               8       0.076048       0.074108       0.074108          00:17
#               9       0.075362       0.074254       0.074254          00:17
#              10       0.074842       0.074170       0.074170          00:17
# Better model found at epoch 11 with valid_loss value: 0.07404759828398343.
#              11       0.074390       0.074048       0.074048          00:16
# Better model found at epoch 12 with valid_loss value: 0.07398904625044497.
#              12       0.073968       0.073989       0.073989          00:17
#              13       0.073668       0.074086       0.074086          00:17
#              14       0.073476       0.074101       0.074101          00:17
#              15       0.073258       0.074059       0.074059          00:17
#              16       0.073175       0.074113       0.074113          00:16
#              17       0.072957       0.074125       0.074125          00:16
#              18       0.072914       0.074073       0.074073          00:12
#              19       0.072899       0.074054       0.074054          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018770661 rmse: 0.13700606 mae: 0.087181486
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09921470176009592.
#               0       0.141779       0.099215       0.099215          00:03
# Better model found at epoch 1 with valid_loss value: 0.09167394036616994.
#               1       0.117688       0.091674       0.091674          00:03
# Better model found at epoch 2 with valid_loss value: 0.08928460445118248.
#               2       0.106783       0.089285       0.089285          00:03
# Better model found at epoch 3 with valid_loss value: 0.08738728847845999.
# ...
#              19       0.042015       0.050190       0.050190          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# scores: mse: 0.010034576 rmse: 0.10017273 mae: 0.05466121
# ----------- Complete! -----------
# ==========Running command for FR, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='FR', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/FR/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00014174741629268049
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0851786874968216.
#               0       0.103586       0.085179       0.085179          00:03
# Better model found at epoch 1 with valid_loss value: 0.07978657162994558.
#               1       0.086508       0.079787       0.079787          00:03
# Better model found at epoch 2 with valid_loss value: 0.07801718777810975.
#               2       0.077502       0.078017       0.078017          00:03
# Better model found at epoch 3 with valid_loss value: 0.07687522447429312.
#               3       0.072124       0.076875       0.076875          00:03
#               4       0.070031       0.077025       0.077025          00:03
# Better model found at epoch 5 with valid_loss value: 0.0761573487321374.
#               5       0.069041       0.076157       0.076157          00:03
# Better model found at epoch 6 with valid_loss value: 0.07574390880066365.
#               6       0.068404       0.075744       0.075744          00:03
# Better model found at epoch 7 with valid_loss value: 0.07513980477490592.
#               7       0.067958       0.075140       0.075140          00:03
# Better model found at epoch 8 with valid_loss value: 0.07495755350036869.
#               8       0.067599       0.074958       0.074958          00:03
# Better model found at epoch 9 with valid_loss value: 0.07488406300059754.
#               9       0.067466       0.074884       0.074884          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.07435536147909887.
#               0       0.067155       0.074355       0.074355          00:17
# Better model found at epoch 1 with valid_loss value: 0.07346260437061382.
#               1       0.066158       0.073463       0.073463          00:17
# Better model found at epoch 2 with valid_loss value: 0.0720572463082918.
#               2       0.064481       0.072057       0.072057          00:10
# Better model found at epoch 3 with valid_loss value: 0.07162783989778275.
#               3       0.062668       0.071628       0.071628          00:15
# Better model found at epoch 4 with valid_loss value: 0.07134359187474573.
#               4       0.061261       0.071344       0.071344          00:16
# Better model found at epoch 5 with valid_loss value: 0.0712744468397198.
#               5       0.060361       0.071274       0.071274          00:09
#               6       0.059666       0.071783       0.071783          00:08
# Better model found at epoch 7 with valid_loss value: 0.07127396014766833.
#               7       0.058956       0.071274       0.071274          00:16
# Better model found at epoch 8 with valid_loss value: 0.07096505471610558.
#               8       0.058521       0.070965       0.070965          00:17
#               9       0.057904       0.071281       0.071281          00:11
#              10       0.057377       0.071695       0.071695          00:07
#              11       0.056879       0.071329       0.071329          00:17
#              12       0.056484       0.071606       0.071606          00:17
#              13       0.056160       0.071118       0.071118          00:17
#              14       0.055839       0.071387       0.071387          00:17
#              15       0.055543       0.071075       0.071075          00:15
#              16       0.055394       0.071164       0.071164          00:17
#              17       0.055220       0.071224       0.071224          00:17
#              18       0.055137       0.071090       0.071090          00:17
#              19       0.055150       0.071180       0.071180          00:17
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.01950871 rmse: 0.13967359 mae: 0.08099357
# ----------- Complete! -----------
# ==========Running command for FR, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='FR', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/FR/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00017073526474706903
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08744875579537502.
#               0       0.103654       0.087449       0.087449          00:03
# Better model found at epoch 1 with valid_loss value: 0.08293061151980333.
#               1       0.088578       0.082931       0.082931          00:03
# Better model found at epoch 2 with valid_loss value: 0.08193674751782995.
#               2       0.079892       0.081937       0.081937          00:03
# Better model found at epoch 3 with valid_loss value: 0.08111680305791258.
#               3       0.075319       0.081117       0.081117          00:03
#               4       0.073666       0.081383       0.081383          00:03
# Better model found at epoch 5 with valid_loss value: 0.08104990358194056.
#               5       0.072915       0.081050       0.081050          00:03
# Better model found at epoch 6 with valid_loss value: 0.07973779847628591.
#               6       0.072263       0.079738       0.079738          00:03
# Better model found at epoch 7 with valid_loss value: 0.07960308997689569.
#               7       0.071764       0.079603       0.079603          00:03
# Better model found at epoch 8 with valid_loss value: 0.07905171326980076.
#               8       0.071420       0.079052       0.079052          00:03
#               9       0.071201       0.079092       0.079092          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.07867237670838136.
#               0       0.070857       0.078672       0.078672          00:17
# Better model found at epoch 1 with valid_loss value: 0.07741902032755126.
#               1       0.069763       0.077419       0.077419          00:17
# Better model found at epoch 2 with valid_loss value: 0.07606821171675603.
#               2       0.067887       0.076068       0.076068          00:17
# Better model found at epoch 3 with valid_loss value: 0.07560081488215.
#               3       0.066142       0.075601       0.075601          00:16
# Better model found at epoch 4 with valid_loss value: 0.0754997345126482.
#               4       0.065055       0.075500       0.075500          00:17
#               5       0.064108       0.075709       0.075709          00:17
#               6       0.063234       0.075790       0.075790          00:16
#               7       0.062535       0.075504       0.075504          00:15
#               8       0.061864       0.075573       0.075573          00:17
# Better model found at epoch 9 with valid_loss value: 0.07527071951092437.
#               9       0.061287       0.075271       0.075271          00:17
# Better model found at epoch 10 with valid_loss value: 0.074959950766649.
#              10       0.060707       0.074960       0.074960          00:17
#              11       0.060128       0.075476       0.075476          00:16
#              12       0.059664       0.075396       0.075396          00:17
#              13       0.059172       0.075747       0.075747          00:17
#              14       0.058818       0.075246       0.075246          00:17
#              15       0.058558       0.075502       0.075502          00:14
#              16       0.058290       0.075285       0.075285          00:17
#              17       0.058123       0.075260       0.075260          00:17
#              18       0.058041       0.075206       0.075206          00:17
#              19       0.057981       0.075371       0.075371          00:13
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307816
# scores: mse: 0.02255438 rmse: 0.15018116 mae: 0.088616975
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533528
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08887572869123975.
#               0       0.143510       0.088876       0.088876          00:03
# Better model found at epoch 1 with valid_loss value: 0.07395235319047068.
#               1       0.108727       0.073952       0.073952          00:03
# Better model found at epoch 2 with valid_loss value: 0.06896266289917012.
#               2       0.090752       0.068963       0.068963          00:03
# Better model found at epoch 3 with valid_loss value: 0.06702677736102873.
#               3       0.080504       0.067027       0.067027          00:03
# Better model found at epoch 4 with valid_loss value: 0.06636285191278701.
#               4       0.076567       0.066363       0.066363          00:03
#               5       0.075207       0.066624       0.066624          00:03
#               6       0.074405       0.066526       0.066526          00:03
# Better model found at epoch 7 with valid_loss value: 0.06559601001883696.
#               7       0.073849       0.065596       0.065596          00:03
# Better model found at epoch 8 with valid_loss value: 0.06542741966646393.
#               8       0.073514       0.065427       0.065427          00:03
# Better model found at epoch 9 with valid_loss value: 0.06526901983881142.
#               9       0.073297       0.065269       0.065269          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.06365651165497577.
#               0       0.072377       0.063657       0.063657          00:15
# Better model found at epoch 1 with valid_loss value: 0.06160723934876146.
#               1       0.069905       0.061607       0.061607          00:15
# Better model found at epoch 2 with valid_loss value: 0.059832836321087844.
#               2       0.067021       0.059833       0.059833          00:17
# Better model found at epoch 3 with valid_loss value: 0.05850935419483624.
#               3       0.064395       0.058509       0.058509          00:17
# Better model found at epoch 4 with valid_loss value: 0.05810095271785025.
#               4       0.062396       0.058101       0.058101          00:16
# Better model found at epoch 5 with valid_loss value: 0.057223865643409706.
#               5       0.061066       0.057224       0.057224          00:17
# Better model found at epoch 6 with valid_loss value: 0.05665957760883716.
#               6       0.059977       0.056660       0.056660          00:17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 37
#      35 # Capture the output in real-time
#      36 output = []
# ---> 37 for line in process.stdout:
#      38     output.append(line)
#      39     print(line, end='')  # Print in the .ipynb cell
#
# KeyboardInterrupt:

# %%
data
# Out:
# [{'Country': 'DE',
#   'Pred_len': '24',
#   'MSE': 0.02097016,
#   'RMSE': 0.14481078,
#   'MAE': 0.0884165},
#  {'Country': 'DE',
#   'Pred_len': '96',
#   'MSE': 0.034867324,
#   'RMSE': 0.18672794,
#   'MAE': 0.12519094},
#  {'Country': 'DE',
#   'Pred_len': '168',
#   'MSE': 0.037424114,
#   'RMSE': 0.19345313,
#   'MAE': 0.13087086},
#  {'Country': 'GB',
#   'Pred_len': '24',
#   'MSE': 0.024337353,
#   'RMSE': 0.15600434,
#   'MAE': 0.09926091},
#  {'Country': 'GB',
#   'Pred_len': '96',
#   'MSE': 0.04080385,
#   'RMSE': 0.20199963,
#   'MAE': 0.13886747},
#  {'Country': 'GB',
#   'Pred_len': '168',
#   'MSE': 0.04290265,
#   'RMSE': 0.20712954,
#   'MAE': 0.14442436},
#  {'Country': 'ES',
#   'Pred_len': '24',
#   'MSE': 0.009585491,
#   'RMSE': 0.097905524,
#   'MAE': 0.059343576},
#  {'Country': 'ES',
#   'Pred_len': '96',
#   'MSE': 0.018770661,
#   'RMSE': 0.13700606,
#   'MAE': 0.087181486},
#  {'Country': 'ES',
#   'Pred_len': '168',
#   'MSE': 0.021218585,
#   'RMSE': 0.145666,
#   'MAE': 0.09426425},
#  {'Country': 'FR',
#   'Pred_len': '24',
#   'MSE': 0.010034576,
#   'RMSE': 0.10017273,
#   'MAE': 0.05466121},
#  {'Country': 'FR',
#   'Pred_len': '96',
#   'MSE': 0.01950871,
#   'RMSE': 0.13967359,
#   'MAE': 0.08099357},
#  {'Country': 'FR',
#   'Pred_len': '168',
#   'MSE': 0.02255438,
#   'RMSE': 0.15018116,
#   'MAE': 0.088616975}]

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup.columns = pd.MultiIndex.from_product([['Self-supervised'], ['MSE','RMSE', 'MAE']], names=['Model', 'Metrics'])

# Path if not exists
path = "results/patchtst/"
if not os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results.csv"), index=True)
df_self_sup.round(4)
# Out:
# Model            Self-supervised
# Metrics                      MSE    RMSE     MAE
# Country Pred_len
# DE      24                0.0215  0.1465  0.0899
#         96                0.0356  0.1887  0.1255
#         168               0.0378  0.1945  0.1316
# GB      24                0.0247  0.1573  0.1000
#         96                0.0413  0.2033  0.1393
#         168               0.0433  0.2081  0.1448
# ES      24                0.0095  0.0976  0.0589
#         96                0.0185  0.1361  0.0866
#         168               0.0215  0.1466  0.0941
# FR      24                0.0101  0.1003  0.0549
#         96                0.0207  0.1440  0.0821
#         168               0.0218  0.1476  0.0866
# IT      24                0.0103  0.1016  0.0582
#         96                0.0189  0.1375  0.0825
#         168               0.0205  0.1432  0.0871

# %%
import os
# Convert the list of dictionaries into a DataFrame
df_self_sup = pd.DataFrame(data)

# Set MultiIndex
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup = df_self_sup.sort_index().round(4)

path = "results/PatchTST/"
if not os.path.exists(path):
    os.makedirs(path)


# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results.csv"), index=True)
df_self_sup

# %%
df_self_sup.to_csv("finetune_results.csv", index=False)

# %%
import numpy as np
import pandas as pd
coun = np.repeat(["DE", "GB", "ES", "FR", "IT"], 3)
pred = np.array([24, 96, 168]*5)

df = pd.DataFrame({'Country': coun, 'Pred_len': pred})
df_2 = pd.read_csv("finetune_results.csv")
final = pd.concat([df, df_2], axis=1)
final
# Out:
#    Country  Pred_len     MSE    RMSE     MAE
# 0       DE        24  0.0210  0.1448  0.0887
# 1       DE        96  0.0363  0.1906  0.1269
# 2       DE       168  0.0379  0.1947  0.1319
# 3       GB        24  0.0242  0.1557  0.0991
# 4       GB        96  0.0403  0.2007  0.1385
# 5       GB       168  0.0431  0.2076  0.1441
# 6       ES        24  0.0098  0.0990  0.0607
# 7       ES        96  0.0185  0.1358  0.0871
# 8       ES       168  0.0213  0.1458  0.0952
# 9       FR        24  0.0100  0.1001  0.0554
# 10      FR        96  0.0201  0.1419  0.0813
# 11      FR       168  0.0212  0.1455  0.0854
# 12      IT        24  0.0102  0.1008  0.0590
# 13      IT        96  0.0184  0.1355  0.0821
# 14      IT       168  0.0203  0.1426  0.0875

# %%
import os
path = "results/PatchTST/"
if not os.path.exists(path):
    os.makedirs(path)


# Save the results to a CSV file
final.to_csv(os.path.join(path, "finetune_results.csv"), index=False)
final
# Out:
#    Country  Pred_len     MSE    RMSE     MAE
# 0       DE        24  0.0210  0.1448  0.0887
# 1       DE        96  0.0363  0.1906  0.1269
# 2       DE       168  0.0379  0.1947  0.1319
# 3       GB        24  0.0242  0.1557  0.0991
# 4       GB        96  0.0403  0.2007  0.1385
# 5       GB       168  0.0431  0.2076  0.1441
# 6       ES        24  0.0098  0.0990  0.0607
# 7       ES        96  0.0185  0.1358  0.0871
# 8       ES       168  0.0213  0.1458  0.0952
# 9       FR        24  0.0100  0.1001  0.0554
# 10      FR        96  0.0201  0.1419  0.0813
# 11      FR       168  0.0212  0.1455  0.0854
# 12      IT        24  0.0102  0.1008  0.0590
# 13      IT        96  0.0184  0.1355  0.0821
# 14      IT       168  0.0203  0.1426  0.0875

# %%
final.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
final.to_csv("finetune_results.csv", index=False)

# %% [markdown]
# # Test on bugs for Italy

# %%
countries = ['DE', 'GB', 'ES', 'FR', 'IT']
pred_lens = ["24", "96", "168"]

for country in countries:
    for pred_len in pred_lens:
        # Just use the same parameters as from the paper
        params = {
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len
            }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Complete command
        # !{command}
# Out:
# args: Namespace(dset_pretrain='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 603404
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.8967356272884459.
#               0       0.938521       0.896736          00:09
# Better model found at epoch 1 with valid_loss value: 0.8881698471826688.
#               1       0.896467       0.888170          00:09
# Better model found at epoch 2 with valid_loss value: 0.8823258079485354.
#               2       0.885393       0.882326          00:09
# Better model found at epoch 3 with valid_loss value: 0.8821932687906835.
#               3       0.878312       0.882193          00:09
# Better model found at epoch 4 with valid_loss value: 0.8765498658716436.
#               4       0.876024       0.876550          00:09
#               5       0.872625       0.877340          00:09
# Better model found at epoch 6 with valid_loss value: 0.8757813294599268.
#               6       0.871166       0.875781          00:09
#               7       0.869507       0.877671          00:09
# Better model found at epoch 8 with valid_loss value: 0.873351206519528.
#               8       0.867975       0.873351          00:09
#               9       0.867239       0.875410          00:09
#              10       0.867303       0.873736          00:09
# Better model found at epoch 11 with valid_loss value: 0.495188105484642.
#              11       0.608950       0.495188          00:09
# Better model found at epoch 12 with valid_loss value: 0.4847974089707079.
#              12       0.503978       0.484797          00:09
# Better model found at epoch 13 with valid_loss value: 0.4774695747940399.
#              13       0.495159       0.477470          00:09
# Better model found at epoch 14 with valid_loss value: 0.4762754510145443.
#              14       0.490194       0.476275          00:09
#              15       0.486599       0.476790          00:09
# Better model found at epoch 16 with valid_loss value: 0.4751617804109032.
#              16       0.484648       0.475162          00:09
# Better model found at epoch 17 with valid_loss value: 0.47410210282750204.
#              17       0.482739       0.474102          00:09
# Better model found at epoch 18 with valid_loss value: 0.4726005883212978.
#              18       0.481069       0.472601          00:09
# Better model found at epoch 19 with valid_loss value: 0.4454305774511798.
#              19       0.473361       0.445431          00:09
# Better model found at epoch 20 with valid_loss value: 0.318727651895596.
#              20       0.419336       0.318728          00:09
# Better model found at epoch 21 with valid_loss value: 0.2427597703925956.
#              21       0.313724       0.242760          00:09
# Better model found at epoch 22 with valid_loss value: 0.22882416789564686.
#              22       0.260966       0.228824          00:09
# Better model found at epoch 23 with valid_loss value: 0.21324038773265866.
#              23       0.242250       0.213240          00:09
# Better model found at epoch 24 with valid_loss value: 0.180197354620118.
#              24       0.222249       0.180197          00:09
# Better model found at epoch 25 with valid_loss value: 0.1609063417762154.
#              25       0.196233       0.160906          00:09
# Better model found at epoch 26 with valid_loss value: 0.15310471785369204.
#              26       0.180621       0.153105          00:09
# Better model found at epoch 27 with valid_loss value: 0.148449061419345.
#              27       0.170199       0.148449          00:09
# Better model found at epoch 28 with valid_loss value: 0.14366076650223758.
#              28       0.162535       0.143661          00:09
# Better model found at epoch 29 with valid_loss value: 0.1396192061794396.
#              29       0.156692       0.139619          00:09
# Better model found at epoch 30 with valid_loss value: 0.13863732979683685.
#              30       0.151614       0.138637          00:09
# Better model found at epoch 31 with valid_loss value: 0.1341101203341131.
#              31       0.148787       0.134110          00:09
# Better model found at epoch 32 with valid_loss value: 0.13148661179693857.
#              32       0.145196       0.131487          00:09
#              33       0.143299       0.133147          00:09
#              34       0.140370       0.132577          00:09
# Better model found at epoch 35 with valid_loss value: 0.13096277222970912.
#              35       0.138300       0.130963          00:09
# Better model found at epoch 36 with valid_loss value: 0.12906480235137816.
#              36       0.136646       0.129065          00:09
# Better model found at epoch 37 with valid_loss value: 0.12854402199132933.
#              37       0.134263       0.128544          00:09
# Better model found at epoch 38 with valid_loss value: 0.1268503733821959.
#              38       0.132729       0.126850          00:09
#              39       0.131227       0.128180          00:09
#              40       0.129391       0.126982          00:09
# Better model found at epoch 41 with valid_loss value: 0.1263340030480828.
#              41       0.128036       0.126334          00:09
#              42       0.127176       0.129643          00:09
#              43       0.126021       0.128046          00:08
# Better model found at epoch 44 with valid_loss value: 0.12491932830934703.
#              44       0.124882       0.124919          00:09
#              45       0.123773       0.129891          00:09
#              46       0.122938       0.125227          00:09
#              47       0.122092       0.128650          00:09
#              48       0.120755       0.129128          00:09
#              49       0.119283       0.132512          00:09
# No improvement since epoch 44: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_model1_losses.csv

# %%
# IT IS BETTER!
# Define parameters in a dictionary
params = {
    "--dset": "IT",
    "--linear_prob_finetune": 1,
    "--pretrained_model": "saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain30_mask0.4_model1.pth",    
    "--scaler_type": "minmax",
    "--n_epochs_finetune": 10,
    "--n_epochs_linear_probe": 20
}

# Build the command string
command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

# Add parameters to the command
for key, value in params.items():
    if value is not None:
        command += f"{key} {value} "
    else:
        command += f"{key} "  # Add flags with no value

# Run the command with !
# !{command}
# Out:
# args: Namespace(linear_prob_finetune=1, is_finetune=0, is_linear_probe=0, n_epochs_linear_probe=20, dset_finetune='IT', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=12, stride=12, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=10, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain30_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# Performing linear probing followed by end-to-end fine-tuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Starting linear probing for 10 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.10813757056041497.
#               0       0.161137       0.108138          00:04
# Better model found at epoch 1 with valid_loss value: 0.09656939712164361.
#               1       0.132584       0.096569          00:04
# Better model found at epoch 2 with valid_loss value: 0.09087136550294955.
#               2       0.123537       0.090871          00:04
# Better model found at epoch 3 with valid_loss value: 0.08758014526863812.
#               3       0.114970       0.087580          00:04
# Better model found at epoch 4 with valid_loss value: 0.08586278780385476.
#               4       0.106743       0.085863          00:04
# Better model found at epoch 5 with valid_loss value: 0.0844781985798922.
#               5       0.099737       0.084478          00:04
# Better model found at epoch 6 with valid_loss value: 0.0842069819848454.
#               6       0.094818       0.084207          00:04
# Better model found at epoch 7 with valid_loss value: 0.08405468710270037.
#               7       0.092057       0.084055          00:04
# Better model found at epoch 8 with valid_loss value: 0.08382456122228438.
#               8       0.090704       0.083825          00:04
#               9       0.090003       0.083871          00:04
# Better model found at epoch 10 with valid_loss value: 0.08365624523240439.
#              10       0.089537       0.083656          00:04
# Better model found at epoch 11 with valid_loss value: 0.08359747468406734.
#              11       0.089301       0.083597          00:04
# Better model found at epoch 12 with valid_loss value: 0.08344239870448536.
#              12       0.089119       0.083442          00:04
# Better model found at epoch 13 with valid_loss value: 0.08318924434404242.
#              13       0.088892       0.083189          00:04
# Better model found at epoch 14 with valid_loss value: 0.08296695519890408.
#              14       0.088728       0.082967          00:04
#              15       0.088581       0.082979          00:04
# Better model found at epoch 16 with valid_loss value: 0.08290457419014442.
#              16       0.088482       0.082905          00:04
# Better model found at epoch 17 with valid_loss value: 0.08284981140186382.
#              17       0.088394       0.082850          00:04
# Better model found at epoch 18 with valid_loss value: 0.08275175785222996.
#              18       0.088338       0.082752          00:04
#              19       0.088268       0.082760          00:04
# Starting full fine-tuning for 20 epochs
# Finetune the head
#           epoch     train_loss     valid_loss           time
#               0       0.088347       0.083214          00:04
#               1       0.088748       0.083694          00:04
#               2       0.089289       0.083948          00:04
#               3       0.089499       0.084088          00:04
#               4       0.089419       0.083947          00:04
#               5       0.089231       0.083624          00:04
#               6       0.088961       0.083192          00:04
#               7       0.088721       0.082865          00:04
#               8       0.088478       0.082801          00:04
#               9       0.088414       0.082753          00:04
# Finetune the entire network
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.081913217245029.
#               0       0.087893       0.081913          00:08
# Better model found at epoch 1 with valid_loss value: 0.08021011290460994.
#               1       0.085796       0.080210          00:08
# Better model found at epoch 2 with valid_loss value: 0.07895167624688518.
#               2       0.082999       0.078952          00:07
# Better model found at epoch 3 with valid_loss value: 0.0781030342964936.
#               3       0.081195       0.078103          00:08
# Better model found at epoch 4 with valid_loss value: 0.07764475910134001.
#               4       0.080039       0.077645          00:08
# Better model found at epoch 5 with valid_loss value: 0.07738752248715927.
#               5       0.079188       0.077388          00:08
# Better model found at epoch 6 with valid_loss value: 0.07722825003019478.
#               6       0.078624       0.077228          00:08
# Better model found at epoch 7 with valid_loss value: 0.0770519830813924.
#               7       0.078195       0.077052          00:08
#               8       0.077899       0.077059          00:08
# Better model found at epoch 9 with valid_loss value: 0.07698487420698993.
#               9       0.077870       0.076985          00:08
# Linear probing and finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920672
# scores: mse: 0.018168202 rmse: 0.13478947 mae: 0.081972055
# ----------- Complete! -----------
