# %% [markdown]
# <summary>Table of Contents</summary>
#
# - [1. Pretrain](#1-pretrain)
# - [2. Finetune](#2-finetune)
#
#
# This notebook demonstrates experiments on 5 countries with self-supervised learning.
# All parameters and settings are taken from the paper.

# %%
import pandas as pd
import subprocess
import os
import time
from utils.helper import extract_metrics_from_output, running_time

# %% [markdown]
# # 1. Pretrain
#
# Tracking loss - MAE.

# %%
# Dynamic variables

countries = ['DE', 'GB', 'ES', 'FR', 'IT']
seq_lens = [512, 512, 336, 168, 168]
pred_lens = ["24", "96", "168"]

# %%
#cuda_device = "1"
#os.environ["CUDA_VISIBLE_DEVICES"] = cuda_device

start = time.time()

countries = ['DE', 'GB', 'ES', 'FR', 'IT']
seq_lens = [512, 512, 336, 168, 168]
pred_lens = ["24", "96", "168"]

for i, country in enumerate(countries):
    for pred_len in pred_lens:
        if country == 'DE' and pred_len == '24':
            seq_len = 336
        else:
            seq_len = seq_lens[i]
            
        # Just use the same parameters as from the paper
        params = {
            "--context_points": seq_len,
            "--dset": country,
            "--mask_ratio": 0.4,
            "--scaler_type": "minmax",
            "--n_epochs_pretrain": 100,
            "--target_points": pred_len,
            "--patch_len": 8,
            "--stride": 8
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_pretrain.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        # Execute the command
        print(f"==========Running command for {country}, pred_len {pred_len}:==========")
        # !{command}
        
end = time.time()
hours, mins, secs = running_time(start, end)
print("Total time: {:0>2}h:{:0>2}m:{:05.2f}s".format(hours, mins, secs))
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(dset_pretrain='DE', context_points=336, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
# suggested_lr 0.00014174741629268049
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9700153529385154.
#               0       1.018714       0.970015          00:10
# Better model found at epoch 1 with valid_loss value: 0.9671504606824031.
#               1       0.982733       0.967150          00:10
# Better model found at epoch 2 with valid_loss value: 0.9626685932976113.
#               2       0.973053       0.962669          00:10
#               3       0.968034       0.964007          00:10
#               4       0.966930       0.964189          00:10
#               5       0.964958       0.963303          00:10
# Better model found at epoch 6 with valid_loss value: 0.9615600055794595.
#               6       0.964181       0.961560          00:10
#               7       0.963316       0.961869          00:10
# Better model found at epoch 8 with valid_loss value: 0.9614165921063214.
#               8       0.963788       0.961417          00:10
#               9       0.963160       0.961440          00:10
# Better model found at epoch 10 with valid_loss value: 0.9609740209556458.
#              10       0.961186       0.960974          00:10
#              11       0.962106       0.961130          00:10
# Better model found at epoch 12 with valid_loss value: 0.9593747957968072.
#              12       0.961553       0.959375          00:10
#              13       0.962074       0.961232          00:10
#              14       0.961749       0.962327          00:09
# Better model found at epoch 15 with valid_loss value: 0.7070812797822503.
#              15       0.871691       0.707081          00:07
# Better model found at epoch 16 with valid_loss value: 0.6772952595956652.
#              16       0.716496       0.677295          00:07
# Better model found at epoch 17 with valid_loss value: 0.6577763010570814.
#              17       0.692767       0.657776          00:08
# Better model found at epoch 18 with valid_loss value: 0.653314775451886.
#              18       0.679103       0.653315          00:10
# Better model found at epoch 19 with valid_loss value: 0.6523543135882459.
#              19       0.672329       0.652354          00:10
# Better model found at epoch 20 with valid_loss value: 0.6390941043710793.
#              20       0.667482       0.639094          00:10
# Better model found at epoch 21 with valid_loss value: 0.517997369862876.
#              21       0.592632       0.517997          00:10
# Better model found at epoch 22 with valid_loss value: 0.3472429741535306.
#              22       0.462355       0.347243          00:10
# Better model found at epoch 23 with valid_loss value: 0.2872866194444165.
#              23       0.377112       0.287287          00:07
# Better model found at epoch 24 with valid_loss value: 0.23403735787457777.
#              24       0.329218       0.234037          00:08
# Better model found at epoch 25 with valid_loss value: 0.20516610908723057.
#              25       0.288632       0.205166          00:10
# Better model found at epoch 26 with valid_loss value: 0.1895095557669495.
#              26       0.254931       0.189510          00:10
# Better model found at epoch 27 with valid_loss value: 0.179996651853034.
#              27       0.228315       0.179997          00:10
# Better model found at epoch 28 with valid_loss value: 0.17193897057714733.
#              28       0.211387       0.171939          00:10
# Better model found at epoch 29 with valid_loss value: 0.16776144448940405.
#              29       0.199661       0.167761          00:10
# Better model found at epoch 30 with valid_loss value: 0.1603592260102089.
#              30       0.190472       0.160359          00:10
# Better model found at epoch 31 with valid_loss value: 0.15622966803786492.
#              31       0.182704       0.156230          00:10
# Better model found at epoch 32 with valid_loss value: 0.15139824012976014.
#              32       0.176996       0.151398          00:10
# Better model found at epoch 33 with valid_loss value: 0.15119680546095887.
#              33       0.171763       0.151197          00:10
# Better model found at epoch 34 with valid_loss value: 0.14980554358261622.
#              34       0.167427       0.149806          00:10
#              35       0.164255       0.151096          00:10
#              36       0.160940       0.150865          00:10
#              37       0.159077       0.150452          00:10
#              38       0.155993       0.150739          00:10
# Better model found at epoch 39 with valid_loss value: 0.14901617061522338.
#              39       0.153959       0.149016          00:10
# Better model found at epoch 40 with valid_loss value: 0.14643188103498975.
#              40       0.152278       0.146432          00:10
#              41       0.150406       0.149640          00:10
#              42       0.148903       0.152110          00:10
#              43       0.147210       0.151908          00:10
#              44       0.145979       0.153321          00:10
#              45       0.144246       0.157244          00:10
# No improvement since epoch 40: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9773816523850691.
#               0       1.015385       0.977382          00:11
# Better model found at epoch 1 with valid_loss value: 0.9760373493439789.
#               1       0.986422       0.976037          00:11
# Better model found at epoch 2 with valid_loss value: 0.9755025840368186.
#               2       0.980773       0.975503          00:11
# Better model found at epoch 3 with valid_loss value: 0.9738939972792922.
#               3       0.978414       0.973894          00:11
# Better model found at epoch 4 with valid_loss value: 0.9735431022426769.
#               4       0.977008       0.973543          00:11
# Better model found at epoch 5 with valid_loss value: 0.9734792164615541.
#               5       0.976483       0.973479          00:11
#               6       0.975637       0.974525          00:11
#               7       0.974097       0.973867          00:11
# Better model found at epoch 8 with valid_loss value: 0.9702915225793328.
#               8       0.975010       0.970292          00:11
#               9       0.974171       0.972615          00:11
#              10       0.974242       0.972874          00:11
#              11       0.973079       0.972851          00:11
#              12       0.973752       0.972908          00:11
#              13       0.973377       0.975076          00:10
# No improvement since epoch 8: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(dset_pretrain='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
# suggested_lr 0.00043287612810830566
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9759483092427548.
#               0       0.997081       0.975948          00:11
# Better model found at epoch 1 with valid_loss value: 0.9747310232020829.
#               1       0.978563       0.974731          00:11
# Better model found at epoch 2 with valid_loss value: 0.9734800487300346.
#               2       0.977754       0.973480          00:11
#               3       0.975427       0.973846          00:11
# Better model found at epoch 4 with valid_loss value: 0.9726207927249712.
#               4       0.975080       0.972621          00:11
# Better model found at epoch 5 with valid_loss value: 0.9723282099044953.
#               5       0.973945       0.972328          00:11
#               6       0.974036       0.972699          00:11
#               7       0.973649       0.973966          00:11
# Better model found at epoch 8 with valid_loss value: 0.9716956070928701.
#               8       0.973041       0.971696          00:11
#               9       0.973100       0.972258          00:11
#              10       0.972890       0.972291          00:11
# Better model found at epoch 11 with valid_loss value: 0.6793937111497612.
#              11       0.808381       0.679394          00:11
# Better model found at epoch 12 with valid_loss value: 0.5597823325323151.
#              12       0.656669       0.559782          00:11
# Better model found at epoch 13 with valid_loss value: 0.3684634794891322.
#              13       0.492950       0.368463          00:11
# Better model found at epoch 14 with valid_loss value: 0.24871503558913427.
#              14       0.361585       0.248715          00:11
# Better model found at epoch 15 with valid_loss value: 0.20710274746444302.
#              15       0.275549       0.207103          00:11
# Better model found at epoch 16 with valid_loss value: 0.18142743913891404.
#              16       0.227607       0.181427          00:11
# Better model found at epoch 17 with valid_loss value: 0.1639285100933435.
#              17       0.197908       0.163929          00:10
# Better model found at epoch 18 with valid_loss value: 0.1552850555867158.
#              18       0.181354       0.155285          00:11
# Better model found at epoch 19 with valid_loss value: 0.15310137789704428.
#              19       0.171732       0.153101          00:10
# Better model found at epoch 20 with valid_loss value: 0.1511602126921929.
#              20       0.165114       0.151160          00:11
# Better model found at epoch 21 with valid_loss value: 0.1482278518262185.
#              21       0.160832       0.148228          00:11
#              22       0.157236       0.152542          00:10
#              23       0.153390       0.150571          00:10
#              24       0.150789       0.156227          00:10
#              25       0.148062       0.152206          00:10
# Better model found at epoch 26 with valid_loss value: 0.14482460668957373.
#              26       0.145581       0.144825          00:10
#              27       0.144289       0.156548          00:11
#              28       0.142020       0.157310          00:11
#              29       0.140888       0.162515          00:10
#              30       0.139680       0.157890          00:10
#              31       0.137955       0.164377          00:10
# No improvement since epoch 26: early stopping
# pretraining completed
# Model saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
# suggested_lr 0.00020565123083486514
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9769083102531365.
#               0       1.009609       0.976908          00:11
# Better model found at epoch 1 with valid_loss value: 0.9756797924290252.
#               1       0.983355       0.975680          00:11
# Better model found at epoch 2 with valid_loss value: 0.9744504892080184.
#               2       0.978924       0.974450          00:11
# Better model found at epoch 3 with valid_loss value: 0.973737427366495.
#               3       0.976088       0.973737          00:11
#               4       0.975365       0.973863          00:11
# Better model found at epoch 5 with valid_loss value: 0.9725497501809555.
#               5       0.974559       0.972550          00:11
#               6       0.974147       0.973173          00:11
#               7       0.973120       0.973005          00:11
# Better model found at epoch 8 with valid_loss value: 0.9720500806759691.
#               8       0.972758       0.972050          00:11
#               9       0.973508       0.972562          00:11
#              10       0.972036       0.973440          00:11
# Better model found at epoch 11 with valid_loss value: 0.970888949905501.
#              11       0.972444       0.970889          00:11
#              12       0.972247       0.972115          00:11
# Better model found at epoch 13 with valid_loss value: 0.9291564931588788.
#              13       0.970286       0.929156          00:11
# Better model found at epoch 14 with valid_loss value: 0.6698808772820493.
#              14       0.722102       0.669881          00:11
# Better model found at epoch 15 with valid_loss value: 0.6568384193541901.
#              15       0.665885       0.656838          00:11
# Better model found at epoch 16 with valid_loss value: 0.6496865952227763.
#              16       0.654493       0.649687          00:11
# Better model found at epoch 17 with valid_loss value: 0.6494033418323749.
#              17       0.649140       0.649403          00:11
#              18       0.645916       0.649820          00:11
# Better model found at epoch 19 with valid_loss value: 0.6135912854245416.
#              19       0.636339       0.613591          00:11
# Better model found at epoch 20 with valid_loss value: 0.4056433987076765.
#              20       0.519821       0.405643          00:11
# Better model found at epoch 21 with valid_loss value: 0.2940371843018638.
#              21       0.375297       0.294037          00:11
# Better model found at epoch 22 with valid_loss value: 0.25484313032184935.
#              22       0.299449       0.254843          00:11
# Better model found at epoch 23 with valid_loss value: 0.24102094999095222.
#              23       0.264512       0.241021          00:11
# Better model found at epoch 24 with valid_loss value: 0.2302288505182363.
#              24       0.246444       0.230229          00:11
# Better model found at epoch 25 with valid_loss value: 0.2205666033846208.
#              25       0.232677       0.220567          00:11
# Better model found at epoch 26 with valid_loss value: 0.21100188291051752.
#              26       0.221644       0.211002          00:11
# Better model found at epoch 27 with valid_loss value: 0.20086091673410608.
#              27       0.210394       0.200861          00:11
# Better model found at epoch 28 with valid_loss value: 0.19545347874276178.
#              28       0.198214       0.195453          00:11
# Better model found at epoch 29 with valid_loss value: 0.19152402026449655.
#              29       0.190233       0.191524          00:11
# Better model found at epoch 30 with valid_loss value: 0.18943983215754182.
#              30       0.185177       0.189440          00:11
# Better model found at epoch 31 with valid_loss value: 0.185703463506062.
#              31       0.182323       0.185703          00:11
#              32       0.179765       0.188573          00:11
#              33       0.177565       0.188310          00:11
# Better model found at epoch 34 with valid_loss value: 0.18501771384158355.
#              34       0.175584       0.185018          00:11
#              35       0.174161       0.185179          00:11
# Better model found at epoch 36 with valid_loss value: 0.1832691258281225.
#              36       0.172420       0.183269          00:11
#              37       0.171309       0.186012          00:11
#              38       0.170046       0.184626          00:11
#              39       0.168723       0.183904          00:11
#              40       0.167728       0.185773          00:11
#              41       0.166826       0.186094          00:11
# No improvement since epoch 36: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.97794248054821.
#               0       1.003023       0.977942          00:10
# Better model found at epoch 1 with valid_loss value: 0.9764894763272987.
#               1       0.980926       0.976489          00:10
# Better model found at epoch 2 with valid_loss value: 0.9740166039462979.
#               2       0.976686       0.974017          00:10
#               3       0.974855       0.974159          00:10
# Better model found at epoch 4 with valid_loss value: 0.9729883130339707.
#               4       0.974076       0.972988          00:10
#               5       0.973547       0.973211          00:10
#               6       0.973989       0.974504          00:10
#               7       0.972943       0.974253          00:10
#               8       0.973034       0.973854          00:10
# Better model found at epoch 9 with valid_loss value: 0.9727741685313263.
#               9       0.972526       0.972774          00:10
# Better model found at epoch 10 with valid_loss value: 0.971078890993694.
#              10       0.971897       0.971079          00:10
# Better model found at epoch 11 with valid_loss value: 0.9707194142849878.
#              11       0.972300       0.970719          00:10
# Better model found at epoch 12 with valid_loss value: 0.6740241526393409.
#              12       0.781071       0.674024          00:10
# Better model found at epoch 13 with valid_loss value: 0.6564857973326892.
#              13       0.666869       0.656486          00:10
# Better model found at epoch 14 with valid_loss value: 0.6532885682592555.
#              14       0.653310       0.653289          00:10
# Better model found at epoch 15 with valid_loss value: 0.6495101295514646.
#              15       0.648414       0.649510          00:10
# Better model found at epoch 16 with valid_loss value: 0.6490411570636696.
#              16       0.645070       0.649041          00:11
# Better model found at epoch 17 with valid_loss value: 0.5705614082206062.
#              17       0.622910       0.570561          00:11
# Better model found at epoch 18 with valid_loss value: 0.3777929369660293.
#              18       0.462608       0.377793          00:10
# Better model found at epoch 19 with valid_loss value: 0.32620318221114725.
#              19       0.368375       0.326203          00:10
# Better model found at epoch 20 with valid_loss value: 0.25130781106972133.
#              20       0.314772       0.251308          00:10
# Better model found at epoch 21 with valid_loss value: 0.22786679496796175.
#              21       0.257019       0.227867          00:11
# Better model found at epoch 22 with valid_loss value: 0.2154859053981896.
#              22       0.229492       0.215486          00:11
# Better model found at epoch 23 with valid_loss value: 0.19843823500432262.
#              23       0.208787       0.198438          00:11
# Better model found at epoch 24 with valid_loss value: 0.19173233367448128.
#              24       0.195544       0.191732          00:11
# Better model found at epoch 25 with valid_loss value: 0.19102329288293327.
#              25       0.187400       0.191023          00:10
# Better model found at epoch 26 with valid_loss value: 0.1900647876512917.
#              26       0.182328       0.190065          00:10
# Better model found at epoch 27 with valid_loss value: 0.1856148529673515.
#              27       0.178094       0.185615          00:11
#              28       0.174609       0.186099          00:10
# Better model found at epoch 29 with valid_loss value: 0.1845874162492372.
#              29       0.171702       0.184587          00:10
# Better model found at epoch 30 with valid_loss value: 0.18322984340037632.
#              30       0.169149       0.183230          00:10
# Better model found at epoch 31 with valid_loss value: 0.18315501201434092.
#              31       0.167199       0.183155          00:10
# Better model found at epoch 32 with valid_loss value: 0.18224541436762612.
#              32       0.165646       0.182245          00:10
#              33       0.163553       0.188998          00:10
#              34       0.162393       0.185586          00:10
#              35       0.161283       0.190399          00:10
#              36       0.159986       0.194151          00:10
#              37       0.158577       0.190608          00:10
# No improvement since epoch 32: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(dset_pretrain='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
# suggested_lr 0.00014174741629268049
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 605192
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9801596847727647.
#               0       1.019229       0.980160          00:11
# Better model found at epoch 1 with valid_loss value: 0.9769617762534991.
#               1       0.988737       0.976962          00:11
# Better model found at epoch 2 with valid_loss value: 0.9763280478140952.
#               2       0.981415       0.976328          00:11
# Better model found at epoch 3 with valid_loss value: 0.9747238674254899.
#               3       0.978203       0.974724          00:11
# Better model found at epoch 4 with valid_loss value: 0.9737569531635929.
#               4       0.976660       0.973757          00:11
#               5       0.976014       0.974032          00:11
#               6       0.974783       0.975040          00:10
#               7       0.974175       0.974201          00:10
# Better model found at epoch 8 with valid_loss value: 0.9716135970689939.
#               8       0.973328       0.971614          00:10
#               9       0.974013       0.973648          00:11
#              10       0.972441       0.972012          00:10
#              11       0.972467       0.973476          00:11
#              12       0.973250       0.974296          00:10
#              13       0.972459       0.973889          00:10
# No improvement since epoch 8: early stopping
# pretraining completed
# Model saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(dset_pretrain='ES', context_points=336, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9680672544786473.
#               0       1.004830       0.968067          00:10
# Better model found at epoch 1 with valid_loss value: 0.9645595934031688.
#               1       0.977961       0.964560          00:10
#               2       0.970913       0.965339          00:10
# Better model found at epoch 3 with valid_loss value: 0.963531823025575.
#               3       0.968341       0.963532          00:10
# Better model found at epoch 4 with valid_loss value: 0.9624998115047451.
#               4       0.965917       0.962500          00:10
# Better model found at epoch 5 with valid_loss value: 0.9590879688505308.
#               5       0.965189       0.959088          00:10
#               6       0.966494       0.960958          00:10
# Better model found at epoch 7 with valid_loss value: 0.9586623622728004.
#               7       0.965053       0.958662          00:10
#               8       0.962532       0.959178          00:10
#               9       0.964065       0.958905          00:10
#              10       0.963605       0.959291          00:10
# Better model found at epoch 11 with valid_loss value: 0.9578182962290895.
#              11       0.962709       0.957818          00:10
# Better model found at epoch 12 with valid_loss value: 0.46418330975048255.
#              12       0.742604       0.464183          00:10
# Better model found at epoch 13 with valid_loss value: 0.4447966513189641.
#              13       0.502765       0.444797          00:10
# Better model found at epoch 14 with valid_loss value: 0.4354438701971409.
#              14       0.482490       0.435444          00:10
# Better model found at epoch 15 with valid_loss value: 0.43078124371682486.
#              15       0.472759       0.430781          00:10
# Better model found at epoch 16 with valid_loss value: 0.42931235517281247.
#              16       0.466692       0.429312          00:10
# Better model found at epoch 17 with valid_loss value: 0.4282270937424602.
#              17       0.463499       0.428227          00:10
# Better model found at epoch 18 with valid_loss value: 0.4230068354662619.
#              18       0.459047       0.423007          00:10
# Better model found at epoch 19 with valid_loss value: 0.42133743509480054.
#              19       0.457211       0.421337          00:10
# Better model found at epoch 20 with valid_loss value: 0.419790595908899.
#              20       0.455218       0.419791          00:10
# Better model found at epoch 21 with valid_loss value: 0.36293296574664224.
#              21       0.444298       0.362933          00:10
# Better model found at epoch 22 with valid_loss value: 0.27683646214512625.
#              22       0.374647       0.276836          00:10
# Better model found at epoch 23 with valid_loss value: 0.17513765651389335.
#              23       0.287267       0.175138          00:10
# Better model found at epoch 24 with valid_loss value: 0.14186602526967387.
#              24       0.228691       0.141866          00:10
# Better model found at epoch 25 with valid_loss value: 0.1142433611971208.
#              25       0.190174       0.114243          00:10
# Better model found at epoch 26 with valid_loss value: 0.10616815575300084.
#              26       0.162681       0.106168          00:10
# Better model found at epoch 27 with valid_loss value: 0.09617367591508164.
#              27       0.145141       0.096174          00:10
# Better model found at epoch 28 with valid_loss value: 0.0919612978400957.
#              28       0.134176       0.091961          00:10
# Better model found at epoch 29 with valid_loss value: 0.0888575467531064.
#              29       0.126910       0.088858          00:10
# Better model found at epoch 30 with valid_loss value: 0.08372692189761943.
#              30       0.120713       0.083727          00:10
# Better model found at epoch 31 with valid_loss value: 0.08019537003032261.
#              31       0.115881       0.080195          00:10
# Better model found at epoch 32 with valid_loss value: 0.07871089626666299.
#              32       0.112856       0.078711          00:10
#              33       0.109297       0.080027          00:10
# Better model found at epoch 34 with valid_loss value: 0.07594497874558921.
#              34       0.106859       0.075945          00:10
# Better model found at epoch 35 with valid_loss value: 0.07548533993862594.
#              35       0.104606       0.075485          00:10
# Better model found at epoch 36 with valid_loss value: 0.07443795918229502.
#              36       0.102570       0.074438          00:10
# Better model found at epoch 37 with valid_loss value: 0.07400167120678432.
#              37       0.100245       0.074002          00:10
# Better model found at epoch 38 with valid_loss value: 0.07237684210914881.
#              38       0.099201       0.072377          00:10
#              39       0.097958       0.073581          00:10
# Better model found at epoch 40 with valid_loss value: 0.0708507717624055.
#              40       0.096735       0.070851          00:10
#              41       0.095834       0.075865          00:10
#              42       0.094810       0.073321          00:10
#              43       0.093670       0.073734          00:10
#              44       0.092664       0.074799          00:10
#              45       0.091859       0.075251          00:10
# No improvement since epoch 40: early stopping
# pretraining completed
# Model saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(dset_pretrain='ES', context_points=336, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
# suggested_lr 0.0002477076355991711
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9676199209214809.
#               0       1.005000       0.967620          00:10
# Better model found at epoch 1 with valid_loss value: 0.965040095479048.
#               1       0.977613       0.965040          00:10
#               2       0.972055       0.965455          00:10
# Better model found at epoch 3 with valid_loss value: 0.9632573325620423.
#               3       0.969300       0.963257          00:10
#               4       0.966835       0.963745          00:10
# Better model found at epoch 5 with valid_loss value: 0.963212596623271.
#               5       0.964521       0.963213          00:10
# Better model found at epoch 6 with valid_loss value: 0.9612364282445077.
#               6       0.964005       0.961236          00:10
# Better model found at epoch 7 with valid_loss value: 0.9610961020138323.
#               7       0.963732       0.961096          00:10
# Better model found at epoch 8 with valid_loss value: 0.960818786869406.
#               8       0.964712       0.960819          00:10
# Better model found at epoch 9 with valid_loss value: 0.9604503311889748.
#               9       0.963599       0.960450          00:10
# Better model found at epoch 10 with valid_loss value: 0.9600262535598048.
#              10       0.963404       0.960026          00:10
#              11       0.962339       0.961060          00:10
# Better model found at epoch 12 with valid_loss value: 0.5856513648037022.
#              12       0.928460       0.585651          00:10
# Better model found at epoch 13 with valid_loss value: 0.44771953983167206.
#              13       0.529825       0.447720          00:10
# Better model found at epoch 14 with valid_loss value: 0.437801947721725.
#              14       0.488308       0.437802          00:10
# Better model found at epoch 15 with valid_loss value: 0.43165786780410903.
#              15       0.475784       0.431658          00:10
# Better model found at epoch 16 with valid_loss value: 0.4292603234336859.
#              16       0.468204       0.429260          00:10
# Better model found at epoch 17 with valid_loss value: 0.4256129141451383.
#              17       0.463406       0.425613          00:10
# Better model found at epoch 18 with valid_loss value: 0.4253191507958706.
#              18       0.459470       0.425319          00:10
# Better model found at epoch 19 with valid_loss value: 0.4211869962240643.
#              19       0.456858       0.421187          00:10
# Better model found at epoch 20 with valid_loss value: 0.4209908096648698.
#              20       0.454278       0.420991          00:10
# Better model found at epoch 21 with valid_loss value: 0.35904714834214807.
#              21       0.436471       0.359047          00:10
# Better model found at epoch 22 with valid_loss value: 0.2948662729162429.
#              22       0.378173       0.294866          00:10
# Better model found at epoch 23 with valid_loss value: 0.1816786863049227.
#              23       0.303153       0.181679          00:10
# Better model found at epoch 24 with valid_loss value: 0.13724002698459112.
#              24       0.229094       0.137240          00:10
# Better model found at epoch 25 with valid_loss value: 0.11373818430888934.
#              25       0.184553       0.113738          00:10
# Better model found at epoch 26 with valid_loss value: 0.10152092259331774.
#              26       0.155744       0.101521          00:10
# Better model found at epoch 27 with valid_loss value: 0.09504421348975285.
#              27       0.139698       0.095044          00:09
# Better model found at epoch 28 with valid_loss value: 0.08722251600322925.
#              28       0.129892       0.087223          00:04
# Better model found at epoch 29 with valid_loss value: 0.08583598001106083.
#              29       0.123462       0.085836          00:04
# Better model found at epoch 30 with valid_loss value: 0.08329800015256306.
#              30       0.119236       0.083298          00:04
# Better model found at epoch 31 with valid_loss value: 0.08232396050523799.
#              31       0.115270       0.082324          00:04
# Better model found at epoch 32 with valid_loss value: 0.08009093294694619.
#              32       0.112343       0.080091          00:04
# Better model found at epoch 33 with valid_loss value: 0.07696535189623169.
#              33       0.109141       0.076965          00:06
# Better model found at epoch 34 with valid_loss value: 0.07540739601079384.
#              34       0.106958       0.075407          00:05
#              35       0.104707       0.075700          00:04
#              36       0.103167       0.076937          00:04
# Better model found at epoch 37 with valid_loss value: 0.0748473475481845.
#              37       0.101529       0.074847          00:04
# Better model found at epoch 38 with valid_loss value: 0.07320170266731083.
#              38       0.099293       0.073202          00:04
# Better model found at epoch 39 with valid_loss value: 0.07169988522013578.
#              39       0.097975       0.071700          00:04
# Better model found at epoch 40 with valid_loss value: 0.07133335644292871.
#              40       0.096385       0.071333          00:04
#              41       0.095111       0.075175          00:04
#              42       0.093934       0.074232          00:04
#              43       0.093045       0.072712          00:04
#              44       0.092369       0.074963          00:04
#              45       0.090885       0.074135          00:04
# No improvement since epoch 40: early stopping
# pretraining completed
# Model saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for ES, pred_len 168:==========
# args: Namespace(dset_pretrain='ES', context_points=336, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
# suggested_lr 0.000298364724028334
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 602376
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9675056988926396.
#               0       1.000327       0.967506          00:10
# Better model found at epoch 1 with valid_loss value: 0.9627868260384077.
#               1       0.976263       0.962787          00:10
# Better model found at epoch 2 with valid_loss value: 0.9613368566554833.
#               2       0.969908       0.961337          00:10
#               3       0.967561       0.961804          00:10
#               4       0.965117       0.963127          00:10
# Better model found at epoch 5 with valid_loss value: 0.9602887363895521.
#               5       0.966651       0.960289          00:10
# Better model found at epoch 6 with valid_loss value: 0.9592110281934382.
#               6       0.964362       0.959211          00:10
#               7       0.963216       0.959362          00:10
# Better model found at epoch 8 with valid_loss value: 0.9589091991447801.
#               8       0.962942       0.958909          00:10
#               9       0.962741       0.960675          00:10
#              10       0.962544       0.960698          00:10
# Better model found at epoch 11 with valid_loss value: 0.4673028848875144.
#              11       0.787517       0.467303          00:10
# Better model found at epoch 12 with valid_loss value: 0.4428027922644286.
#              12       0.503924       0.442803          00:10
# Better model found at epoch 13 with valid_loss value: 0.4352732670477935.
#              13       0.481155       0.435273          00:10
# Better model found at epoch 14 with valid_loss value: 0.430014012457805.
#              14       0.471262       0.430014          00:10
# Better model found at epoch 15 with valid_loss value: 0.42817200299995883.
#              15       0.465560       0.428172          00:10
# Better model found at epoch 16 with valid_loss value: 0.4247672603763585.
#              16       0.460358       0.424767          00:10
# Better model found at epoch 17 with valid_loss value: 0.422630014832558.
#              17       0.458141       0.422630          00:10
# Better model found at epoch 18 with valid_loss value: 0.4206532114482134.
#              18       0.455004       0.420653          00:10
# Better model found at epoch 19 with valid_loss value: 0.375324824016137.
#              19       0.448369       0.375325          00:10
# Better model found at epoch 20 with valid_loss value: 0.2705720938863618.
#              20       0.373099       0.270572          00:10
# Better model found at epoch 21 with valid_loss value: 0.15094217256131134.
#              21       0.250004       0.150942          00:10
# Better model found at epoch 22 with valid_loss value: 0.13728123223116148.
#              22       0.197959       0.137281          00:10
# Better model found at epoch 23 with valid_loss value: 0.12571470328773363.
#              23       0.177717       0.125715          00:10
# Better model found at epoch 24 with valid_loss value: 0.12126839315991375.
#              24       0.166510       0.121268          00:10
# Better model found at epoch 25 with valid_loss value: 0.11079974326038408.
#              25       0.157085       0.110800          00:10
# Better model found at epoch 26 with valid_loss value: 0.09706750647075169.
#              26       0.146296       0.097068          00:10
# Better model found at epoch 27 with valid_loss value: 0.0845358622598232.
#              27       0.131800       0.084536          00:10
# Better model found at epoch 28 with valid_loss value: 0.08184386312559176.
#              28       0.120849       0.081844          00:10
# Better model found at epoch 29 with valid_loss value: 0.07798930657630342.
#              29       0.113994       0.077989          00:10
# Better model found at epoch 30 with valid_loss value: 0.07447085042143504.
#              30       0.108744       0.074471          00:10
#              31       0.105374       0.077118          00:10
# Better model found at epoch 32 with valid_loss value: 0.07328636336518968.
#              32       0.102565       0.073286          00:10
# Better model found at epoch 33 with valid_loss value: 0.07026995730011423.
#              33       0.100029       0.070270          00:10
#              34       0.097699       0.070506          00:10
#              35       0.095952       0.071899          00:10
#              36       0.094709       0.071076          00:10
#              37       0.093051       0.076855          00:10
# Better model found at epoch 38 with valid_loss value: 0.06771315410230219.
#              38       0.092622       0.067713          00:10
#              39       0.090813       0.071564          00:10
#              40       0.089906       0.072158          00:10
#              41       0.088717       0.069548          00:10
#              42       0.088057       0.070339          00:10
#              43       0.087403       0.073048          00:10
# No improvement since epoch 38: early stopping
# pretraining completed
# Model saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for FR, pred_len 24:==========
# args: Namespace(dset_pretrain='FR', context_points=168, target_points=24, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
# suggested_lr 0.00020565123083486514
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9455920227551472.
#               0       0.999115       0.945592          00:11
# Better model found at epoch 1 with valid_loss value: 0.9430912404998392.
#               1       0.958802       0.943091          00:11
# Better model found at epoch 2 with valid_loss value: 0.9412948021805131.
#               2       0.948997       0.941295          00:11
# Better model found at epoch 3 with valid_loss value: 0.934423286201142.
#               3       0.945328       0.934423          00:11
# Better model found at epoch 4 with valid_loss value: 0.9307671065727039.
#               4       0.940901       0.930767          00:11
#               5       0.939965       0.933193          00:11
#               6       0.938125       0.930813          00:10
# Better model found at epoch 7 with valid_loss value: 0.9306645337381374.
#               7       0.934972       0.930665          00:11
#               8       0.936496       0.931812          00:11
# Better model found at epoch 9 with valid_loss value: 0.9272660428311484.
#               9       0.933224       0.927266          00:11
#              10       0.932743       0.930002          00:11
#              11       0.931297       0.928292          00:11
#              12       0.930904       0.927666          00:11
# Better model found at epoch 13 with valid_loss value: 0.9269912324573749.
#              13       0.930513       0.926991          00:11
#              14       0.930146       0.929405          00:10
# Better model found at epoch 15 with valid_loss value: 0.8813342259630851.
#              15       0.924396       0.881334          00:10
# Better model found at epoch 16 with valid_loss value: 0.40949565267110344.
#              16       0.642640       0.409496          00:10
# Better model found at epoch 17 with valid_loss value: 0.31174462490072585.
#              17       0.423731       0.311745          00:10
# Better model found at epoch 18 with valid_loss value: 0.20728004410160647.
# ...
#              12       0.932306       0.928572          00:10
#              13       0.930567       0.929848          00:10
#              14       0.931346       0.929106          00:10
# Better model found at epoch 15 with valid_loss value: 0.9121811602762586.
#              15       0.930159       0.912181          00:10
# Better model found at epoch 16 with valid_loss value: 0.4101058275193019.
#              16       0.598815       0.410106          00:10
# Better model found at epoch 17 with valid_loss value: 0.2810296961707817.
#              17       0.383852       0.281030          00:10
# Better model found at epoch 18 with valid_loss value: 0.19322872422641546.
#              18       0.271026       0.193229          00:10
# Better model found at epoch 19 with valid_loss value: 0.1660347101445633.
#              19       0.223850       0.166035          00:10
# Better model found at epoch 20 with valid_loss value: 0.15193066068529335.
#              20       0.202205       0.151931          00:10
# Better model found at epoch 21 with valid_loss value: 0.1438329241677306.
#              21       0.186202       0.143833          00:10
# Better model found at epoch 22 with valid_loss value: 0.13724500518990268.
#              22       0.175242       0.137245          00:10
# Better model found at epoch 23 with valid_loss value: 0.13449213998348783.
#              23       0.167790       0.134492          00:10
# Better model found at epoch 24 with valid_loss value: 0.12921455755137123.
#              24       0.160373       0.129215          00:10
# Better model found at epoch 25 with valid_loss value: 0.12140592563108211.
#              25       0.153494       0.121406          00:10
# Better model found at epoch 26 with valid_loss value: 0.11638695476176714.
#              26       0.147810       0.116387          00:10
# Better model found at epoch 27 with valid_loss value: 0.11457676217930673.
#              27       0.141480       0.114577          00:10
# Better model found at epoch 28 with valid_loss value: 0.11197968044713588.
#              28       0.136699       0.111980          00:10
# Better model found at epoch 29 with valid_loss value: 0.10694115319512024.
#              29       0.131425       0.106941          00:10
# Better model found at epoch 30 with valid_loss value: 0.10447477132383988.
#              30       0.128650       0.104475          00:10
# Better model found at epoch 31 with valid_loss value: 0.10194710885977963.
#              31       0.125609       0.101947          00:10
# Better model found at epoch 32 with valid_loss value: 0.09950387656199734.
#              32       0.122421       0.099504          00:10
# Better model found at epoch 33 with valid_loss value: 0.09857773654269543.
#              33       0.120586       0.098578          00:10
# Better model found at epoch 34 with valid_loss value: 0.0977971992903782.
#              34       0.118456       0.097797          00:10
# Better model found at epoch 35 with valid_loss value: 0.09684181305417605.
#              35       0.116437       0.096842          00:10
# Better model found at epoch 36 with valid_loss value: 0.09539259870239866.
#              36       0.114814       0.095393          00:10
#              37       0.113138       0.096526          00:10
# Better model found at epoch 38 with valid_loss value: 0.09363152287829742.
#              38       0.112546       0.093632          00:10
#              39       0.110818       0.095054          00:10
#              40       0.110065       0.094587          00:10
#              41       0.109235       0.095278          00:10
#              42       0.108209       0.096591          00:10
#              43       0.106852       0.098088          00:10
# No improvement since epoch 38: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(dset_pretrain='IT', context_points=168, target_points=96, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
# suggested_lr 0.00017073526474706903
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9443365731794141.
#               0       1.004134       0.944337          00:10
# Better model found at epoch 1 with valid_loss value: 0.9392109311432059.
#               1       0.960812       0.939211          00:10
# Better model found at epoch 2 with valid_loss value: 0.9335832612896664.
#               2       0.950490       0.933583          00:10
#               3       0.946653       0.935977          00:10
#               4       0.941660       0.933800          00:10
#               5       0.940701       0.935242          00:10
# Better model found at epoch 6 with valid_loss value: 0.9297452673667616.
#               6       0.937683       0.929745          00:10
#               7       0.936956       0.933429          00:10
#               8       0.935015       0.931946          00:10
#               9       0.933186       0.930279          00:10
#              10       0.933099       0.930220          00:10
# Better model found at epoch 11 with valid_loss value: 0.9287054547650528.
#              11       0.932766       0.928705          00:10
#              12       0.932222       0.930333          00:10
#              13       0.932746       0.930555          00:10
# Better model found at epoch 14 with valid_loss value: 0.927050463410293.
#              14       0.931920       0.927050          00:10
#              15       0.930891       0.928534          00:10
# Better model found at epoch 16 with valid_loss value: 0.7269891998067535.
#              16       0.897440       0.726989          00:10
# Better model found at epoch 17 with valid_loss value: 0.4423413741481896.
#              17       0.540586       0.442341          00:10
# Better model found at epoch 18 with valid_loss value: 0.4300621138247559.
#              18       0.465172       0.430062          00:10
# Better model found at epoch 19 with valid_loss value: 0.42177829726912125.
#              19       0.450458       0.421778          00:10
# Better model found at epoch 20 with valid_loss value: 0.2896495499389748.
#              20       0.393670       0.289650          00:10
# Better model found at epoch 21 with valid_loss value: 0.18653037037861067.
#              21       0.266140       0.186530          00:10
# Better model found at epoch 22 with valid_loss value: 0.1602025850697976.
#              22       0.217154       0.160203          00:10
# Better model found at epoch 23 with valid_loss value: 0.1464402350106794.
#              23       0.194748       0.146440          00:10
# Better model found at epoch 24 with valid_loss value: 0.1371674204765053.
#              24       0.180979       0.137167          00:10
# Better model found at epoch 25 with valid_loss value: 0.13406507648812552.
#              25       0.169764       0.134065          00:10
# Better model found at epoch 26 with valid_loss value: 0.12656228148520138.
#              26       0.161753       0.126562          00:10
#              27       0.154622       0.127923          00:10
# Better model found at epoch 28 with valid_loss value: 0.11765578714592656.
#              28       0.148476       0.117656          00:05
# Better model found at epoch 29 with valid_loss value: 0.11386474410725184.
#              29       0.144127       0.113865          00:04
# Better model found at epoch 30 with valid_loss value: 0.11197076709024105.
#              30       0.138329       0.111971          00:04
# Better model found at epoch 31 with valid_loss value: 0.10946673648545566.
#              31       0.134715       0.109467          00:04
#              32       0.131868       0.109681          00:07
# Better model found at epoch 33 with valid_loss value: 0.10675459039996948.
#              33       0.128456       0.106755          00:10
# Better model found at epoch 34 with valid_loss value: 0.1057260213778987.
#              34       0.126004       0.105726          00:10
# Better model found at epoch 35 with valid_loss value: 0.10084980405182059.
#              35       0.123550       0.100850          00:10
# Better model found at epoch 36 with valid_loss value: 0.1006015414431194.
#              36       0.121056       0.100602          00:10
# Better model found at epoch 37 with valid_loss value: 0.0999526120861727.
#              37       0.119333       0.099953          00:10
# Better model found at epoch 38 with valid_loss value: 0.09843694378051261.
#              38       0.117799       0.098437          00:10
#              39       0.116425       0.099285          00:10
#              40       0.114894       0.099312          00:10
# Better model found at epoch 41 with valid_loss value: 0.09782374159313975.
#              41       0.113901       0.097824          00:10
# Better model found at epoch 42 with valid_loss value: 0.09771605352738506.
#              42       0.112749       0.097716          00:10
# Better model found at epoch 43 with valid_loss value: 0.09623076871122356.
#              43       0.112237       0.096231          00:10
#              44       0.110649       0.097628          00:10
#              45       0.109056       0.099223          00:10
#              46       0.108788       0.096779          00:10
#              47       0.107552       0.096564          00:10
#              48       0.107219       0.096784          00:10
# No improvement since epoch 43: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(dset_pretrain='IT', context_points=168, target_points=168, batch_size=64, num_workers=0, features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=512, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
# suggested_lr 0.00035938136638046257
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 599688
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9394655069055656.
#               0       0.982106       0.939466          00:11
# Better model found at epoch 1 with valid_loss value: 0.9359846638039272.
#               1       0.948621       0.935985          00:10
# Better model found at epoch 2 with valid_loss value: 0.9334863329491191.
#               2       0.943720       0.933486          00:10
# Better model found at epoch 3 with valid_loss value: 0.932559056865429.
#               3       0.939804       0.932559          00:11
# Better model found at epoch 4 with valid_loss value: 0.9315795998939981.
#               4       0.937533       0.931580          00:11
# Better model found at epoch 5 with valid_loss value: 0.9314680019399391.
#               5       0.935755       0.931468          00:11
#               6       0.935514       0.935352          00:10
# Better model found at epoch 7 with valid_loss value: 0.9303086053278857.
#               7       0.934148       0.930309          00:10
#               8       0.933808       0.931873          00:10
# Better model found at epoch 9 with valid_loss value: 0.9299947963835831.
#               9       0.932838       0.929995          00:10
# Better model found at epoch 10 with valid_loss value: 0.9290725052229128.
#              10       0.932005       0.929073          00:10
# Better model found at epoch 11 with valid_loss value: 0.9286023948213403.
#              11       0.929951       0.928602          00:10
# Better model found at epoch 12 with valid_loss value: 0.4940966853156389.
#              12       0.854053       0.494097          00:10
# Better model found at epoch 13 with valid_loss value: 0.43713553780565617.
#              13       0.488007       0.437136          00:10
# Better model found at epoch 14 with valid_loss value: 0.4177362274617158.
#              14       0.451309       0.417736          00:10
# Better model found at epoch 15 with valid_loss value: 0.192833043510981.
#              15       0.330868       0.192833          00:10
# Better model found at epoch 16 with valid_loss value: 0.1620724202380156.
#              16       0.222812       0.162072          00:10
# Better model found at epoch 17 with valid_loss value: 0.15123406191467356.
#              17       0.197055       0.151234          00:09
# Better model found at epoch 18 with valid_loss value: 0.13956442747676703.
#              18       0.182791       0.139564          00:11
# Better model found at epoch 19 with valid_loss value: 0.1377894933742333.
#              19       0.172247       0.137789          00:11
# Better model found at epoch 20 with valid_loss value: 0.13287455023130043.
#              20       0.163540       0.132875          00:10
# Better model found at epoch 21 with valid_loss value: 0.12755572782127347.
#              21       0.156005       0.127556          00:10
# Better model found at epoch 22 with valid_loss value: 0.12311197045645171.
#              22       0.149756       0.123112          00:10
# Better model found at epoch 23 with valid_loss value: 0.12164392067733204.
#              23       0.143589       0.121644          00:10
# Better model found at epoch 24 with valid_loss value: 0.11678294736628829.
#              24       0.136483       0.116783          00:09
# Better model found at epoch 25 with valid_loss value: 0.1059327398005259.
#              25       0.130077       0.105933          00:10
# Better model found at epoch 26 with valid_loss value: 0.10533890079552939.
#              26       0.124268       0.105339          00:08
# Better model found at epoch 27 with valid_loss value: 0.10388386608760086.
#              27       0.120795       0.103884          00:10
#              28       0.118189       0.115673          00:10
# Better model found at epoch 29 with valid_loss value: 0.10224946460318726.
#              29       0.117319       0.102249          00:10
# Better model found at epoch 30 with valid_loss value: 0.09954843029598222.
#              30       0.113700       0.099548          00:10
# Better model found at epoch 31 with valid_loss value: 0.09904645055792545.
#              31       0.110979       0.099046          00:10
# Better model found at epoch 32 with valid_loss value: 0.09248540744187901.
#              32       0.109683       0.092485          00:10
#              33       0.108157       0.100994          00:10
#              34       0.106907       0.097658          00:10
#              35       0.106505       0.095676          00:10
#              36       0.105704       0.094236          00:10
#              37       0.103694       0.102289          00:10
# No improvement since epoch 32: early stopping
# pretraining completed
# Model saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1
# Metrics saved in: saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1_losses.csv
# Total time: 01h:54m:08.20s

# %% [markdown]
# # 2. Finetune
#
# Linear probing + full fine-tuning.

# %%
# Dynamic variables
#cuda_device = "1"
#os.environ["CUDA_VISIBLE_DEVICES"] = cuda_device

#countries = ['DE', 'GB', 'ES', 'FR', 'IT']
#seq_lens = [512, 512, 336, 168, 168]
#pred_lens = ["24", "96", "168"]

start = time.time()

# List to store metrics for the DataFrame
data = []

for i, country in enumerate(countries):
    for pred_len in pred_lens:
        if country == 'DE' and pred_len == '24':
            seq_len = 336
        else:
            seq_len = seq_lens[i]

        # Define the parameters for each country and pred_len
        params = {
            "--dset": country,
            "--context_points": seq_len,
            "--is_finetune": 1,
            "--pretrained_model": f"saved_models/{country}/masked_patchtst/based_model/patchtst_pretrained_cw{seq_len}_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth",
            "--scaler_type": "minmax",
            "--n_epochs_finetune": 20,
            "--target_points": pred_len,
            "--patch_len": 8,
            "--stride": 8
        }

        # Build the command string
        command = "python PatchTST-main/PatchTST_self_supervised/patchtst_finetune.py "

        # Add parameters to the command
        for key, value in params.items():
            if value is not None:
                command += f"{key} {value} "
            else:
                command += f"{key} "  # Add flags with no value

        print(f"==========Running command for {country}, pred_len {pred_len}:==========")

        # Run the command and capture the output
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        # Capture the output in real-time
        output = []
        for line in process.stdout:
            output.append(line)
            print(line, end='')  # Print in the .ipynb cell

        # Wait for the process to complete
        process.stdout.close()
        process.wait()

        try:
            # Extract metrics from the output using the function
            metrics = extract_metrics_from_output(output, if_supervised=False)
            mse, rmse, mae = metrics[0]

            # Append the results to the data list
            data.append({
                'Country': country,
                'Pred_len': pred_len,
                'MSE': mse,
                'RMSE': rmse,
                'MAE': mae
            })
        except ValueError as e:
            print(f"\nError: {e} for {country}, pred_len {pred_len}")

end = time.time()
hours, mins, secs = running_time(start, end)
print("Total time: {:0>2}h:{:0>2}m:{:05.2f}s".format(hours, mins, secs))
# Out:
# ==========Running command for DE, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=336, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00020565123083486514
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1141524024191481.
#               0       0.133547       0.114152       0.114152          00:02
# Better model found at epoch 1 with valid_loss value: 0.09870153472836578.
#               1       0.105153       0.098702       0.098702          00:02
# Better model found at epoch 2 with valid_loss value: 0.09641601012722173.
#               2       0.091898       0.096416       0.096416          00:02
#               3       0.088425       0.096483       0.096483          00:02
# Better model found at epoch 4 with valid_loss value: 0.09606364181000683.
#               4       0.087724       0.096064       0.096064          00:02
# Better model found at epoch 5 with valid_loss value: 0.09458370862214995.
#               5       0.087051       0.094584       0.094584          00:02
# Better model found at epoch 6 with valid_loss value: 0.09427009964173336.
#               6       0.086450       0.094270       0.094270          00:02
#               7       0.085855       0.094283       0.094283          00:02
# Better model found at epoch 8 with valid_loss value: 0.09350562375593131.
#               8       0.085489       0.093506       0.093506          00:02
# Better model found at epoch 9 with valid_loss value: 0.09348709820665614.
#               9       0.085311       0.093487       0.093487          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09130343958287257.
#               0       0.083807       0.091303       0.091303          00:10
# Better model found at epoch 1 with valid_loss value: 0.09021274909647942.
#               1       0.081288       0.090213       0.090213          00:10
# Better model found at epoch 2 with valid_loss value: 0.08941002438186123.
#               2       0.078735       0.089410       0.089410          00:10
#               3       0.076779       0.089530       0.089530          00:10
# Better model found at epoch 4 with valid_loss value: 0.08819341513817959.
#               4       0.075422       0.088193       0.088193          00:10
#               5       0.074557       0.088499       0.088499          00:10
# Better model found at epoch 6 with valid_loss value: 0.08795142453718131.
#               6       0.073786       0.087951       0.087951          00:10
# Better model found at epoch 7 with valid_loss value: 0.08737390256491777.
#               7       0.073134       0.087374       0.087374          00:10
#               8       0.072561       0.087806       0.087806          00:10
# Better model found at epoch 9 with valid_loss value: 0.08637944283315908.
#               9       0.072050       0.086379       0.086379          00:10
#              10       0.071425       0.087708       0.087708          00:10
#              11       0.071125       0.086667       0.086667          00:10
#              12       0.070564       0.086819       0.086819          00:10
#              13       0.070203       0.086537       0.086537          00:10
# Better model found at epoch 14 with valid_loss value: 0.08602164545990329.
#              14       0.069819       0.086022       0.086022          00:10
#              15       0.069502       0.086033       0.086033          00:10
#              16       0.069277       0.086155       0.086155          00:10
#              17       0.069045       0.086053       0.086053          00:10
# Better model found at epoch 18 with valid_loss value: 0.08599728833867822.
#              18       0.068947       0.085997       0.085997          00:10
#              19       0.068875       0.086018       0.086018          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# scores: mse: 0.021122973 rmse: 0.14533745 mae: 0.08827506
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00014174741629268049
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.13094818140065603.
#               0       0.143965       0.130948       0.130948          00:03
# Better model found at epoch 1 with valid_loss value: 0.12418259573331977.
#               1       0.126384       0.124183       0.124183          00:03
# Better model found at epoch 2 with valid_loss value: 0.12361990026189992.
#               2       0.117054       0.123620       0.123620          00:03
# Better model found at epoch 3 with valid_loss value: 0.12336887642074348.
#               3       0.112104       0.123369       0.123369          00:03
# Better model found at epoch 4 with valid_loss value: 0.1224207705070179.
#               4       0.110128       0.122421       0.122421          00:03
# Better model found at epoch 5 with valid_loss value: 0.12227958014963894.
#               5       0.109196       0.122280       0.122280          00:03
# Better model found at epoch 6 with valid_loss value: 0.12130953336363405.
#               6       0.108445       0.121310       0.121310          00:03
# Better model found at epoch 7 with valid_loss value: 0.1210829831799227.
#               7       0.107766       0.121083       0.121083          00:03
# Better model found at epoch 8 with valid_loss value: 0.12064636081481388.
#               8       0.107255       0.120646       0.120646          00:03
# Better model found at epoch 9 with valid_loss value: 0.12054479116342047.
#               9       0.106888       0.120545       0.120545          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11994049842033666.
#               0       0.106454       0.119940       0.119940          00:10
# Better model found at epoch 1 with valid_loss value: 0.11914793531326281.
#               1       0.105280       0.119148       0.119148          00:10
# Better model found at epoch 2 with valid_loss value: 0.11792713286335435.
#               2       0.103735       0.117927       0.117927          00:10
# Better model found at epoch 3 with valid_loss value: 0.11779526911487999.
#               3       0.102025       0.117795       0.117795          00:10
#               4       0.100230       0.117995       0.117995          00:10
#               5       0.098544       0.119286       0.119286          00:10
#               6       0.096890       0.119543       0.119543          00:10
#               7       0.095333       0.119544       0.119544          00:10
#               8       0.094038       0.120187       0.120187          00:10
#               9       0.092813       0.120172       0.120172          00:10
#              10       0.091685       0.120557       0.120557          00:09
#              11       0.090762       0.120809       0.120809          00:10
#              12       0.089957       0.120773       0.120773          00:09
#              13       0.089245       0.120938       0.120938          00:09
#              14       0.088628       0.121328       0.121328          00:10
#              15       0.088210       0.121250       0.121250          00:09
#              16       0.087818       0.121093       0.121093          00:09
#              17       0.087605       0.121077       0.121077          00:10
#              18       0.087528       0.121220       0.121220          00:10
#              19       0.087428       0.121175       0.121175          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# scores: mse: 0.036566958 rmse: 0.19122489 mae: 0.12688467
# ----------- Complete! -----------
# ==========Running command for DE, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='DE', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/DE/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.1339525599348551.
#               0       0.148619       0.133953       0.133953          00:03
# Better model found at epoch 1 with valid_loss value: 0.1284174561873508.
#               1       0.133268       0.128417       0.128417          00:03
# Better model found at epoch 2 with valid_loss value: 0.12697356720448089.
#               2       0.124788       0.126974       0.126974          00:03
# Better model found at epoch 3 with valid_loss value: 0.12583766807230776.
#               3       0.119127       0.125838       0.125838          00:03
# Better model found at epoch 4 with valid_loss value: 0.12545166819644843.
#               4       0.116121       0.125452       0.125452          00:03
# Better model found at epoch 5 with valid_loss value: 0.12519927631782068.
#               5       0.114590       0.125199       0.125199          00:03
# Better model found at epoch 6 with valid_loss value: 0.12470083426706838.
#               6       0.113666       0.124701       0.124701          00:03
# Better model found at epoch 7 with valid_loss value: 0.124393829340678.
#               7       0.113028       0.124394       0.124394          00:03
# Better model found at epoch 8 with valid_loss value: 0.1241697992619741.
#               8       0.112640       0.124170       0.124170          00:03
# Better model found at epoch 9 with valid_loss value: 0.12408779928834596.
#               9       0.112458       0.124088       0.124088          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12368173911743063.
#               0       0.112060       0.123682       0.123682          00:10
# Better model found at epoch 1 with valid_loss value: 0.12323443272862465.
#               1       0.111083       0.123234       0.123234          00:10
# Better model found at epoch 2 with valid_loss value: 0.12226561896985119.
#               2       0.109706       0.122266       0.122266          00:09
# Better model found at epoch 3 with valid_loss value: 0.1218785135667092.
#               3       0.108301       0.121879       0.121878          00:10
#               4       0.106697       0.122148       0.122148          00:10
# Better model found at epoch 5 with valid_loss value: 0.12173761913966018.
#               5       0.105035       0.121738       0.121738          00:10
#               6       0.103372       0.122587       0.122587          00:10
#               7       0.101929       0.123002       0.123002          00:10
#               8       0.100697       0.122804       0.122804          00:10
#               9       0.099608       0.123521       0.123521          00:10
#              10       0.098657       0.123371       0.123371          00:10
#              11       0.097729       0.123614       0.123614          00:10
#              12       0.097092       0.123661       0.123661          00:10
#              13       0.096414       0.123253       0.123253          00:10
#              14       0.096006       0.123568       0.123568          00:10
#              15       0.095609       0.123428       0.123428          00:10
#              16       0.095470       0.123376       0.123376          00:10
#              17       0.095262       0.123462       0.123462          00:10
#              18       0.095124       0.123311       0.123311          00:10
#              19       0.095037       0.123362       0.123362          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# scores: mse: 0.039372537 rmse: 0.19842514 mae: 0.13356948
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 603416
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 6.73415065775082e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 603416
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11103003742573286.
#               0       0.127257       0.111030       0.111030          00:03
# Better model found at epoch 1 with valid_loss value: 0.10001357951232508.
#               1       0.105598       0.100014       0.100014          00:03
# Better model found at epoch 2 with valid_loss value: 0.09708144746448749.
#               2       0.097165       0.097081       0.097081          00:03
# Better model found at epoch 3 with valid_loss value: 0.09541433456148464.
#               3       0.091516       0.095414       0.095414          00:03
# Better model found at epoch 4 with valid_loss value: 0.09526699410386842.
#               4       0.087997       0.095267       0.095267          00:03
# Better model found at epoch 5 with valid_loss value: 0.09480492547525937.
#               5       0.086032       0.094805       0.094805          00:03
# Better model found at epoch 6 with valid_loss value: 0.09430101482703676.
#               6       0.084864       0.094301       0.094301          00:03
# Better model found at epoch 7 with valid_loss value: 0.09406404094870918.
#               7       0.084115       0.094064       0.094064          00:03
# Better model found at epoch 8 with valid_loss value: 0.09376034760409964.
#               8       0.083686       0.093760       0.093760          00:03
# Better model found at epoch 9 with valid_loss value: 0.09369169409796224.
#               9       0.083449       0.093692       0.093692          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09320013381592307.
#               0       0.083252       0.093200       0.093200          00:10
# Better model found at epoch 1 with valid_loss value: 0.09242659641343795.
#               1       0.082425       0.092427       0.092427          00:10
# Better model found at epoch 2 with valid_loss value: 0.0913714451365711.
#               2       0.081177       0.091371       0.091371          00:10
# Better model found at epoch 3 with valid_loss value: 0.09059561044816632.
#               3       0.079731       0.090596       0.090596          00:10
# Better model found at epoch 4 with valid_loss value: 0.08997419460689943.
#               4       0.078572       0.089974       0.089974          00:10
# Better model found at epoch 5 with valid_loss value: 0.08946605263290172.
#               5       0.077668       0.089466       0.089466          00:10
#               6       0.076778       0.089778       0.089778          00:10
# Better model found at epoch 7 with valid_loss value: 0.08942556542293309.
#               7       0.076196       0.089426       0.089426          00:10
# Better model found at epoch 8 with valid_loss value: 0.08872349913794837.
#               8       0.075665       0.088723       0.088724          00:10
#               9       0.075347       0.088750       0.088750          00:11
# Better model found at epoch 10 with valid_loss value: 0.08851145179359518.
#              10       0.074949       0.088511       0.088511          00:10
# Better model found at epoch 11 with valid_loss value: 0.08820893654432906.
#              11       0.074580       0.088209       0.088209          00:09
# Better model found at epoch 12 with valid_loss value: 0.08815651130154717.
#              12       0.074355       0.088157       0.088156          00:10
# Better model found at epoch 13 with valid_loss value: 0.08784352082118586.
#              13       0.074069       0.087844       0.087844          00:09
#              14       0.073875       0.087919       0.087919          00:09
# Better model found at epoch 15 with valid_loss value: 0.08763818862029013.
#              15       0.073725       0.087638       0.087638          00:09
#              16       0.073589       0.087718       0.087718          00:10
#              17       0.073498       0.087671       0.087670          00:10
#              18       0.073459       0.087645       0.087645          00:10
#              19       0.073421       0.087654       0.087654          00:09
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 603416
# scores: mse: 0.024512038 rmse: 0.15656321 mae: 0.09983117
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12404080942649003.
#               0       0.132030       0.124041       0.124041          00:03
# Better model found at epoch 1 with valid_loss value: 0.12086052518243999.
#               1       0.120361       0.120861       0.120861          00:03
# Better model found at epoch 2 with valid_loss value: 0.12007696091207282.
#               2       0.114575       0.120077       0.120077          00:03
# Better model found at epoch 3 with valid_loss value: 0.11988069489295158.
#               3       0.110398       0.119881       0.119881          00:03
# Better model found at epoch 4 with valid_loss value: 0.11868400853081774.
#               4       0.108031       0.118684       0.118684          00:03
# Better model found at epoch 5 with valid_loss value: 0.11812078663738304.
#               5       0.106651       0.118121       0.118121          00:03
# Better model found at epoch 6 with valid_loss value: 0.11786829278758136.
#               6       0.105677       0.117868       0.117868          00:03
# Better model found at epoch 7 with valid_loss value: 0.1169533315958096.
#               7       0.104878       0.116953       0.116953          00:03
# Better model found at epoch 8 with valid_loss value: 0.1167802182128509.
#               8       0.104356       0.116780       0.116780          00:03
# Better model found at epoch 9 with valid_loss value: 0.11667990998779496.
#               9       0.104066       0.116680       0.116680          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.11645614090152054.
#               0       0.103826       0.116456       0.116456          00:10
#               1       0.103275       0.116559       0.116559          00:10
# Better model found at epoch 2 with valid_loss value: 0.1160315070528631.
#               2       0.102545       0.116032       0.116031          00:10
# Better model found at epoch 3 with valid_loss value: 0.11566665686660903.
#               3       0.101736       0.115667       0.115667          00:10
#               4       0.101014       0.115802       0.115802          00:10
#               5       0.099906       0.116323       0.116323          00:10
#               6       0.098659       0.117834       0.117834          00:10
#               7       0.097440       0.117846       0.117846          00:10
#               8       0.096416       0.118178       0.118178          00:09
#               9       0.095526       0.118927       0.118927          00:09
#              10       0.094745       0.118596       0.118596          00:10
#              11       0.093934       0.118734       0.118734          00:10
#              12       0.093285       0.119181       0.119181          00:10
#              13       0.092806       0.119908       0.119908          00:10
#              14       0.092308       0.119446       0.119446          00:10
#              15       0.092007       0.119547       0.119547          00:10
#              16       0.091668       0.119762       0.119762          00:10
#              17       0.091471       0.119662       0.119662          00:10
#              18       0.091359       0.119655       0.119655          00:10
#              19       0.091314       0.119652       0.119652          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1193312
# scores: mse: 0.04189668 rmse: 0.20468678 mae: 0.14022176
# ----------- Complete! -----------
# ==========Running command for GB, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='GB', context_points=512, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/GB/masked_patchtst/based_model/patchtst_pretrained_cw512_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12716229076187635.
#               0       0.133394       0.127162       0.127162          00:03
# Better model found at epoch 1 with valid_loss value: 0.1249715276473479.
#               1       0.123643       0.124972       0.124972          00:03
# Better model found at epoch 2 with valid_loss value: 0.12416715604674379.
#               2       0.118654       0.124167       0.124167          00:03
# Better model found at epoch 3 with valid_loss value: 0.12386854307745349.
#               3       0.114794       0.123869       0.123869          00:03
# Better model found at epoch 4 with valid_loss value: 0.12254886510991272.
#               4       0.112466       0.122549       0.122549          00:03
# Better model found at epoch 5 with valid_loss value: 0.12241237269149823.
#               5       0.110995       0.122412       0.122412          00:03
# Better model found at epoch 6 with valid_loss value: 0.12222279486302075.
#               6       0.109892       0.122223       0.122223          00:03
# Better model found at epoch 7 with valid_loss value: 0.12168745835177219.
#               7       0.109186       0.121687       0.121687          00:03
# Better model found at epoch 8 with valid_loss value: 0.121225850460028.
#               8       0.108651       0.121226       0.121226          00:03
# Better model found at epoch 9 with valid_loss value: 0.12117440324039293.
#               9       0.108362       0.121174       0.121174          00:03
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.12100500630994772.
#               0       0.108107       0.121005       0.121005          00:10
#               1       0.107590       0.121019       0.121019          00:10
#               2       0.106890       0.121051       0.121051          00:10
#               3       0.106135       0.121316       0.121316          00:10
#               4       0.105165       0.121347       0.121347          00:10
#               5       0.103795       0.122819       0.122819          00:10
#               6       0.102090       0.123841       0.123841          00:09
#               7       0.100503       0.124987       0.124987          00:09
#               8       0.099189       0.125195       0.125195          00:10
#               9       0.098176       0.125116       0.125116          00:09
#              10       0.097225       0.125685       0.125685          00:10
#              11       0.096356       0.125442       0.125442          00:10
#              12       0.095721       0.125731       0.125731          00:10
#              13       0.095095       0.125473       0.125473          00:10
#              14       0.094644       0.126036       0.126036          00:10
#              15       0.094264       0.125886       0.125886          00:10
#              16       0.093991       0.126086       0.126086          00:10
#              17       0.093752       0.125909       0.125909          00:10
#              18       0.093603       0.125917       0.125917          00:10
#              19       0.093595       0.126039       0.126039          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 64
# number of model params 1783208
# scores: mse: 0.04310584 rmse: 0.20761946 mae: 0.14424649
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 24:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=336, target_points=24, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00014174741629268049
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08068353837951886.
#               0       0.126662       0.080684       0.080684          00:02
# Better model found at epoch 1 with valid_loss value: 0.0689526441800205.
#               1       0.098096       0.068953       0.068953          00:02
# Better model found at epoch 2 with valid_loss value: 0.06539977860446909.
#               2       0.082127       0.065400       0.065400          00:02
# Better model found at epoch 3 with valid_loss value: 0.06497274358613479.
#               3       0.074153       0.064973       0.064973          00:02
# Better model found at epoch 4 with valid_loss value: 0.06377493478064179.
#               4       0.071401       0.063775       0.063775          00:02
# Better model found at epoch 5 with valid_loss value: 0.06351316690406597.
#               5       0.070448       0.063513       0.063513          00:02
# Better model found at epoch 6 with valid_loss value: 0.06293197811004604.
#               6       0.069765       0.062932       0.062932          00:02
# Better model found at epoch 7 with valid_loss value: 0.06214718498830073.
#               7       0.069229       0.062147       0.062147          00:02
# Better model found at epoch 8 with valid_loss value: 0.0619785946359277.
#               8       0.068793       0.061979       0.061979          00:02
# Better model found at epoch 9 with valid_loss value: 0.061954551673460874.
#               9       0.068591       0.061955       0.061955          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.060434150910557746.
#               0       0.067845       0.060434       0.060434          00:10
# Better model found at epoch 1 with valid_loss value: 0.05903708200391819.
#               1       0.065614       0.059037       0.059037          00:10
# Better model found at epoch 2 with valid_loss value: 0.05743762613474143.
#               2       0.062989       0.057438       0.057438          00:10
# Better model found at epoch 3 with valid_loss value: 0.05614162308237494.
#               3       0.060502       0.056142       0.056142          00:10
# Better model found at epoch 4 with valid_loss value: 0.05484683248646604.
#               4       0.058670       0.054847       0.054847          00:10
# Better model found at epoch 5 with valid_loss value: 0.05460273604004142.
#               5       0.057407       0.054603       0.054603          00:10
# Better model found at epoch 6 with valid_loss value: 0.05413228329957174.
#               6       0.056508       0.054132       0.054132          00:07
# Better model found at epoch 7 with valid_loss value: 0.05356187407794404.
#               7       0.055870       0.053562       0.053562          00:04
# Better model found at epoch 8 with valid_loss value: 0.05351545221268297.
#               8       0.055328       0.053515       0.053515          00:04
# Better model found at epoch 9 with valid_loss value: 0.05320463629997638.
#               9       0.054933       0.053205       0.053205          00:04
# Better model found at epoch 10 with valid_loss value: 0.05266779788690536.
#              10       0.054462       0.052668       0.052668          00:04
# Better model found at epoch 11 with valid_loss value: 0.052642994071195916.
#              11       0.054084       0.052643       0.052643          00:10
# Better model found at epoch 12 with valid_loss value: 0.05244748424022589.
#              12       0.053731       0.052447       0.052447          00:10
# Better model found at epoch 13 with valid_loss value: 0.052427819865452086.
#              13       0.053410       0.052428       0.052428          00:10
# Better model found at epoch 14 with valid_loss value: 0.05234124458390301.
#              14       0.053267       0.052341       0.052341          00:10
# Better model found at epoch 15 with valid_loss value: 0.052033447540513915.
#              15       0.052994       0.052033       0.052033          00:10
# Better model found at epoch 16 with valid_loss value: 0.05191138213674451.
#              16       0.052789       0.051911       0.051911          00:05
# Better model found at epoch 17 with valid_loss value: 0.05183297007417917.
#              17       0.052723       0.051833       0.051833          00:04
# Better model found at epoch 18 with valid_loss value: 0.05177284794182031.
#              18       0.052591       0.051773       0.051773          00:04
# Better model found at epoch 19 with valid_loss value: 0.05173193367228969.
#              19       0.052509       0.051732       0.051732          00:04
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 533016
# scores: mse: 0.009424369 rmse: 0.09707919 mae: 0.057880163
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=336, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920160
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920160
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09611917717656632.
#               0       0.141023       0.096119       0.096119          00:02
# Better model found at epoch 1 with valid_loss value: 0.08795062717720199.
#               1       0.115249       0.087951       0.087951          00:02
# Better model found at epoch 2 with valid_loss value: 0.08490220668162632.
#               2       0.103526       0.084902       0.084902          00:02
# Better model found at epoch 3 with valid_loss value: 0.08409285766502238.
#               3       0.094909       0.084093       0.084093          00:02
# Better model found at epoch 4 with valid_loss value: 0.08305240441765409.
#               4       0.090506       0.083052       0.083052          00:02
# Better model found at epoch 5 with valid_loss value: 0.0825341667752619.
#               5       0.088382       0.082534       0.082534          00:02
# Better model found at epoch 6 with valid_loss value: 0.08236866664653682.
#               6       0.087305       0.082369       0.082369          00:02
# Better model found at epoch 7 with valid_loss value: 0.0818069445592199.
#               7       0.086696       0.081807       0.081807          00:02
# Better model found at epoch 8 with valid_loss value: 0.08155350712278783.
#               8       0.086310       0.081554       0.081554          00:02
# Better model found at epoch 9 with valid_loss value: 0.08148576256897122.
#               9       0.086158       0.081486       0.081486          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08059483303880187.
#               0       0.085725       0.080595       0.080595          00:10
# Better model found at epoch 1 with valid_loss value: 0.07916376472392443.
#               1       0.084500       0.079164       0.079164          00:10
# Better model found at epoch 2 with valid_loss value: 0.07796720251792616.
#               2       0.082728       0.077967       0.077967          00:10
# Better model found at epoch 3 with valid_loss value: 0.07729503609864473.
#               3       0.080713       0.077295       0.077295          00:10
# Better model found at epoch 4 with valid_loss value: 0.07636761459710639.
#               4       0.079046       0.076368       0.076368          00:10
# Better model found at epoch 5 with valid_loss value: 0.0756345520764468.
#               5       0.077809       0.075635       0.075635          00:10
# Better model found at epoch 6 with valid_loss value: 0.07515737535121288.
#               6       0.076932       0.075157       0.075157          00:10
#               7       0.076161       0.075378       0.075378          00:10
# Better model found at epoch 8 with valid_loss value: 0.07509335051521816.
#               8       0.075617       0.075093       0.075093          00:10
# Better model found at epoch 9 with valid_loss value: 0.07501296686679973.
#               9       0.075051       0.075013       0.075013          00:10
#              10       0.074609       0.075250       0.075250          00:10
# Better model found at epoch 11 with valid_loss value: 0.07486105438555228.
#              11       0.074238       0.074861       0.074861          00:10
#              12       0.073834       0.074994       0.074994          00:10
#              13       0.073521       0.075320       0.075320          00:09
#              14       0.073233       0.075012       0.075012          00:09
#              15       0.073066       0.075129       0.075129          00:10
#              16       0.072846       0.075374       0.075374          00:10
#              17       0.072885       0.075178       0.075178          00:10
#              18       0.072730       0.075261       0.075261          00:10
#              19       0.072694       0.075130       0.075130          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 920160
# scores: mse: 0.01816612 rmse: 0.13478175 mae: 0.084764615
# ----------- Complete! -----------
# ==========Running command for ES, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='ES', context_points=336, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/ES/masked_patchtst/based_model/patchtst_pretrained_cw336_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307304
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00011768119524349978
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 42
# number of model params 1307304
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09869717428834596.
#               0       0.139679       0.098697       0.098697          00:02
# Better model found at epoch 1 with valid_loss value: 0.09238910596531265.
#               1       0.117355       0.092389       0.092389          00:02
# Better model found at epoch 2 with valid_loss value: 0.08990885550669973.
#               2       0.105790       0.089909       0.089909          00:02
# Better model found at epoch 3 with valid_loss value: 0.0891335693238772.
#               3       0.097715       0.089134       0.089134          00:02
# Better model found at epoch 4 with valid_loss value: 0.0881937907316452.
#               4       0.094040       0.088194       0.088194          00:02
# Better model found at epoch 5 with valid_loss value: 0.0875173487381391.
#               5       0.092429       0.087517       0.087517          00:02
# ...
# Better model found at epoch 5 with valid_loss value: 0.06838170972421888.
#               5       0.077384       0.068382       0.068382          00:02
#               6       0.076885       0.068434       0.068434          00:02
# Better model found at epoch 7 with valid_loss value: 0.06755383758274942.
#               7       0.076463       0.067554       0.067554          00:02
# Better model found at epoch 8 with valid_loss value: 0.0673896503617224.
#               8       0.076221       0.067390       0.067390          00:02
# Better model found at epoch 9 with valid_loss value: 0.0673502725248688.
#               9       0.076091       0.067350       0.067350          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.0649062744651133.
#               0       0.074582       0.064906       0.064906          00:10
# Better model found at epoch 1 with valid_loss value: 0.062227938515361104.
#               1       0.071105       0.062228       0.062228          00:10
# Better model found at epoch 2 with valid_loss value: 0.06035046196260003.
#               2       0.066724       0.060350       0.060350          00:10
# Better model found at epoch 3 with valid_loss value: 0.05839857887144121.
#               3       0.063592       0.058399       0.058399          00:10
# Better model found at epoch 4 with valid_loss value: 0.057149925434418734.
#               4       0.061639       0.057150       0.057150          00:10
# Better model found at epoch 5 with valid_loss value: 0.0565998629011179.
#               5       0.060538       0.056600       0.056600          00:10
# Better model found at epoch 6 with valid_loss value: 0.05621915648216332.
#               6       0.059594       0.056219       0.056219          00:10
# Better model found at epoch 7 with valid_loss value: 0.05566397905157984.
#               7       0.058870       0.055664       0.055664          00:10
# Better model found at epoch 8 with valid_loss value: 0.05528027830696075.
#               8       0.058342       0.055280       0.055280          00:10
# Better model found at epoch 9 with valid_loss value: 0.05526972453617601.
#               9       0.057860       0.055270       0.055270          00:10
# Better model found at epoch 10 with valid_loss value: 0.05485216827662558.
#              10       0.057482       0.054852       0.054852          00:10
# Better model found at epoch 11 with valid_loss value: 0.05446356371013954.
#              11       0.057016       0.054464       0.054464          00:10
#              12       0.056792       0.054478       0.054478          00:10
# Better model found at epoch 13 with valid_loss value: 0.05441249818573317.
#              13       0.056465       0.054412       0.054412          00:10
# Better model found at epoch 14 with valid_loss value: 0.053849437333810014.
#              14       0.056182       0.053849       0.053849          00:10
#              15       0.055953       0.053875       0.053875          00:10
#              16       0.055875       0.053884       0.053884          00:10
# Better model found at epoch 17 with valid_loss value: 0.053822498220290636.
#              17       0.055749       0.053822       0.053822          00:05
# Better model found at epoch 18 with valid_loss value: 0.05375578857146986.
#              18       0.055574       0.053756       0.053756          00:05
#              19       0.055635       0.053761       0.053761          00:09
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 465816
# scores: mse: 0.00995004 rmse: 0.099749885 mae: 0.056406565
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 96:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=168, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 659424
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 0.00014174741629268049
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 659424
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.09872052632666294.
#               0       0.152170       0.098721       0.098721          00:02
# Better model found at epoch 1 with valid_loss value: 0.09038733535903173.
#               1       0.123111       0.090387       0.090387          00:02
# Better model found at epoch 2 with valid_loss value: 0.08784540236917718.
#               2       0.108513       0.087845       0.087845          00:02
# Better model found at epoch 3 with valid_loss value: 0.08691302952095199.
#               3       0.099560       0.086913       0.086913          00:02
# Better model found at epoch 4 with valid_loss value: 0.08669835859629271.
#               4       0.096531       0.086698       0.086698          00:02
# Better model found at epoch 5 with valid_loss value: 0.08582033633797803.
#               5       0.095575       0.085820       0.085820          00:02
# Better model found at epoch 6 with valid_loss value: 0.08581455562830553.
#               6       0.095112       0.085815       0.085815          00:02
# Better model found at epoch 7 with valid_loss value: 0.08543210506827197.
#               7       0.094796       0.085432       0.085432          00:02
# Better model found at epoch 8 with valid_loss value: 0.08520463116291192.
#               8       0.094524       0.085205       0.085205          00:02
# Better model found at epoch 9 with valid_loss value: 0.08518661362451688.
#               9       0.094435       0.085187       0.085187          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08365076249745729.
#               0       0.093404       0.083651       0.083651          00:10
# Better model found at epoch 1 with valid_loss value: 0.08150243425485659.
#               1       0.090463       0.081502       0.081502          00:10
# Better model found at epoch 2 with valid_loss value: 0.07941759449374491.
#               2       0.087138       0.079418       0.079418          00:10
# Better model found at epoch 3 with valid_loss value: 0.07802236757208604.
#               3       0.084221       0.078022       0.078022          00:10
# Better model found at epoch 4 with valid_loss value: 0.07708253045698993.
#               4       0.082453       0.077083       0.077083          00:10
# Better model found at epoch 5 with valid_loss value: 0.0761741545066492.
#               5       0.081178       0.076174       0.076174          00:10
# Better model found at epoch 6 with valid_loss value: 0.07538661227369813.
#               6       0.080252       0.075387       0.075387          00:10
# Better model found at epoch 7 with valid_loss value: 0.07507601831869151.
#               7       0.079499       0.075076       0.075076          00:10
# Better model found at epoch 8 with valid_loss value: 0.07490584495302328.
#               8       0.079017       0.074906       0.074906          00:10
# Better model found at epoch 9 with valid_loss value: 0.0746875834329231.
#               9       0.078576       0.074688       0.074688          00:10
# Better model found at epoch 10 with valid_loss value: 0.0745741295562322.
#              10       0.078148       0.074574       0.074574          00:10
#              11       0.077844       0.074575       0.074575          00:10
# Better model found at epoch 12 with valid_loss value: 0.07406192093578366.
#              12       0.077537       0.074062       0.074062          00:10
#              13       0.077209       0.074097       0.074097          00:10
# Better model found at epoch 14 with valid_loss value: 0.07385300092332435.
#              14       0.076953       0.073853       0.073853          00:10
# Better model found at epoch 15 with valid_loss value: 0.0738239781850717.
#              15       0.076761       0.073824       0.073824          00:10
# Better model found at epoch 16 with valid_loss value: 0.0737893137920184.
#              16       0.076584       0.073789       0.073789          00:10
#              17       0.076569       0.073851       0.073851          00:10
# Better model found at epoch 18 with valid_loss value: 0.07370794186076078.
#              18       0.076447       0.073708       0.073708          00:09
#              19       0.076467       0.073750       0.073750          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 659424
# scores: mse: 0.01814586 rmse: 0.13470657 mae: 0.07888919
# ----------- Complete! -----------
# ==========Running command for IT, pred_len 168:==========
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='IT', context_points=168, target_points=168, batch_size=64, num_workers=0, scaler='standard', features='M', patch_len=8, stride=8, revin=1, overlapping_windows=True, scaler_type='minmax', if_relu=False, n_layers=3, n_heads=16, d_model=128, d_ff=256, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='saved_models/IT/masked_patchtst/based_model/patchtst_pretrained_cw168_patch8_stride8_epochs-pretrain100_mask0.4_model1.pth', finetuned_model_id=1, model_type='based_model')
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 853032
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# suggested_lr 9.770099572992256e-05
# end-to-end finetuning
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 853032
# check unmatched_layers: ['backbone.encoder.layers.0.ff.0.weight', 'backbone.encoder.layers.0.ff.0.bias', 'backbone.encoder.layers.0.ff.3.weight', 'backbone.encoder.layers.1.ff.0.weight', 'backbone.encoder.layers.1.ff.0.bias', 'backbone.encoder.layers.1.ff.3.weight', 'backbone.encoder.layers.2.ff.0.weight', 'backbone.encoder.layers.2.ff.0.bias', 'backbone.encoder.layers.2.ff.3.weight']
# Finetune the head
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.10374234854517433.
#               0       0.160756       0.103742       0.103742          00:02
# Better model found at epoch 1 with valid_loss value: 0.09527668292609193.
#               1       0.129751       0.095277       0.095277          00:02
# Better model found at epoch 2 with valid_loss value: 0.09221374923778919.
#               2       0.117822       0.092214       0.092214          00:02
# Better model found at epoch 3 with valid_loss value: 0.09155626201205644.
#               3       0.108354       0.091556       0.091556          00:02
# Better model found at epoch 4 with valid_loss value: 0.09047271462184052.
#               4       0.103119       0.090473       0.090473          00:02
# Better model found at epoch 5 with valid_loss value: 0.08957436315196361.
#               5       0.100613       0.089574       0.089574          00:02
# Better model found at epoch 6 with valid_loss value: 0.08933927780043327.
#               6       0.099567       0.089339       0.089339          00:02
# Better model found at epoch 7 with valid_loss value: 0.08903604171705191.
#               7       0.098982       0.089036       0.089036          00:02
#               8       0.098778       0.089102       0.089102          00:02
# Better model found at epoch 9 with valid_loss value: 0.08890856437111498.
#               9       0.098622       0.088909       0.088909          00:02
# Finetune the entire network
#           epoch     train_loss     valid_loss      valid_mae           time
# Better model found at epoch 0 with valid_loss value: 0.08796051442475918.
#               0       0.097892       0.087961       0.087961          00:06
# Better model found at epoch 1 with valid_loss value: 0.08619901750383356.
#               1       0.095692       0.086199       0.086199          00:04
# Better model found at epoch 2 with valid_loss value: 0.08465379187013729.
#               2       0.092832       0.084654       0.084654          00:10
# Better model found at epoch 3 with valid_loss value: 0.08353445554670777.
#               3       0.090007       0.083534       0.083534          00:10
# Better model found at epoch 4 with valid_loss value: 0.08252766692577546.
#               4       0.087958       0.082528       0.082528          00:10
# Better model found at epoch 5 with valid_loss value: 0.08199582790083927.
#               5       0.086607       0.081996       0.081996          00:10
# Better model found at epoch 6 with valid_loss value: 0.08144163712429761.
#               6       0.085685       0.081442       0.081442          00:11
# Better model found at epoch 7 with valid_loss value: 0.08080308959096616.
#               7       0.085057       0.080803       0.080803          00:10
# Better model found at epoch 8 with valid_loss value: 0.08078761723413315.
#               8       0.084555       0.080788       0.080788          00:10
# Better model found at epoch 9 with valid_loss value: 0.08066311978673535.
#               9       0.084052       0.080663       0.080663          00:10
# Better model found at epoch 10 with valid_loss value: 0.08031802442033385.
#              10       0.083691       0.080318       0.080318          00:10
# Better model found at epoch 11 with valid_loss value: 0.08002947677443963.
#              11       0.083437       0.080029       0.080030          00:10
# Better model found at epoch 12 with valid_loss value: 0.07969781356452227.
#              12       0.083223       0.079698       0.079698          00:10
#              13       0.082953       0.079893       0.079893          00:10
#              14       0.082753       0.080098       0.080098          00:09
#              15       0.082562       0.079855       0.079855          00:10
#              16       0.082455       0.079758       0.079758          00:10
#              17       0.082375       0.079708       0.079708          00:10
#              18       0.082363       0.079851       0.079852          00:10
#              19       0.082294       0.079866       0.079866          00:10
# finetune completed
# scaler_type: minmax overlapping_windows: True
# number of patches: 21
# number of model params 853032
# scores: mse: 0.019644476 rmse: 0.14015876 mae: 0.08383012
# ----------- Complete! -----------
# Total time: 01h:04m:41.07s

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup.columns = pd.MultiIndex.from_product([['Self-supervised'], ['MSE','RMSE', 'MAE']], names=['Model', 'Metrics'])

# Path if not exists
path = "results/patchtst/"
if not os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results_neeeeew.csv"), index=True)
df_self_sup.round(4)
# Out:
# Model            Self-supervised
# Metrics                      MSE    RMSE     MAE
# Country Pred_len
# DE      24                0.0211  0.1453  0.0883
#         96                0.0366  0.1912  0.1269
#         168               0.0394  0.1984  0.1336
# GB      24                0.0245  0.1566  0.0998
#         96                0.0419  0.2047  0.1402
#         168               0.0431  0.2076  0.1442
# ES      24                0.0094  0.0971  0.0579
#         96                0.0182  0.1348  0.0848
#         168               0.0208  0.1441  0.0919
# FR      24                0.0099  0.0994  0.0530
#         96                0.0198  0.1406  0.0792
#         168               0.0221  0.1486  0.0861
# IT      24                0.0100  0.0997  0.0564
#         96                0.0181  0.1347  0.0789
#         168               0.0196  0.1402  0.0838

# %%
df_self_sup = pd.DataFrame(data)
df_self_sup.set_index(['Country', 'Pred_len'], inplace=True)
df_self_sup.columns = pd.MultiIndex.from_product([['Self-supervised'], ['MSE','RMSE', 'MAE']], names=['Model', 'Metrics'])

# Path if not exists
path = "results/patchtst/"
if not os.path.exists(path):
    os.makedirs(path)

# Save the results to a CSV file
df_self_sup.to_csv(os.path.join(path, "finetune_results.csv"), index=True)
df_self_sup.round(4)
# Out:
# Model            Self-supervised
# Metrics                      MSE    RMSE     MAE
# Country Pred_len
# DE      24                0.0210  0.1448  0.0878
#         96                0.0353  0.1878  0.1256
#         168               0.0379  0.1947  0.1318
# GB      24                0.0247  0.1571  0.1001
#         96                0.0409  0.2021  0.1390
#         168               0.0429  0.2071  0.1445
# ES      24                0.0094  0.0970  0.0581
#         96                0.0185  0.1359  0.0867
#         168               0.0208  0.1442  0.0924
# FR      24                0.0100  0.1002  0.0537
#         96                0.0193  0.1390  0.0785
#         168               0.0212  0.1455  0.0856
# IT      24                0.0101  0.1003  0.0571
#         96                0.0181  0.1344  0.0795
#         168               0.0197  0.1403  0.0853
